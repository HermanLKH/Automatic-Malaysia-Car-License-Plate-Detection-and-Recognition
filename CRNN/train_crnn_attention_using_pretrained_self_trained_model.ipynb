# %%
# cell 1
import os
import time
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import pandas as pd
import random
import numpy as np

from config import (IMG_HEIGHT, IMG_WIDTH, NUM_FIDUCIAL,
                    INPUT_CHANNEL, OUTPUT_CHANNEL, HIDDEN_SIZE,
                    CHARACTERS, NUM_CLASSES)
from dataset import LmdbDataset, AlignCollate
# from utils import CTCLabelConverter, Averager
from utils import AttnLabelConverter, Averager
from model import CRNN

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print("Running on", device)
# Out:
# Running on cuda

# %%
# ─── cell 0: reproducibility ────────────────────────────────────────────────
SEED = 300188
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)

# Make cuDNN deterministic (slower but reproducible)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

print(f"All seeds set to {SEED}, cudnn.deterministic={torch.backends.cudnn.deterministic}")
# Out:
# All seeds set to 300188, cudnn.deterministic=True

# %%
# cell 2
# paths to your LMDBs
train_lmdb = "lmdb_data/train"
val_lmdb   = "lmdb_data/val"

# instantiate datasets
train_dataset = LmdbDataset(train_lmdb)
val_dataset   = LmdbDataset(val_lmdb)

# collate_fn resizes + normalizes
collate_fn = AlignCollate(
    imgH=IMG_HEIGHT, imgW=IMG_WIDTH, keep_ratio_with_pad=False
)

# loaders
BATCH_SIZE = 32
train_loader = DataLoader(
    train_dataset, batch_size=BATCH_SIZE, shuffle=True,
    num_workers=0, collate_fn=collate_fn, pin_memory=True
)
val_loader = DataLoader(
    val_dataset, batch_size=BATCH_SIZE, shuffle=False,
    num_workers=0, collate_fn=collate_fn, pin_memory=True
)

print(f"{len(train_dataset)} train / {len(val_dataset)} val samples")
# Out:
# Loaded 884 valid samples from lmdb_data/train
# Loaded 252 valid samples from lmdb_data/val
# 884 train / 252 val samples

# %%
converter   = AttnLabelConverter(CHARACTERS)
num_classes = len(converter.character)   # includes [GO] and [s]

model = CRNN(
    IMG_HEIGHT,      # imgH
    IMG_WIDTH,       # imgW
    INPUT_CHANNEL,   # input_channel
    OUTPUT_CHANNEL,  # output_channel
    HIDDEN_SIZE,     # hidden_size
    num_classes,     # num_classes (with GO/s)
    True,            # use_attention
    NUM_FIDUCIAL     # num_fiducial
).to(device)

criterion = nn.CrossEntropyLoss(ignore_index=0).to(device)
optimizer = optim.Adadelta(model.parameters(), lr=1.0)

# %%
# ─── cell 4: validate (Attention) ─────────────────────────────────────────────
NUM_EPOCHS       = 500
PRINT_EVERY      = 28
BATCH_MAX_LENGTH = 25     # 25 # must match what you used to init the converter

def validate(model, loader):
    model.eval()
    avg_loss = Averager()
    correct, total = 0, 0

    with torch.no_grad():
        for images, texts in loader:
            images = images.to(device)

            # encode full text → shape [B, L+1], plus lengths
            text, length = converter.encode(texts, batch_max_length=BATCH_MAX_LENGTH)
            text_input  = text[:, :-1].to(device)  # drop final [s]
            text_target = text[:,  1:].to(device)  # everything after [GO]

            # forward
            preds = model(images, text_input, is_train=False,
                          batch_max_length=BATCH_MAX_LENGTH)
            B, S, C = preds.size()

            # cross‐entropy over (B×S) predictions
            loss = criterion(
                preds.view(B * S, C),
                text_target.contiguous().view(B * S)
            )
            avg_loss.add(loss)

            # greedy decode
            _, pred_inds = preds.max(2)                   # [B, S]
            pred_strs = converter.decode(pred_inds, length)  # pass length

            # strip off anything after the "[s]" token
            pred_strs = [s.split('[s]')[0] for s in pred_strs]

            total += len(texts)
            correct += sum(p == g for p, g in zip(pred_strs, texts))

    acc = correct / total * 100
    return avg_loss.val(), acc

# %%
# ─── cell 5: load pretrained CTC weights (skip old Prediction head) ────────────

from collections import OrderedDict

orig      = torch.load("best_pretrained_attention_crnn.pth", map_location=device)
# strip off the "module." prefix if you wrapped in DataParallel
stripped  = OrderedDict((k[len("module."):], v)
                        for k, v in orig.items()
                        if k.startswith("module."))

own = model.state_dict()
for k, v in stripped.items():
    # skip the old attention head entirely
    if k.startswith("Prediction."):
        continue
    # only overwrite if shapes match
    if k in own and v.size() == own[k].size():
        own[k] = v

model.load_state_dict(own)
print("✅ Loaded pretrained moddel (trained on generated dataset)")
# Out:
# ✅ Loaded pretrained moddel (trained on generated dataset)

# %%
# ─── Cell 6: training w/ history, best‐model saving, plotting & ONNX export ───

# hyper‐params
best_val_acc    = 0.0
history         = {'epoch': [], 'train_loss': [], 'val_loss': [], 'val_acc': []}

for epoch in range(1, NUM_EPOCHS+1):
    print(f"→ Starting epoch {epoch}  (printing every {PRINT_EVERY} iters)")
    model.train()
    epoch_loss = Averager()
    start = time.time()

    # ─── training ─────────────────────────────────────────────────────────────
    for i, (images, texts) in enumerate(train_loader, 1):
        images = images.to(device)

        text, length   = converter.encode(texts, batch_max_length=BATCH_MAX_LENGTH)
        text_input     = text[:, :-1].to(device)
        text_target    = text[:,  1:].to(device)

        preds = model(
            images,
            text=text_input,
            is_train=True,
            batch_max_length=BATCH_MAX_LENGTH
        )  # [B, S, C]
        B, S, C = preds.size()
        loss = criterion(
            preds.view(B * S, C),
            text_target.contiguous().view(B * S)
        )

        optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 5)
        optimizer.step()
        epoch_loss.add(loss)

        # mini‐table prints
        if i % PRINT_EVERY == 0 or i == 1:
            print(f"[Epoch {epoch}] iter {i}/{len(train_loader)}, avg loss: {epoch_loss.val():.4f}", flush=True)
            with torch.no_grad():
                probs     = preds.softmax(2)
                max_vals, max_inds = probs.max(2)
                pred_strs = converter.decode(max_inds, length)
                pred_strs = [s.split('[s]')[0] for s in pred_strs]

            print("-" * 80)
            print(f"{'Ground Truth':25s} | {'Prediction':25s} | AvgConfidence")
            print("-" * 80)
            for gt, pr, conf_seq in zip(texts[:5], pred_strs[:5], max_vals[:5]):
                conf = conf_seq.mean().item()
                print(f"{gt:25s} | {pr:25s} | {conf_seq.mean().item():.4f}")
            print("-" * 80)

    # ─── validation ────────────────────────────────────────────────────────────
    val_loss, val_acc = validate(model, val_loader)
    elapsed = time.time() - start
    train_l = epoch_loss.val()
    print(f"==> Epoch {epoch} done in {elapsed:.1f}s | "
          f"train_loss={train_l:.4f}  valid_loss={val_loss:.4f}  valid_acc={val_acc:.2f}%\n")

    # ─── record history & save best ──────────────────────────────────────────
    history['epoch'].append(epoch)
    history['train_loss'].append(train_l)
    history['val_loss'].append(val_loss)
    history['val_acc'].append(val_acc)

    if val_acc > best_val_acc:
        best_val_acc = val_acc
        torch.save(model.state_dict(), "best_attention_crnn.pth")
        print(f"💾 New best model saved (epoch {epoch}, val_acc={val_acc:.2f}%)\n")
# Out:
# → Starting epoch 1  (printing every 28 iters)
# [Epoch 1] iter 1/28, avg loss: 3.6477
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QCK8417                   |                           | 0.0274
# PMU3220                   |                           | 0.0274
# VFK8102                   |                           | 0.0274
# QAB401E                   |                           | 0.0274
# PZ171M                    |                           | 0.0274
# --------------------------------------------------------------------------------
# [Epoch 1] iter 28/28, avg loss: 3.3198
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QAB2477H                  | 7                         | 0.2923
# QKW3360                   | 77                        | 0.3001
# QM5826G                   | 7                         | 0.2974
# JSH9196                   | 7                         | 0.2912
# VFH2157                   | 77                        | 0.2984
# --------------------------------------------------------------------------------
# ==> Epoch 1 done in 3.1s | train_loss=3.3198  valid_loss=3.0270  valid_acc=0.00%
#
# → Starting epoch 2  (printing every 28 iters)
# [Epoch 2] iter 1/28, avg loss: 3.0260
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# JCY8064                   | 77                        | 0.3439
# VAW902                    | 77                        | 0.3442
# KCT6037                   | 77                        | 0.3464
# SM2004                    | 77                        | 0.3497
# QS2775V                   | 7                         | 0.3440
# --------------------------------------------------------------------------------
# [Epoch 2] iter 28/28, avg loss: 2.9582
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QCL6382                   | QAA11                     | 0.5435
# VAH7666                   | QAA11                     | 0.5397
# NAH1048                   | QAA11                     | 0.5403
# QRT99                     | QAA11                     | 0.5366
# QAA8678A                  | QAA11                     | 0.5416
# --------------------------------------------------------------------------------
# ==> Epoch 2 done in 2.4s | train_loss=2.9582  valid_loss=2.8259  valid_acc=0.00%
#
# → Starting epoch 3  (printing every 28 iters)
# [Epoch 3] iter 1/28, avg loss: 2.8089
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# T/M232                    | QAA66                     | 0.5799
# JUS8529                   | QAA66                     | 0.5796
# BQP5287                   | QAA66                     | 0.5795
# PGX9411                   | QAA66                     | 0.5822
# QTA2566                   | QAA66                     | 0.5797
# --------------------------------------------------------------------------------
# [Epoch 3] iter 28/28, avg loss: 2.8149
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# KDH2309                   | QAA7777                   | 0.5596
# QCJ4164                   | QAA7777                   | 0.5585
# JUJ7630                   | QAA7777                   | 0.5597
# VAK1383                   | QAA7777                   | 0.5589
# QPC7622                   | QAA7777                   | 0.5600
# --------------------------------------------------------------------------------
# ==> Epoch 3 done in 2.4s | train_loss=2.8149  valid_loss=2.8951  valid_acc=0.00%
#
# → Starting epoch 4  (printing every 28 iters)
# [Epoch 4] iter 1/28, avg loss: 2.9706
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# SM2004                    | QA99                      | 0.7467
# NDY5034                   | QA99                      | 0.7460
# PPA4817                   | QA99                      | 0.7452
# TBY9929                   | QA99                      | 0.7467
# NDH2698                   | QA99                      | 0.7466
# --------------------------------------------------------------------------------
# [Epoch 4] iter 28/28, avg loss: 2.7506
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QAA4174                   | QA76                      | 0.7444
# VFX8581                   | QA71                      | 0.7468
# JTF3425                   | QA71                      | 0.7465
# KBJ5226                   | QA71                      | 0.7439
# SYU3073                   | QA71                      | 0.7466
# --------------------------------------------------------------------------------
# ==> Epoch 4 done in 2.4s | train_loss=2.7506  valid_loss=2.7044  valid_acc=0.00%
#
# → Starting epoch 5  (printing every 28 iters)
# [Epoch 5] iter 1/28, avg loss: 2.7242
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QTY1471                   | QAA777                    | 0.4920
# WB6629Q                   | QAA777                    | 0.4914
# T/N7845                   | QAA777                    | 0.4903
# VBY8203                   | QAA777                    | 0.4910
# VFX447                    | QAA777                    | 0.4909
# --------------------------------------------------------------------------------
# [Epoch 5] iter 28/28, avg loss: 2.6710
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# BRJ8996                   | QA771                     | 0.7394
# WUP3371                   | QA771                     | 0.7389
# QAA4174                   | QAA71                     | 0.7379
# BQX3898                   | QAA71                     | 0.7380
# AEE7918                   | QA771                     | 0.7390
# --------------------------------------------------------------------------------
# ==> Epoch 5 done in 2.4s | train_loss=2.6710  valid_loss=2.7709  valid_acc=0.00%
#
# → Starting epoch 6  (printing every 28 iters)
# [Epoch 6] iter 1/28, avg loss: 2.8425
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# VLB768                    | QQA7711                   | 0.5060
# PDG4307                   | QQA7711                   | 0.5046
# QTT7328                   | QQA7711                   | 0.5030
# WXQ6691                   | QQA7711                   | 0.5080
# JUS8529                   | QQA7711                   | 0.5062
# --------------------------------------------------------------------------------
# [Epoch 6] iter 28/28, avg loss: 2.6307
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# AND897                    | QWB566                    | 0.3803
# WNB6877                   | QWB5666                   | 0.3842
# PLT2670                   | QWC5666                   | 0.3837
# QM9779R                   | QWB5666                   | 0.3837
# 426                       | QWB566                    | 0.3694
# --------------------------------------------------------------------------------
# ==> Epoch 6 done in 2.4s | train_loss=2.6307  valid_loss=2.6780  valid_acc=0.00%
#
# → Starting epoch 7  (printing every 28 iters)
# [Epoch 7] iter 1/28, avg loss: 2.6427
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# WVB5362                   | QW777                     | 0.4661
# AJA8335                   | QW777                     | 0.4836
# BRJ8996                   | QW777                     | 0.4897
# BMG317                    | QW777                     | 0.4613
# JVD4749                   | QW777                     | 0.4875
# --------------------------------------------------------------------------------
# [Epoch 7] iter 28/28, avg loss: 2.5820
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# JRA7032                   | QAA4991                   | 0.2488
# TAM408                    | QAA4999                   | 0.2365
# NCH9890                   | QAA4999                   | 0.2478
# CEN2010                   | QAA4999                   | 0.2581
# 426                       | QAA4999                   | 0.2248
# --------------------------------------------------------------------------------
# ==> Epoch 7 done in 2.4s | train_loss=2.5820  valid_loss=2.7063  valid_acc=0.00%
#
# → Starting epoch 8  (printing every 28 iters)
# [Epoch 8] iter 1/28, avg loss: 2.6529
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# JKN8193                   | QA444                     | 0.3397
# QC5088                    | QA440                     | 0.3284
# T/BE701                   | QA444                     | 0.3358
# T/N4793                   | QA444                     | 0.3351
# WB8444L                   | QA444                     | 0.3395
# --------------------------------------------------------------------------------
# [Epoch 8] iter 28/28, avg loss: 2.5499
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# JUJ7630                   | QAA6699                   | 0.2823
# JNB9682                   | QAA6699                   | 0.2735
# CES4236                   | QAA6699                   | 0.2792
# QRK6337                   | QAA6699                   | 0.2809
# VAJ4559                   | QAA6699                   | 0.2820
# --------------------------------------------------------------------------------
# ==> Epoch 8 done in 2.4s | train_loss=2.5499  valid_loss=2.5374  valid_acc=0.00%
#
# → Starting epoch 9  (printing every 28 iters)
# [Epoch 9] iter 1/28, avg loss: 2.5469
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# KFW2299                   | QAA633                    | 0.3176
# VHE7588                   | QAA633                    | 0.3215
# QAB9766H                  | QAA633                    | 0.3260
# NAN6440                   | QAA633                    | 0.3178
# QAB7401J                  | QAA633                    | 0.3258
# --------------------------------------------------------------------------------
# [Epoch 9] iter 28/28, avg loss: 2.5411
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# WPB3184                   | QAB9999                   | 0.2846
# WNB6877                   | QAA9999                   | 0.2801
# QCG9886                   | QAA9999                   | 0.2864
# GOLD7966                  | QAA9999                   | 0.2934
# PC8558A                   | QAB9999                   | 0.2828
# --------------------------------------------------------------------------------
# ==> Epoch 9 done in 2.5s | train_loss=2.5411  valid_loss=2.5331  valid_acc=0.00%
#
# → Starting epoch 10  (printing every 28 iters)
# [Epoch 10] iter 1/28, avg loss: 2.4990
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# T/BB578                   | QAB777                    | 0.3053
# QSV1707                   | QAB777                    | 0.3073
# RAB7878                   | QAB777                    | 0.3098
# PGL2189                   | QAB777                    | 0.3046
# MBC6268                   | QAB777                    | 0.3049
# --------------------------------------------------------------------------------
# [Epoch 10] iter 28/28, avg loss: 2.5185
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# FFF1519                   | QAB666                    | 0.3122
# BGQ1741                   | QBB666                    | 0.2846
# TAM408                    | QAB666                    | 0.3003
# DFC7000                   | QAB666                    | 0.3053
# QS5039N                   | QAB666                    | 0.2895
# --------------------------------------------------------------------------------
# ==> Epoch 10 done in 2.5s | train_loss=2.5185  valid_loss=2.5285  valid_acc=0.00%
#
# → Starting epoch 11  (printing every 28 iters)
# [Epoch 11] iter 1/28, avg loss: 2.5447
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# PRF6163                   | QAA9919                   | 0.2846
# JVJ7886                   | QAB911                    | 0.3124
# QTJ9189                   | QAB911                    | 0.3124
# MCR5505                   | QAA991                    | 0.2798
# FFF1519                   | QAB911                    | 0.3120
# --------------------------------------------------------------------------------
# [Epoch 11] iter 28/28, avg loss: 2.4982
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# T/JA7639                  | QAA860                    | 0.3480
# QCQ9249                   | QAA860                    | 0.3433
# WXQ6691                   | QAA860                    | 0.3390
# BPT2823                   | QAA860                    | 0.3387
# TAM408                    | QAA860                    | 0.3302
# --------------------------------------------------------------------------------
# ==> Epoch 11 done in 2.4s | train_loss=2.4982  valid_loss=2.5525  valid_acc=0.00%
#
# → Starting epoch 12  (printing every 28 iters)
# [Epoch 12] iter 1/28, avg loss: 2.5194
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# JWY375                    | QAA9999                   | 0.3202
# NAP4617                   | QAA9999                   | 0.3281
# AJA8335                   | QAA9999                   | 0.3161
# WUP3371                   | QAA9999                   | 0.3281
# QCJ4164                   | QAA9999                   | 0.3004
# --------------------------------------------------------------------------------
# [Epoch 12] iter 28/28, avg loss: 2.4959
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QKY2146                   | QAB888                    | 0.3106
# JTC5690                   | QBB772                    | 0.2932
# WB1351J                   | QAB788                    | 0.3219
# SYS100                    | QW777                     | 0.2007
# VDP6513                   | QAB888                    | 0.3090
# --------------------------------------------------------------------------------
# ==> Epoch 12 done in 2.5s | train_loss=2.4959  valid_loss=2.4861  valid_acc=0.00%
#
# → Starting epoch 13  (printing every 28 iters)
# [Epoch 13] iter 1/28, avg loss: 2.4905
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# UNIMAS9600                | QAA3338                   | 0.3083
# QRL1169                   | QAA333                    | 0.3097
# AND897                    | QAA333                    | 0.3172
# WWB3971                   | QAB333                    | 0.3233
# NDP6199                   | QAA333                    | 0.3208
# --------------------------------------------------------------------------------
# [Epoch 13] iter 28/28, avg loss: 2.4698
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# BJB6131                   | QAA888                    | 0.3367
# MBP8122                   | QAA888                    | 0.3408
# WC3255U                   | QAA888                    | 0.3375
# T/JA383                   | QAA888                    | 0.3395
# PRF6163                   | QAA788                    | 0.3430
# --------------------------------------------------------------------------------
# ==> Epoch 13 done in 2.4s | train_loss=2.4698  valid_loss=2.4888  valid_acc=0.00%
#
# → Starting epoch 14  (printing every 28 iters)
# [Epoch 14] iter 1/28, avg loss: 2.3772
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# WQD6028                   | QAA883                    | 0.3297
# VX2808                    | QAA883                    | 0.3271
# BKB9642                   | QAA883                    | 0.3318
# JUH2988                   | QAA883                    | 0.3314
# QKF9421                   | QAA888                    | 0.3230
# --------------------------------------------------------------------------------
# [Epoch 14] iter 28/28, avg loss: 2.4597
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# BNG7883                   | QAA9333                   | 0.3500
# KFL5361                   | QAA9333                   | 0.3506
# AGX7136                   | QAA9333                   | 0.3268
# VJY4021                   | QAA9333                   | 0.3394
# BLJ6613                   | QAB3333                   | 0.3547
# --------------------------------------------------------------------------------
# ==> Epoch 14 done in 2.5s | train_loss=2.4597  valid_loss=2.4938  valid_acc=0.00%
#
# → Starting epoch 15  (printing every 28 iters)
# [Epoch 15] iter 1/28, avg loss: 2.4091
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QAU4660                   | QAA333                    | 0.3136
# WVB5362                   | QCB333                    | 0.3487
# ANM7267                   | QAB333                    | 0.3546
# PCT6590                   | QAB333                    | 0.3532
# QKY4531                   | QAA333                    | 0.3535
# --------------------------------------------------------------------------------
# [Epoch 15] iter 28/28, avg loss: 2.4468
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QKB1883                   | QAA5559                   | 0.3589
# JKN9008                   | QAA522                    | 0.3784
# VX2808                    | QAA222                    | 0.3771
# PPA4817                   | QAB522                    | 0.3890
# WLC9954                   | QAA5229                   | 0.3804
# --------------------------------------------------------------------------------
# ==> Epoch 15 done in 2.5s | train_loss=2.4468  valid_loss=2.4766  valid_acc=0.00%
#
# → Starting epoch 16  (printing every 28 iters)
# [Epoch 16] iter 1/28, avg loss: 2.3456
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# PLT2670                   | QAA711                    | 0.3820
# QAB9551A                  | QAA9118                   | 0.3467
# PPD2622                   | QAA771                    | 0.3840
# ABE8012                   | QAA9118                   | 0.3820
# VET8129                   | QAA711                    | 0.3853
# --------------------------------------------------------------------------------
# [Epoch 16] iter 28/28, avg loss: 2.4473
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# PMG7552                   | QJB773                    | 0.3792
# CDR5920                   | QAB7333                   | 0.3675
# SYH6139                   | QAB7333                   | 0.3647
# NDB8499                   | QAA9388                   | 0.3373
# VJD5050                   | QJB773                    | 0.3776
# --------------------------------------------------------------------------------
# ==> Epoch 16 done in 2.5s | train_loss=2.4473  valid_loss=2.4733  valid_acc=0.00%
#
# → Starting epoch 17  (printing every 28 iters)
# [Epoch 17] iter 1/28, avg loss: 2.5232
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# JVJ7886                   | QBB911                    | 0.3834
# BPV878                    | QCB911                    | 0.3625
# JUH2988                   | QAB9119                   | 0.3671
# UMT6556                   | QCB911                    | 0.3835
# BDA8389                   | QAB9919                   | 0.3385
# --------------------------------------------------------------------------------
# [Epoch 17] iter 28/28, avg loss: 2.4347
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# BKJ3569                   | QCB881                    | 0.3785
# VLS3922                   | QAA8888                   | 0.3715
# QKU9019                   | QAA8888                   | 0.3262
# QAB9766H                  | QAA8888                   | 0.3701
# WNT3307                   | QAA8888                   | 0.3738
# --------------------------------------------------------------------------------
# ==> Epoch 17 done in 2.4s | train_loss=2.4347  valid_loss=2.5267  valid_acc=0.00%
#
# → Starting epoch 18  (printing every 28 iters)
# [Epoch 18] iter 1/28, avg loss: 2.3920
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# AMS4464                   | QAB1116                   | 0.3770
# AFL6541                   | QAB1110                   | 0.3832
# MBT7931                   | QAB1110                   | 0.3739
# ALX5554                   | QAB1110                   | 0.3711
# QAB9551A                  | QAA9116                   | 0.3557
# --------------------------------------------------------------------------------
# [Epoch 18] iter 28/28, avg loss: 2.4264
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# JWW9278                   | QAA939                    | 0.3852
# WFR9497                   | QAA939                    | 0.3865
# QBB7772                   | QAA999                    | 0.4027
# QLB7733                   | QAA9999                   | 0.3551
# QAA9381W                  | QAA939                    | 0.3993
# --------------------------------------------------------------------------------
# ==> Epoch 18 done in 2.4s | train_loss=2.4264  valid_loss=2.7385  valid_acc=0.00%
#
# → Starting epoch 19  (printing every 28 iters)
# [Epoch 19] iter 1/28, avg loss: 2.3341
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QAA8678A                  | QAA9999                   | 0.3999
# VHC9931                   | QAB7799                   | 0.3833
# VAM9906                   | QAA9799                   | 0.3900
# QS1016K                   | QAA9999                   | 0.3821
# QAB7401J                  | QAA9999                   | 0.3525
# --------------------------------------------------------------------------------
# [Epoch 19] iter 28/28, avg loss: 2.4292
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QAA6198S                  | QAB8888                   | 0.4037
# VS5705                    | VV77                      | 0.3776
# VDA4811                   | QCB8888                   | 0.3888
# WC3399L                   | QAB8888                   | 0.3801
# MDB5515                   | QCB8888                   | 0.3859
# --------------------------------------------------------------------------------
# ==> Epoch 19 done in 2.3s | train_loss=2.4292  valid_loss=2.5434  valid_acc=0.00%
#
# → Starting epoch 20  (printing every 28 iters)
# [Epoch 20] iter 1/28, avg loss: 2.2771
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# PLT2670                   | VJB779                    | 0.4122
# QAA5728D                  | QAA9999                   | 0.4043
# QKY2146                   | QAB9999                   | 0.3941
# TDB7888                   | VTT777                    | 0.4201
# BDW7792                   | VJB779                    | 0.4128
# --------------------------------------------------------------------------------
# [Epoch 20] iter 28/28, avg loss: 2.4113
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# BLJ6613                   | VCB788                    | 0.4103
# QPD9089                   | QAB888                    | 0.4046
# NEA1254                   | QCB888                    | 0.3961
# ALN8722                   | QCB888                    | 0.3987
# BMG317                    | QCB888                    | 0.3879
# --------------------------------------------------------------------------------
# ==> Epoch 20 done in 2.3s | train_loss=2.4113  valid_loss=2.4803  valid_acc=0.00%
#
# → Starting epoch 21  (printing every 28 iters)
# [Epoch 21] iter 1/28, avg loss: 2.3507
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QDB7699                   | QCB8112                   | 0.3966
# PEJ9595                   | WCB711                    | 0.4017
# MDN8761                   | WCB8112                   | 0.3925
# PGL2189                   | QMB8112                   | 0.3983
# CDD8169                   | QMB8112                   | 0.3940
# --------------------------------------------------------------------------------
# [Epoch 21] iter 28/28, avg loss: 2.4031
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# KDS3030                   | QAA9398                   | 0.3837
# VFM6378                   | QCB9338                   | 0.3928
# WTT1097                   | VCB333                    | 0.3978
# BNB8655                   | QCB9338                   | 0.3811
# PRH9023                   | QAA9398                   | 0.3844
# --------------------------------------------------------------------------------
# ==> Epoch 21 done in 2.4s | train_loss=2.4031  valid_loss=3.0224  valid_acc=0.00%
#
# → Starting epoch 22  (printing every 28 iters)
# [Epoch 22] iter 1/28, avg loss: 2.5341
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# ANK8132                   | VDB777                    | 0.4072
# VBY8203                   | VDB777                    | 0.4050
# QAW2391                   | QAA989                    | 0.4018
# WXP416                    | VV777                     | 0.4281
# VKR5274                   | VDB979                    | 0.3943
# --------------------------------------------------------------------------------
# [Epoch 22] iter 28/28, avg loss: 2.3885
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# AJU9877                   | QDB999                    | 0.3749
# QPC5351                   | QCB909                    | 0.3799
# JSD809                    | QDB989                    | 0.3665
# BHP7067                   | VDB900                    | 0.3768
# VKJ7096                   | VDB980                    | 0.3769
# --------------------------------------------------------------------------------
# ==> Epoch 22 done in 2.4s | train_loss=2.3885  valid_loss=2.4491  valid_acc=0.00%
#
# → Starting epoch 23  (printing every 28 iters)
# [Epoch 23] iter 1/28, avg loss: 2.3432
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# VGN2263                   | QDB800                    | 0.3861
# JTW5239                   | VDB800                    | 0.3841
# JQP3182                   | QDB800                    | 0.3965
# QRR2912                   | QAB808                    | 0.3996
# PCT6590                   | VDB800                    | 0.3962
# --------------------------------------------------------------------------------
# [Epoch 23] iter 28/28, avg loss: 2.3876
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QCE9329                   | QAB7633                   | 0.3780
# SD2901V                   | QAB766                    | 0.3704
# KEN7203                   | VTT711                    | 0.4173
# BHX5241                   | QAB7663                   | 0.3704
# VFC331                    | VDT771                    | 0.3921
# --------------------------------------------------------------------------------
# ==> Epoch 23 done in 2.4s | train_loss=2.3876  valid_loss=2.4530  valid_acc=0.00%
#
# → Starting epoch 24  (printing every 28 iters)
# [Epoch 24] iter 1/28, avg loss: 2.4103
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# BLG7607                   | VCT711                    | 0.3917
# VEW8287                   | VTT111                    | 0.4367
# NEA9731                   | VCT711                    | 0.4012
# QCJ5838                   | QAA9399                   | 0.3960
# UNIMAS6119                | QAA9699                   | 0.4274
# --------------------------------------------------------------------------------
# [Epoch 24] iter 28/28, avg loss: 2.3776
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# T/J9885                   | VCT3333                   | 0.3965
# AM9232                    | VCT3333                   | 0.3887
# QBB7772                   | QAA9399                   | 0.3972
# QAR53                     | QAA9999                   | 0.4111
# JLY2201                   | QCB3399                   | 0.3850
# --------------------------------------------------------------------------------
# ==> Epoch 24 done in 2.4s | train_loss=2.3776  valid_loss=2.5046  valid_acc=0.00%
#
# → Starting epoch 25  (printing every 28 iters)
# [Epoch 25] iter 1/28, avg loss: 2.3819
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# BNG7865                   | QAB3339                   | 0.3932
# ABX8314                   | QAA3399                   | 0.4406
# NBS4847                   | QCB333                    | 0.3855
# JRG6799                   | QCB3339                   | 0.3842
# AHU7727                   | QAB3339                   | 0.3861
# --------------------------------------------------------------------------------
# [Epoch 25] iter 28/28, avg loss: 2.3709
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# SMK5                      | VC7713                    | 0.3853
# VKG5010                   | VCB703                    | 0.3828
# QKY2146                   | VCT733                    | 0.3968
# VNP3597                   | QCB909                    | 0.3740
# VNH9099                   | QAA889                    | 0.4088
# --------------------------------------------------------------------------------
# ==> Epoch 25 done in 2.4s | train_loss=2.3709  valid_loss=2.5088  valid_acc=0.00%
#
# → Starting epoch 26  (printing every 28 iters)
# [Epoch 26] iter 1/28, avg loss: 2.3965
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# VN815                     | VTT733                    | 0.3926
# KAX1199                   | VDT7333                   | 0.3819
# FC9447                    | VDN7333                   | 0.3523
# TTB1838                   | QDN8333                   | 0.3679
# JUJ7630                   | VDT7333                   | 0.3772
# --------------------------------------------------------------------------------
# [Epoch 26] iter 28/28, avg loss: 2.3786
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QAA5515N                  | QCB8899                   | 0.3850
# PGL2189                   | VCB777                    | 0.3828
# PRM41                     | VCB779                    | 0.3896
# PBW9097                   | VCB777                    | 0.3749
# T/BE110                   | VCJ777                    | 0.3947
# --------------------------------------------------------------------------------
# ==> Epoch 26 done in 2.5s | train_loss=2.3786  valid_loss=2.4623  valid_acc=0.00%
#
# → Starting epoch 27  (printing every 28 iters)
# [Epoch 27] iter 1/28, avg loss: 2.3225
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QAX6845                   | QAA9899                   | 0.3748
# NBC771                    | VCB7111                   | 0.3536
# AFM2020                   | VCB7119                   | 0.3637
# VJG3205                   | VCB7111                   | 0.3661
# WMX9993                   | QCB8199                   | 0.3523
# --------------------------------------------------------------------------------
# [Epoch 27] iter 28/28, avg loss: 2.3713
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# BRJ8996                   | QAA6699                   | 0.3793
# WUG4754                   | QCA7699                   | 0.3454
# QAR6858                   | QAA6699                   | 0.4670
# T/JA6344                  | VCT7713                   | 0.3706
# MDV8552                   | VCT7669                   | 0.3460
# --------------------------------------------------------------------------------
# ==> Epoch 27 done in 2.5s | train_loss=2.3713  valid_loss=2.4426  valid_acc=0.00%
#
# → Starting epoch 28  (printing every 28 iters)
# [Epoch 28] iter 1/28, avg loss: 2.3017
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QRS3073                   | QAA8639                   | 0.3474
# TTB1838                   | VCT7733                   | 0.3603
# JDP9718                   | VVT773                    | 0.3650
# NDH2698                   | QCA8339                   | 0.3435
# VES3744                   | VCJ7333                   | 0.3501
# --------------------------------------------------------------------------------
# [Epoch 28] iter 28/28, avg loss: 2.3485
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QC5088                    | VCB711                    | 0.3560
# VJD5050                   | VCT711                    | 0.3767
# PC8558A                   | WCB711                    | 0.3737
# QCR2878                   | QAB888                    | 0.3583
# WFW1265                   | VTT711                    | 0.3886
# --------------------------------------------------------------------------------
# ==> Epoch 28 done in 2.5s | train_loss=2.3485  valid_loss=2.7035  valid_acc=0.00%
#
# → Starting epoch 29  (printing every 28 iters)
# [Epoch 29] iter 1/28, avg loss: 2.3444
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QAA8392N                  | QAA5888                   | 0.4288
# TLW4851                   | QCB5888                   | 0.3584
# BGQ1741                   | QCB5888                   | 0.3563
# BRV1389                   | QCB5888                   | 0.3583
# BGT233                    | WCB5888                   | 0.3553
# --------------------------------------------------------------------------------
# [Epoch 29] iter 28/28, avg loss: 2.3374
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QCA6734                   | QAB6699                   | 0.3717
# W5870P                    | V77                       | 0.4352
# QTA2566                   | QAB6699                   | 0.3782
# BJM9030                   | VCB779                    | 0.3663
# JKN8193                   | QMB6699                   | 0.3573
# --------------------------------------------------------------------------------
# ==> Epoch 29 done in 2.4s | train_loss=2.3374  valid_loss=2.4614  valid_acc=0.00%
#
# → Starting epoch 30  (printing every 28 iters)
# [Epoch 30] iter 1/28, avg loss: 2.2885
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# KDT6929                   | QAA7759                   | 0.3703
# MDS7934                   | WCB7770                   | 0.3648
# JMW7452                   | VCJ7777                   | 0.3748
# WB6629Q                   | QA6759                    | 0.3599
# QKL8220                   | QAA7759                   | 0.3583
# --------------------------------------------------------------------------------
# [Epoch 30] iter 28/28, avg loss: 2.3270
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QCT7867                   | VCB758                    | 0.3601
# JKN9008                   | WDB5858                   | 0.3389
# QBB9955                   | QAB559                    | 0.3962
# KDQ4187                   | WDB555                    | 0.3492
# BKJ3569                   | QDB5858                   | 0.3402
# --------------------------------------------------------------------------------
# ==> Epoch 30 done in 2.5s | train_loss=2.3270  valid_loss=2.4870  valid_acc=0.00%
#
# → Starting epoch 31  (printing every 28 iters)
# [Epoch 31] iter 1/28, avg loss: 2.2906
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# JTU3636                   | WDB5688                   | 0.3465
# VHE7588                   | VCN5118                   | 0.3545
# QPB615                    | VCB5118                   | 0.3498
# NCH9890                   | QDB5688                   | 0.3453
# WSY5453                   | VCJ5118                   | 0.3558
# --------------------------------------------------------------------------------
# [Epoch 31] iter 28/28, avg loss: 2.3178
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QBE2772                   | VBB888                    | 0.3272
# VLU1213                   | VTT731                    | 0.3705
# ALX5554                   | VDT7333                   | 0.3571
# QCH6494                   | QAB8888                   | 0.3720
# QRS3073                   | QAB8888                   | 0.3656
# --------------------------------------------------------------------------------
# ==> Epoch 31 done in 2.5s | train_loss=2.3178  valid_loss=2.5599  valid_acc=0.00%
#
# → Starting epoch 32  (printing every 28 iters)
# [Epoch 32] iter 1/28, avg loss: 2.3370
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QPA3725                   | QAB5669                   | 0.3658
# JQP3182                   | VBB562                    | 0.3537
# WDJ9407                   | QDB5662                   | 0.3676
# JLK9805                   | JDB5662                   | 0.3750
# JRA7032                   | JDB5662                   | 0.3759
# --------------------------------------------------------------------------------
# [Epoch 32] iter 28/28, avg loss: 2.3195
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# JLX6457                   | VDH333                    | 0.3688
# JCY8064                   | VDH333                    | 0.3685
# VKR5274                   | WMB338                    | 0.3571
# MCD9708                   | VCJ333                    | 0.3744
# QM7691Q                   | QAA999                    | 0.3761
# --------------------------------------------------------------------------------
# ==> Epoch 32 done in 2.4s | train_loss=2.3195  valid_loss=2.4671  valid_acc=0.00%
#
# → Starting epoch 33  (printing every 28 iters)
# [Epoch 33] iter 1/28, avg loss: 2.2191
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# AHU7727                   | QAA6888                   | 0.3709
# QA                        | VTT771                    | 0.2978
# VNP3597                   | VCJ7888                   | 0.3614
# VAM9906                   | QAA6888                   | 0.3636
# MDJ5126                   | VCH7888                   | 0.3563
# --------------------------------------------------------------------------------
# [Epoch 33] iter 28/28, avg loss: 2.3063
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# PMQ2551                   | WCH7722                   | 0.3421
# BRJ8996                   | QCH7722                   | 0.3428
# ...
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# ADM250                    | ADM250                    | 0.8769
# BEP3409                   | BEP3409                   | 0.8973
# WC3255U                   | WC3255U                   | 0.9287
# KDS818                    | KDS818                    | 0.9501
# QAA2662Q                  | QAA2662Q                  | 0.8888
# --------------------------------------------------------------------------------
# [Epoch 490] iter 28/28, avg loss: 0.0011
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# WNH553                    | WNH553                    | 0.9508
# GOLD5564                  | GOLD5564                  | 0.9413
# VLB768                    | VLB768                    | 0.9090
# QAB2477H                  | QAB2477H                  | 0.9542
# CBF6175                   | CBF6175                   | 0.8903
# --------------------------------------------------------------------------------
# ==> Epoch 490 done in 2.4s | train_loss=0.0011  valid_loss=5.0761  valid_acc=0.00%
#
# → Starting epoch 491  (printing every 28 iters)
# [Epoch 491] iter 1/28, avg loss: 0.0014
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QAP5276                   | QAP5276                   | 0.9349
# AGX7136                   | AGX7136                   | 0.9264
# PC1811P                   | PC1811P                   | 0.9090
# JWC6011                   | JWC6011                   | 0.9523
# QKW3360                   | QKW3360                   | 0.8850
# --------------------------------------------------------------------------------
# [Epoch 491] iter 28/28, avg loss: 0.0011
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# VML1256                   | VML1256                   | 0.9149
# QM5966P                   | QM5966P                   | 0.8980
# PEJ9595                   | PEJ9595                   | 0.8838
# QAA3953V                  | QAA3953V                  | 0.8677
# QAA5191E                  | QAA5191E                  | 0.8828
# --------------------------------------------------------------------------------
# ==> Epoch 491 done in 2.4s | train_loss=0.0011  valid_loss=5.0979  valid_acc=0.00%
#
# → Starting epoch 492  (printing every 28 iters)
# [Epoch 492] iter 1/28, avg loss: 0.0008
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QAA3323X                  | QAA3323X                  | 0.9486
# T/M232                    | T/M232                    | 0.9413
# NDD5646                   | NDD5646                   | 0.9585
# PKV4279                   | PKV4279                   | 0.9484
# ALN8722                   | ALN8722                   | 0.9032
# --------------------------------------------------------------------------------
# [Epoch 492] iter 28/28, avg loss: 0.0010
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# WSA5116                   | WSA5116                   | 0.9714
# WB8444L                   | WB8444L                   | 0.9067
# VJY6189                   | VJY6189                   | 0.9047
# WFB2641                   | WFB2641                   | 0.8826
# JPC3442                   | JPC3442                   | 0.9300
# --------------------------------------------------------------------------------
# ==> Epoch 492 done in 2.4s | train_loss=0.0010  valid_loss=5.0785  valid_acc=0.00%
#
# → Starting epoch 493  (printing every 28 iters)
# [Epoch 493] iter 1/28, avg loss: 0.0010
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# PBW9097                   | PBW9097                   | 0.8910
# DFC4000                   | DFC4000                   | 0.9737
# JHC8095                   | JHC8095                   | 0.9342
# TCM3335                   | TCM3335                   | 0.9381
# QM4764C                   | QM4764C                   | 0.8521
# --------------------------------------------------------------------------------
# [Epoch 493] iter 28/28, avg loss: 0.0011
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# VKG5010                   | VKG5010                   | 0.9681
# WD8974A                   | WD8974A                   | 0.8652
# JVH1978                   | JVH1978                   | 0.9414
# PC8558A                   | PC8558A                   | 0.8892
# QAA8698P                  | QAA8698P                  | 0.9519
# --------------------------------------------------------------------------------
# ==> Epoch 493 done in 2.5s | train_loss=0.0011  valid_loss=5.0828  valid_acc=0.40%
#
# → Starting epoch 494  (printing every 28 iters)
# [Epoch 494] iter 1/28, avg loss: 0.0010
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# JVD7333                   | JVD7333                   | 0.9387
# QAB401E                   | QAB401E                   | 0.9424
# JUV9528                   | JUV9528                   | 0.9573
# BNY4363                   | BNY4363                   | 0.8669
# JKN9008                   | JKN9008                   | 0.9681
# --------------------------------------------------------------------------------
# [Epoch 494] iter 28/28, avg loss: 0.0010
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# WXX2093                   | WXX2093                   | 0.9720
# RC9863                    | RC9863                    | 0.9346
# JWY375                    | JWY375                    | 0.9298
# SK1636C                   | SK1636C                   | 0.8588
# JXL9880                   | JXL9880                   | 0.8630
# --------------------------------------------------------------------------------
# ==> Epoch 494 done in 2.4s | train_loss=0.0010  valid_loss=5.0726  valid_acc=0.40%
#
# → Starting epoch 495  (printing every 28 iters)
# [Epoch 495] iter 1/28, avg loss: 0.0016
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# MCV1838                   | MCV1838                   | 0.8963
# QAA7228U                  | QAA7228U                  | 0.8812
# PRF6163                   | PRF6163                   | 0.8929
# TBT9322                   | TBT9322                   | 0.9584
# BNB8655                   | BNB8655                   | 0.8888
# --------------------------------------------------------------------------------
# [Epoch 495] iter 28/28, avg loss: 0.0011
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# VHB3371                   | VHB3371                   | 0.9440
# BPS7534                   | BPS7534                   | 0.8982
# MADANI7776                | MADANI7776                | 0.8516
# WDQ1009                   | WDQ1009                   | 0.9205
# BQU9918                   | BQU9918                   | 0.9103
# --------------------------------------------------------------------------------
# ==> Epoch 495 done in 2.5s | train_loss=0.0011  valid_loss=5.0692  valid_acc=0.40%
#
# → Starting epoch 496  (printing every 28 iters)
# [Epoch 496] iter 1/28, avg loss: 0.0011
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# TCA7789                   | TCA7789                   | 0.9582
# ALN8722                   | ALN8722                   | 0.8984
# QCQ3562                   | QCQ3562                   | 0.9204
# JDS809                    | JDS809                    | 0.9495
# QAB2477H                  | QAB2477H                  | 0.9538
# --------------------------------------------------------------------------------
# [Epoch 496] iter 28/28, avg loss: 0.0011
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# ZC3873                    | ZC3873                    | 0.9038
# QM7691Q                   | QM7691Q                   | 0.9337
# TBY9929                   | TBY9929                   | 0.9357
# SJG7119                   | SJG7119                   | 0.9676
# FC9447                    | FC9447                    | 0.9533
# --------------------------------------------------------------------------------
# ==> Epoch 496 done in 2.5s | train_loss=0.0011  valid_loss=5.0868  valid_acc=0.40%
#
# → Starting epoch 497  (printing every 28 iters)
# [Epoch 497] iter 1/28, avg loss: 0.0013
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# VGE3354                   | VGE3354                   | 0.9295
# PCT6590                   | PCT6590                   | 0.9164
# M1407M                    | M1407M                    | 0.8303
# WEH8092                   | WEH8092                   | 0.8648
# WC4922X                   | WC4922X                   | 0.8814
# --------------------------------------------------------------------------------
# [Epoch 497] iter 28/28, avg loss: 0.0011
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# WMR8630                   | WMR8630                   | 0.9430
# W5384D                    | W5384D                    | 0.8451
# QAA6493D                  | QAA6493D                  | 0.9166
# QRK6337                   | QRK6337                   | 0.9236
# QPA3725                   | QPA3725                   | 0.9322
# --------------------------------------------------------------------------------
# ==> Epoch 497 done in 2.5s | train_loss=0.0011  valid_loss=5.0865  valid_acc=0.40%
#
# → Starting epoch 498  (printing every 28 iters)
# [Epoch 498] iter 1/28, avg loss: 0.0011
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QTV6692                   | QTV6692                   | 0.9646
# MAM6063                   | MAM6063                   | 0.9576
# JWY375                    | JWY375                    | 0.9178
# QTT7328                   | QTT7328                   | 0.9147
# WFB2641                   | WFB2641                   | 0.9312
# --------------------------------------------------------------------------------
# [Epoch 498] iter 28/28, avg loss: 0.0011
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# WNB6877                   | WNB6877                   | 0.8943
# QS2582P                   | QS2582P                   | 0.8900
# JWK5515                   | JWK5515                   | 0.9426
# PZ171M                    | PZ171M                    | 0.8176
# QM9C                      | QM9C                      | 0.9030
# --------------------------------------------------------------------------------
# ==> Epoch 498 done in 2.5s | train_loss=0.0011  valid_loss=5.1408  valid_acc=0.40%
#
# → Starting epoch 499  (printing every 28 iters)
# [Epoch 499] iter 1/28, avg loss: 0.0009
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# VJG3205                   | VJG3205                   | 0.8944
# WUV9209                   | WUV9209                   | 0.9270
# VKJ7096                   | VKJ7096                   | 0.9491
# UM2356                    | UM2356                    | 0.9482
# QBB9955                   | QBB9955                   | 0.9653
# --------------------------------------------------------------------------------
# [Epoch 499] iter 28/28, avg loss: 0.0010
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# VNG8061                   | VNG8061                   | 0.9141
# SJG7119                   | SJG7119                   | 0.9186
# WUP3371                   | WUP3371                   | 0.9420
# 437B                      | 437B                      | 0.8095
# KP3300Q                   | KP3300Q                   | 0.9303
# --------------------------------------------------------------------------------
# ==> Epoch 499 done in 2.5s | train_loss=0.0010  valid_loss=5.1008  valid_acc=0.40%
#
# → Starting epoch 500  (printing every 28 iters)
# [Epoch 500] iter 1/28, avg loss: 0.0008
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# AKS8887                   | AKS8887                   | 0.8872
# VAW902                    | VAW902                    | 0.9240
# W/TP3358                  | W/TP3358                  | 0.9044
# WXT2433                   | WXT2433                   | 0.9453
# FG8999                    | FG8999                    | 0.9365
# --------------------------------------------------------------------------------
# [Epoch 500] iter 28/28, avg loss: 0.0011
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# VJE3434                   | VJE3434                   | 0.9231
# T/BE110                   | T/BE110                   | 0.9345
# PHA6245                   | PHA6245                   | 0.9705
# QCE9329                   | QCE9329                   | 0.8743
# VM6611                    | VM6611                    | 0.8803
# --------------------------------------------------------------------------------
# ==> Epoch 500 done in 2.4s | train_loss=0.0011  valid_loss=5.1088  valid_acc=0.00%

# %%
clean_history = {
  'epoch':      history['epoch'],
  'train_loss': [x.cpu().item() if hasattr(x, 'cpu') else x for x in history['train_loss']],
  'val_loss':   [x.cpu().item() if hasattr(x, 'cpu') else x for x in history['val_loss']],
  'val_acc':    [x.cpu().item() if hasattr(x, 'cpu') else x for x in history['val_acc']],
}
df = pd.DataFrame(clean_history)
display(df)

plt.figure()
plt.plot(df['epoch'], df['train_loss'], label='Train Loss')
plt.plot(df['epoch'], df['val_loss'],   label='Val Loss')
plt.xlabel('Epoch'); plt.ylabel('Loss'); plt.legend()
plt.title('Loss over Epochs')
plt.show()

plt.figure()
plt.plot(df['epoch'], df['val_acc'],   label='Val Accuracy')
plt.xlabel('Epoch'); plt.ylabel('Accuracy (%)'); plt.legend()
plt.title('Val Accuracy over Epochs')
plt.show()
# Out:
#      epoch  train_loss  val_loss    val_acc
# 0        1    3.205925  2.875817   0.000000
# 1        2    2.797049  2.708875   0.000000
# 2        3    2.468144  2.382759   0.000000
# 3        4    2.226118  2.158576   0.000000
# 4        5    2.030336  2.303679   0.000000
# ..     ...         ...       ...        ...
# 495    496    0.000099  1.228439  61.111111
# 496    497    0.000097  1.224077  61.507937
# 497    498    0.000102  1.225003  61.111111
# 498    499    0.000100  1.222711  61.507937
# 499    500    0.000101  1.219639  61.904762
#
# [500 rows x 4 columns]

# %%
# # ─── Cell 9: ONNX export via isolated inference head ─────────────────────────
# import torch

# class CRNNInference(torch.nn.Module):
#     def __init__(self, crnn, max_len):
#         super().__init__()
#         # use exactly the names printed out by your inspection
#         self.Transformation     = crnn.Transformation
#         self.FeatureExtraction = crnn.FeatureExtraction
#         self.AdaptiveAvgPool    = crnn.AdaptiveAvgPool
#         self.SequenceModeling   = crnn.SequenceModeling
#         self.Prediction         = crnn.Prediction
#         self.max_len           = max_len
#         # adjust this if your converter stores start-token under a different key
#         self.start_id          = crnn.converter.dict['[GO]']

#     def forward(self, image):
#         # 1) Spatial‐transformer + feature CNN
#         x = self.Transformation(image)                     # [B, C, H, W]
#         x = self.FeatureExtraction(x)                      # [B, C, H, W]

#         # 2) Pool down height to 1
#         x = self.AdaptiveAvgPool(x)                        # [B, C, 1, W]
#         x = x.squeeze(2)                                   # [B, C, W]
#         x = x.permute(0, 2, 1)                             # [B, W, C]

#         # 3) 2‐layer BiLSTM
#         contextual = self.SequenceModeling(x)              # [B, W, hidden]

#         # 4) Dummy “[GO]” token vector
#         B = contextual.size(0)
#         dummy_text = torch.full(
#             (B,),
#             self.start_id,
#             dtype=torch.long,
#             device=image.device
#         )  # shape [B]

#         # 5) Attention decoder (inference path)
#         return self.Prediction(
#             batch_H           = contextual,
#             text              = dummy_text,
#             is_train          = False,
#             batch_max_length  = self.max_len
#         )

# # Wrap and export
# inference_model = CRNNInference(model, BATCH_MAX_LENGTH).eval()
# dummy_img       = torch.randn(1, INPUT_CHANNEL, IMG_HEIGHT, IMG_WIDTH, device=device)

# torch.onnx.export(
#     inference_model,
#     dummy_img,
#     "best_attention_crnn.onnx",
#     input_names   = ['image'],
#     output_names  = ['logits'],
#     dynamic_axes  = {
#         'image':  {0: 'batch'},
#         'logits': {0: 'batch', 1: 'time'}
#     },
#     opset_version = 13,
# )

# print("✅ Exported best_attention_crnn.onnx")

# %% [markdown]
# # DUMP

# %%
# # ─── cell 6: attention‐based training loop ──────────────────────────────────────
# for epoch in range(1, NUM_EPOCHS+1):
#     print(f"→ Starting epoch {epoch}  (printing every {PRINT_EVERY} iters)")
#     model.train()
#     epoch_loss = Averager()
#     start      = time.time()

#     for i, (images, texts) in enumerate(train_loader, 1):
#         images = images.to(device)

#         # encode with [GO] & [s]; also get lengths
#         text, length = converter.encode(texts, batch_max_length=BATCH_MAX_LENGTH)
#         text_input  = text[:, :-1].to(device)   # drop final [s]
#         text_target = text[:,  1:].to(device)   # everything after [GO]

#         # forward + loss
#         preds = model(images,
#                       text=text_input,
#                       is_train=True,
#                       batch_max_length=BATCH_MAX_LENGTH)  # [B, S, C]
#         B, S, C = preds.size()
#         loss = criterion(
#             preds.view(B * S, C),
#             text_target.contiguous().view(B * S)
#         )

#         optimizer.zero_grad()
#         loss.backward()
#         torch.nn.utils.clip_grad_norm_(model.parameters(), 5)
#         optimizer.step()
#         epoch_loss.add(loss)

#         if i % PRINT_EVERY == 0 or i == 1:
#             print(f"[Epoch {epoch}] iter {i}/{len(train_loader)}, avg loss: {epoch_loss.val():.4f}", flush=True)

#             # quick greedy‐decode
#             with torch.no_grad():
#                 probs        = preds.softmax(2)           # [B, S, C]
#                 max_vals, max_inds = probs.max(2)         # [B, S]
#                 pred_strs    = converter.decode(max_inds, length)
#                 pred_strs    = [s.split('[s]')[0] for s in pred_strs]

#             # print a mini‐table
#             print("-" * 80)
#             print(f"{'Ground Truth':25s} | {'Prediction':25s} | AvgConfidence")
#             print("-" * 80)
#             for gt, pr, conf_seq in zip(texts[:5], pred_strs[:5], max_vals[:5]):
#                 conf = conf_seq.mean().item()
#                 print(f"{gt:25s} | {pr:25s} | {conf:0.4f}")
#             print("-" * 80)

#     # end‐of‐epoch validation
#     val_loss, val_acc = validate(model, val_loader)
#     elapsed = time.time() - start
#     print(f"==> Epoch {epoch} done in {elapsed:.1f}s | "
#           f"train_loss={epoch_loss.val():.4f}"
#           f"  valid_loss={val_loss:.4f}  valid_acc={val_acc:.2f}%\n")
