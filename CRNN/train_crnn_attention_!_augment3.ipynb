# %%
# cell 1
import os
import time
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
import matplotlib.pyplot as plt
import pandas as pd
import random
import numpy as np

from config import (IMG_HEIGHT, IMG_WIDTH, NUM_FIDUCIAL,
                    INPUT_CHANNEL, OUTPUT_CHANNEL, HIDDEN_SIZE,
                    CHARACTERS, MAX_LABEL_LENGTH)
from dataset import LmdbDataset, AlignCollate
# from utils import CTCLabelConverter, Averager
from utils import AttnLabelConverter, Averager
from model import CRNN
from PIL import Image
import torchvision.transforms as T

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print("Running on", device)
# Out:
# Running on cuda

# %%
# ─── cell 0: reproducibility ────────────────────────────────────────────────
SEED = 300188
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)

# Make cuDNN deterministic (slower but reproducible)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

print(f"All seeds set to {SEED}, cudnn.deterministic={torch.backends.cudnn.deterministic}")
# Out:
# All seeds set to 300188, cudnn.deterministic=True

# %% [markdown]
# -------- Added Augmentation ---------

# %%
augment_pipeline = T.Compose([
    # rotate up to ±15°
    T.RandomRotation(15, expand=False, fill=255),
    # slight brightness jitter
    T.ColorJitter(brightness=0.2),
    # add gaussian noise in [0,1], then back to uint8
    T.Lambda(lambda img: (
        Image.fromarray(
            (
                np.clip(
                    np.array(img).astype(np.float32) / 255.0
                    + np.random.normal(0, 0.02, img.size[::-1]),
                    0.0, 1.0
                ) * 255.0
            ).astype(np.uint8)
        )
    )),
])

# %%
class AugmentedLmdbDataset(Dataset):
    def __init__(self, base_dataset, augment, num_aug=2):
        self.base     = base_dataset
        self.augment  = augment
        self.num_aug  = num_aug
        self.orig_len = len(base_dataset)

    def __len__(self):
        # each original plus `num_aug` variants
        return self.orig_len * (1 + self.num_aug)

    def __getitem__(self, idx):
        if idx < self.orig_len:
            # raw sample
            return self.base[idx]
        # augmented sample
        base_idx = idx % self.orig_len
        img, label = self.base[base_idx]
        return self.augment(img), label

# %% [markdown]
# -------- Augment End --------

# %%
# cell 2
# paths to your LMDBs
train_lmdb = "v4_lmdb_data_!/train"
val_lmdb   = "v4_lmdb_data_!/val"

# instantiate datasets
train_dataset = LmdbDataset(train_lmdb)
val_dataset   = LmdbDataset(val_lmdb)

# augmentations
NUM_AUG = 2   # → total factor = 1 (orig) + 2 aug = ×3
aug_train_dataset = AugmentedLmdbDataset(train_dataset, augment_pipeline, num_aug=NUM_AUG)
print(f"Original train images: {len(train_dataset)}")
print(f"After augmentation:    {len(aug_train_dataset)}  (×{1+NUM_AUG} total samples)")

# collate_fn resizes + normalizes
collate_fn = AlignCollate(
    imgH=IMG_HEIGHT, imgW=IMG_WIDTH, keep_ratio_with_pad=False
)

# loaders
BATCH_SIZE = 32
train_loader = DataLoader(
    aug_train_dataset, batch_size=BATCH_SIZE, shuffle=True,
    num_workers=0, collate_fn=collate_fn, pin_memory=True
)
val_loader = DataLoader(
    val_dataset, batch_size=BATCH_SIZE, shuffle=False,
    num_workers=0, collate_fn=collate_fn, pin_memory=True
)

print(f"{len(aug_train_dataset)} train / {len(val_dataset)} val samples")
# Out:
# Loaded 1372 valid samples from v4_lmdb_data_!/train
# Loaded 343 valid samples from v4_lmdb_data_!/val
# Original train images: 1372
# After augmentation:    4116  (×3 total samples)
# 4116 train / 343 val samples

# %%
converter   = AttnLabelConverter(CHARACTERS)
num_classes = len(converter.character)   # includes [GO] and [s]

model = CRNN(
    IMG_HEIGHT,      # imgH
    IMG_WIDTH,       # imgW
    INPUT_CHANNEL,   # input_channel
    OUTPUT_CHANNEL,  # output_channel
    HIDDEN_SIZE,     # hidden_size
    num_classes,     # num_classes (with GO/s)
    True,            # use_attention
    NUM_FIDUCIAL     # num_fiducial
).to(device)

criterion = nn.CrossEntropyLoss(ignore_index=0).to(device)
optimizer = optim.Adadelta(model.parameters(), lr=1.0)

# %%
# ─── cell 4: validate (Attention) ─────────────────────────────────────────────
NUM_EPOCHS       = 500
PRINT_EVERY      = len(train_dataset) // BATCH_SIZE + 1
PATIENCE       = 100          # stop if no val_acc ↑ for 50 epochs

def validate(model, loader):
    model.eval()
    avg_loss = Averager()
    correct, total = 0, 0

    with torch.no_grad():
        for images, texts in loader:
            images = images.to(device)

            # encode full text → shape [B, L+1], plus lengths
            text, length = converter.encode(texts, batch_max_length=MAX_LABEL_LENGTH)
            text_input  = text[:, :-1].to(device)  # drop final [s]
            text_target = text[:,  1:].to(device)  # everything after [GO]

            # forward
            preds = model(images, text_input, is_train=False,
                          batch_max_length=MAX_LABEL_LENGTH)
            B, S, C = preds.size()

            # cross‐entropy over (B×S) predictions
            loss = criterion(
                preds.view(B * S, C),
                text_target.contiguous().view(B * S)
            )
            avg_loss.add(loss)

            # greedy decode
            _, pred_inds = preds.max(2)                   # [B, S]
            pred_strs = converter.decode(pred_inds, length)  # pass length

            # strip off anything after the "[s]" token
            pred_strs = [s.split('[s]')[0] for s in pred_strs]

            total += len(texts)
            correct += sum(p == g for p, g in zip(pred_strs, texts))

    acc = correct / total * 100
    return avg_loss.val(), acc

# %%
# ─── cell 5: load pretrained CTC weights (skip old Prediction head) ────────────

from collections import OrderedDict

orig      = torch.load("pretrained_model/TPS-ResNet-BiLSTM-Attn.pth", map_location=device)
# strip off the "module." prefix if you wrapped in DataParallel
stripped  = OrderedDict((k[len("module."):], v)
                        for k, v in orig.items()
                        if k.startswith("module."))

own = model.state_dict()
for k, v in stripped.items():
    # skip the old attention head entirely
    if k.startswith("Prediction."):
        continue
    # only overwrite if shapes match
    if k in own and v.size() == own[k].size():
        own[k] = v

model.load_state_dict(own)
print("✅ Loaded pretrained Attn weights")
# Out:
# ✅ Loaded pretrained Attn weights

# %%
# ─── Cell 6: training w/ history, best‐model saving + EARLY STOPPING ───

# hyper‑params
best_val_acc   = 0.0
history        = {'epoch': [], 'train_loss': [], 'val_loss': [], 'val_acc': []}

patience_cnt   = 0           # how many epochs since last improvement

for epoch in range(1, NUM_EPOCHS+1):
    print(f"→ Starting epoch {epoch}  (printing every {PRINT_EVERY} iters)")
    model.train()
    epoch_loss = Averager()
    start = time.time()

    # ─── training ──────────────────────────────────────────────────────────
    for i, (images, texts) in enumerate(train_loader, 1):
        images = images.to(device)

        text, length   = converter.encode(texts, batch_max_length=MAX_LABEL_LENGTH)
        text_input     = text[:, :-1].to(device)
        text_target    = text[:,  1:].to(device)

        preds = model(
            images,
            text=text_input,
            is_train=True,
            batch_max_length=MAX_LABEL_LENGTH
        )  # [B, S, C]
        B, S, C = preds.size()
        loss = criterion(
            preds.view(B * S, C),
            text_target.contiguous().view(B * S)
        )

        optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 5)
        optimizer.step()
        epoch_loss.add(loss)

        # mini‐table prints
        if i % PRINT_EVERY == 0:
            print(f"[Epoch {epoch}] iter {i}/{len(train_loader)}, avg loss: {epoch_loss.val():.4f}", flush=True)
            with torch.no_grad():
                probs     = preds.softmax(2)
                max_vals, max_inds = probs.max(2)
                pred_strs = converter.decode(max_inds, length)
                pred_strs = [s.split('[s]')[0] for s in pred_strs]

            print("-" * 80)
            print(f"{'Ground Truth':25s} | {'Prediction':25s} | AvgConfidence")
            print("-" * 80)
            for gt, pr, conf_seq in zip(texts[:5], pred_strs[:5], max_vals[:5]):
                conf = conf_seq.mean().item()
                print(f"{gt:25s} | {pr:25s} | {conf_seq.mean().item():.4f}")
            print("-" * 80)

    # ─── validation ────────────────────────────────────────────────────────
    val_loss, val_acc = validate(model, val_loader)
    elapsed   = time.time() - start
    train_l   = epoch_loss.val()
    print(f"==> Epoch {epoch} done in {elapsed:.1f}s | "
          f"train_loss={train_l:.4f}  valid_loss={val_loss:.4f}  valid_acc={val_acc:.2f}%\n")

    # ─── record history ───────────────────────────────────────────────────
    history['epoch'].append(epoch)
    history['train_loss'].append(train_l)
    history['val_loss'].append(val_loss)
    history['val_acc'].append(val_acc)

    # ─── best‑model tracking & early‑stopping logic ───────────────────────
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        torch.save(model.state_dict(), "best_attention_crnn_augment3.pth")
        print(f"💾 New best model saved (epoch {epoch}, val_acc={val_acc:.2f}%)\n")
        patience_cnt = 0                          # reset counter
    else:
        patience_cnt += 1
        print(f"no improvement for {patience_cnt}/{PATIENCE} epochs\n")
        if patience_cnt >= PATIENCE:
            print(f"🔚 Early stopping: val_acc hasn't improved for {PATIENCE} epochs.")
            break
# Out:
# → Starting epoch 1  (printing every 43 iters)
# [Epoch 1] iter 43/129, avg loss: 3.1237
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QAA!4673S                 | Q!!3                      | 0.2880
# PJN5826                   | QQ888                     | 0.2579
# QAA!8383R                 | QA888                     | 0.2756
# MY!3045                   | Q!!!                      | 0.2811
# VBV198                    | Q999                      | 0.2708
# --------------------------------------------------------------------------------
# [Epoch 1] iter 86/129, avg loss: 2.8347
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# VJM4722                   | QAA77                     | 0.4632
# NDN3779                   | QQ7777                    | 0.4574
# TCD!6404                  | QAA4444                   | 0.3396
# VNL9999                   | Q99999999999999999999     | 0.5764
# AFB9825                   | QQ888                     | 0.5509
# --------------------------------------------------------------------------------
# [Epoch 1] iter 129/129, avg loss: 2.6144
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# T/J!9885                  | QW!!888                   | 0.3667
# QKM!9995                  | QC!9999                   | 0.3878
# WFG!4626                  | QC!!6666                  | 0.4416
# T/BD!1513                 | QC!!555                   | 0.3503
# JQL3221                   | QA3322                    | 0.3996
# --------------------------------------------------------------------------------
# ==> Epoch 1 done in 10.2s | train_loss=2.6144  valid_loss=1.9493  valid_acc=0.00%
#
# no improvement for 1/100 epochs
#
# → Starting epoch 2  (printing every 43 iters)
# [Epoch 2] iter 43/129, avg loss: 1.8843
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# AHA3878                   | QAA4888                   | 0.5138
# SD2367N                   | QD2226                    | 0.4453
# WQP1991                   | QQ99999                   | 0.4247
# QDB!448                   | VKK!4444                  | 0.4625
# WYX8694                   | WWL8844                   | 0.4615
# --------------------------------------------------------------------------------
# [Epoch 2] iter 86/129, avg loss: 1.7608
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QRT!99                    | QA!!99                    | 0.4233
# PMT5916                   | MMM911                    | 0.5007
# WGC!5600                  | VM!5500                   | 0.4799
# ALN!8722                  | VC!!822                   | 0.4721
# ANB!9161                  | QA!!911                   | 0.5012
# --------------------------------------------------------------------------------
# [Epoch 2] iter 129/129, avg loss: 1.5971
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# SD288V                    | SS288                     | 0.6029
# NDN4403                   | NNN440                    | 0.7105
# MW2567                    | MW2677                    | 0.6214
# QM1252K                   | QM122                     | 0.5165
# PC1811P                   | PC1111                    | 0.6816
# --------------------------------------------------------------------------------
# ==> Epoch 2 done in 9.6s | train_loss=1.5971  valid_loss=1.0697  valid_acc=3.21%
#
# 💾 New best model saved (epoch 2, val_acc=3.21%)
#
# → Starting epoch 3  (printing every 43 iters)
# [Epoch 3] iter 43/129, avg loss: 1.0432
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# KDT6929                   | KDT6999                   | 0.7307
# JVB!7580                  | VTN!7500                  | 0.5783
# WA!7920W                  | TB220                     | 0.6584
# QAA!9328G                 | QAA!328                   | 0.5957
# QS!6618B                  | QAG!6688                  | 0.5576
# --------------------------------------------------------------------------------
# [Epoch 3] iter 86/129, avg loss: 0.9384
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QCE1128                   | QCE118                    | 0.8311
# QRN!3728                  | QCC!379                   | 0.5992
# WWN1840                   | WWN840                    | 0.7371
# PQS5137                   | PQS137                    | 0.6759
# JXL9880                   | JXL880                    | 0.8102
# --------------------------------------------------------------------------------
# [Epoch 3] iter 129/129, avg loss: 0.8584
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# BEP3409                   | BEP3499                   | 0.7306
# QS3284P                   | QS3284P                   | 0.7169
# QAB7672J                  | QAB7772                   | 0.6824
# AHN!1732                  | QAN!7722                  | 0.5632
# WYX8694                   | WYX8694                   | 0.7137
# --------------------------------------------------------------------------------
# ==> Epoch 3 done in 9.3s | train_loss=0.8584  valid_loss=0.7187  valid_acc=40.52%
#
# 💾 New best model saved (epoch 3, val_acc=40.52%)
#
# → Starting epoch 4  (printing every 43 iters)
# [Epoch 4] iter 43/129, avg loss: 0.6035
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# VJM4722                   | VJM4722                   | 0.8722
# QAA2705N                  | QAA2705                   | 0.8754
# VNH9099                   | VNH9099                   | 0.9166
# ALX1666                   | ALX1666                   | 0.9106
# AEE7918                   | AEE7918                   | 0.9218
# --------------------------------------------------------------------------------
# [Epoch 4] iter 86/129, avg loss: 0.5287
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QS2878F                   | QS2878F                   | 0.8731
# W6916B                    | WW918B                    | 0.5946
# BPL7211                   | BPL7211                   | 0.9165
# QAA3827W                  | QAA3827                   | 0.9065
# MBP5604                   | MBP5604                   | 0.9341
# --------------------------------------------------------------------------------
# [Epoch 4] iter 129/129, avg loss: 0.5293
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QAP6228                   | QAP6229                   | 0.9309
# BMW8953                   | BMW8953                   | 0.9099
# NAE2377                   | NAE2377                   | 0.9331
# QAX6845                   | QAX6845                   | 0.9580
# JXP!4469                  | VDX!4469                  | 0.7345
# --------------------------------------------------------------------------------
# ==> Epoch 4 done in 9.2s | train_loss=0.5293  valid_loss=0.5428  valid_acc=61.22%
#
# 💾 New best model saved (epoch 4, val_acc=61.22%)
#
# → Starting epoch 5  (printing every 43 iters)
# [Epoch 5] iter 43/129, avg loss: 0.4490
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# WSJ8268                   | WSJ8268                   | 0.9454
# QAA8598S                  | QAA8598S                  | 0.9465
# QAB!8977J                 | QAB!8977                  | 0.7223
# VFN!701                   | VVV!700                   | 0.7575
# PPK9573                   | PPK9573                   | 0.9510
# --------------------------------------------------------------------------------
# [Epoch 5] iter 86/129, avg loss: 0.4283
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QRR!5692                  | QAA!5992                  | 0.6823
# QKN!6026                  | QAA!8026                  | 0.6542
# CCW!3760                  | WCW!3760                  | 0.6874
# QCH2454                   | QCH2454                   | 0.9395
# TBY9929                   | TBV9929                   | 0.9122
# --------------------------------------------------------------------------------
# [Epoch 5] iter 129/129, avg loss: 0.4084
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QCF847                    | QCF847                    | 0.9517
# QAM1319                   | QAM1119                   | 0.9034
# K1688Q                    | K1688Q                    | 0.8748
# HQ2186                    | HQ2186                    | 0.8545
# MDH7007                   | MDH7007                   | 0.9622
# --------------------------------------------------------------------------------
# ==> Epoch 5 done in 9.5s | train_loss=0.4084  valid_loss=0.5133  valid_acc=64.43%
#
# 💾 New best model saved (epoch 5, val_acc=64.43%)
#
# → Starting epoch 6  (printing every 43 iters)
# [Epoch 6] iter 43/129, avg loss: 0.4190
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# T/JA213                   | T/JA213                   | 0.9491
# SMH1061                   | SMH1061                   | 0.9148
# VKR!5274                  | VKV!5274                  | 0.8020
# SK3694F                   | SK3694F                   | 0.9700
# QAH1581                   | QAH1581                   | 0.9266
# --------------------------------------------------------------------------------
# [Epoch 6] iter 86/129, avg loss: 0.3927
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# ANT8883                   | ANT8883                   | 0.9769
# PJS1739                   | PJS1738                   | 0.9280
# VTQ1924                   | VDG1924                   | 0.9446
# RT9009                    | RT9009                    | 0.9429
# VHG1732                   | VHG1732                   | 0.9489
# --------------------------------------------------------------------------------
# [Epoch 6] iter 129/129, avg loss: 0.3459
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# PNV!4846                  | SDD!4846                  | 0.7745
# QAA!4494H                 | QAA!4494H                 | 0.8738
# TAE2798                   | TAE2798                   | 0.9809
# WXM1116                   | WXM1116                   | 0.9691
# WA1414L                   | WA1414L                   | 0.9138
# --------------------------------------------------------------------------------
# ==> Epoch 6 done in 9.4s | train_loss=0.3459  valid_loss=0.4662  valid_acc=66.47%
#
# 💾 New best model saved (epoch 6, val_acc=66.47%)
#
# → Starting epoch 7  (printing every 43 iters)
# [Epoch 7] iter 43/129, avg loss: 0.2880
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QS2582P                   | QS2582P                   | 0.9749
# JQL3221                   | JQL3221                   | 0.9363
# QMW2233                   | QMW2233                   | 0.9634
# VNQ2521                   | VNQ2521                   | 0.9687
# NDP9388                   | NDP9388                   | 0.9605
# --------------------------------------------------------------------------------
# [Epoch 7] iter 86/129, avg loss: 0.2426
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QCR2878                   | QCR2878                   | 0.9801
# JV271                     | JV271                     | 0.8997
# QKL88                     | QKL88                     | 0.9651
# QS4848D                   | QS4848DD                  | 0.9764
# VJA520                    | VJA520                    | 0.9585
# --------------------------------------------------------------------------------
# [Epoch 7] iter 129/129, avg loss: 0.2495
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# WFX7807                   | WFX7807                   | 0.9678
# AMC!5652                  | MCM!5652                  | 0.7955
# JLY2201                   | JLY2201                   | 0.9141
# KDQ4187                   | KDQ4187                   | 0.9460
# QCQ3562                   | QCQ3562                   | 0.9746
# --------------------------------------------------------------------------------
# ==> Epoch 7 done in 9.3s | train_loss=0.2495  valid_loss=0.4573  valid_acc=66.18%
#
# no improvement for 1/100 epochs
#
# → Starting epoch 8  (printing every 43 iters)
# [Epoch 8] iter 43/129, avg loss: 0.2350
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# VFS9098                   | VFS9098                   | 0.9744
# QAH7520                   | QAH7520                   | 0.9542
# DDM8378                   | QQM8378                   | 0.9107
# WC178M                    | WC178M                    | 0.9438
# SWM7576                   | SWM7576                   | 0.9224
# --------------------------------------------------------------------------------
# [Epoch 8] iter 86/129, avg loss: 0.2146
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QAA!9831T                 | QAA!9831T                 | 0.8701
# QM!155J                   | QMM!555J                  | 0.7881
# QAA5515N                  | QAA5515N                  | 0.9571
# BDA8389                   | BDA8389                   | 0.8848
# ANM3637                   | ANM3637                   | 0.9924
# --------------------------------------------------------------------------------
# [Epoch 8] iter 129/129, avg loss: 0.1955
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# NDN3779                   | NDN3779                   | 0.9555
# QAA6595Q                  | QAA6595Q                  | 0.9860
# QAR6858                   | QAR6858                   | 0.9733
# VKB9657                   | VKB9657                   | 0.9955
# RW6398                    | RW6398                    | 0.9343
# --------------------------------------------------------------------------------
# ==> Epoch 8 done in 9.2s | train_loss=0.1955  valid_loss=0.4740  valid_acc=60.93%
#
# no improvement for 2/100 epochs
#
# → Starting epoch 9  (printing every 43 iters)
# [Epoch 9] iter 43/129, avg loss: 0.1888
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# VJR!1999                  | JJG!1999                  | 0.8637
# QAR6858                   | QAR6858                   | 0.9615
# QAR2857                   | QAR2857                   | 0.9768
# QTP9129                   | QTP9129                   | 0.9822
# QRN!8598                  | QCN!6598                  | 0.7217
# --------------------------------------------------------------------------------
# [Epoch 9] iter 86/129, avg loss: 0.2083
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QLB797                    | QLB797                    | 0.9349
# NAP4617                   | NAP4617                   | 0.9514
# QKU7969                   | QKU7969                   | 0.9381
# JTF3425                   | JTF3425                   | 0.9831
# WLC9954                   | WLC9954                   | 0.9697
# --------------------------------------------------------------------------------
# [Epoch 9] iter 129/129, avg loss: 0.1939
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QAA!8383R                 | QAA!8383R                 | 0.9696
# T/N4541                   | T/N4541                   | 0.9267
# QCS!8822                  | QCS!8822                  | 0.8224
# QM9779R                   | QM9779R                   | 0.9777
# NCH9890                   | NCH9890                   | 0.9646
# --------------------------------------------------------------------------------
# ==> Epoch 9 done in 9.6s | train_loss=0.1939  valid_loss=0.3933  valid_acc=66.76%
#
# 💾 New best model saved (epoch 9, val_acc=66.76%)
#
# → Starting epoch 10  (printing every 43 iters)
# [Epoch 10] iter 43/129, avg loss: 0.1132
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QRR9945                   | QRR9945                   | 0.9900
# QAB9218                   | QAB9218                   | 0.9659
# QAA8951J                  | QAA8951J                  | 0.9468
# SD2367N                   | SD2367N                   | 0.9856
# SYP9169                   | SYP9169                   | 0.9893
# --------------------------------------------------------------------------------
# [Epoch 10] iter 86/129, avg loss: 0.1014
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# 426                       | 426                       | 0.9734
# QCS7175                   | QCS7173                   | 0.9467
# VEW8287                   | VEW8287                   | 0.9866
# JWE!3023                  | WWE!3023                  | 0.8608
# PLX8764                   | PLX8164                   | 0.8578
# --------------------------------------------------------------------------------
# [Epoch 10] iter 129/129, avg loss: 0.0946
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# ABX8314                   | ABX8314                   | 0.9775
# QAA7166M                  | QAA7166M                  | 0.9689
# QTE!4766                  | QTF!4766                  | 0.8700
# RC!9863                   | RDT!9663                  | 0.7718
# VLB768                    | VLB768                    | 0.9956
# --------------------------------------------------------------------------------
# ==> Epoch 10 done in 9.5s | train_loss=0.0946  valid_loss=0.5134  valid_acc=69.39%
#
# 💾 New best model saved (epoch 10, val_acc=69.39%)
#
# → Starting epoch 11  (printing every 43 iters)
# [Epoch 11] iter 43/129, avg loss: 0.0810
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QS8591M                   | QS8591K                   | 0.9362
# T/BB578                   | T/BB578                   | 0.9542
# VKD2793                   | PPV!888                   | 0.6083
# QRS2176                   | QRS2176                   | 0.9811
# SYY!4563                  | SYY!4563                  | 0.9633
# --------------------------------------------------------------------------------
# [Epoch 11] iter 86/129, avg loss: 0.1216
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# JWA!8158                  | JJA!8158                  | 0.8465
# JSD809                    | JSD809                    | 0.9742
# DCS!3819                  | DCS!3819                  | 0.9053
# UM2356                    | UH2336                    | 0.8718
# NDM4685                   | NDH4685                   | 0.8928
# --------------------------------------------------------------------------------
# [Epoch 11] iter 129/129, avg loss: 0.1330
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# VKP                       | VKP                       | 0.9665
# QAA9839E                  | QAA9839E                  | 0.9429
# KEN!7203                  | KEN!7203                  | 0.9428
# PDP6868                   | PDP6868                   | 0.9687
# VAJ4559                   | VAJ4559                   | 0.9938
# --------------------------------------------------------------------------------
# ==> Epoch 11 done in 9.0s | train_loss=0.1330  valid_loss=0.4519  valid_acc=66.18%
#
# no improvement for 1/100 epochs
#
# → Starting epoch 12  (printing every 43 iters)
# [Epoch 12] iter 43/129, avg loss: 0.0558
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# WGT7178                   | WGT7178                   | 0.9956
# PPT549                    | PPT549                    | 0.9724
# WQD6028                   | WQD6028                   | 0.9865
# KDN!1893                  | KDN!1893                  | 0.9290
# PQD!8388                  | PQD!8388                  | 0.9021
# --------------------------------------------------------------------------------
# [Epoch 12] iter 86/129, avg loss: 0.0545
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# BJM!8453                  | BJM!8453                  | 0.9128
# QAR53                     | QAR53                     | 0.9926
# DFC7000                   | DFC7000                   | 0.9955
# BMW8953                   | BMW8953                   | 0.9819
# MDL1672                   | MDL1672                   | 0.9981
# --------------------------------------------------------------------------------
# [Epoch 12] iter 129/129, avg loss: 0.0455
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# MD3426Q                   | MD3426Q                   | 0.9962
# RX8899                    | RX8899                    | 0.9567
# RAY!5050                  | RAY!5050                  | 0.9658
# QAA8133S                  | QAA8133S                  | 0.9691
# JXP!4469                  | JXP!4469                  | 0.9441
# --------------------------------------------------------------------------------
# ==> Epoch 12 done in 8.9s | train_loss=0.0455  valid_loss=0.3580  valid_acc=74.93%
#
# 💾 New best model saved (epoch 12, val_acc=74.93%)
#
# → Starting epoch 13  (printing every 43 iters)
# [Epoch 13] iter 43/129, avg loss: 0.0349
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# VAX9343                   | VAX9343                   | 0.9942
# MU!6275                   | MU!6275                   | 0.9138
# WDC!4844                  | WDC!4844                  | 0.9390
# QCJ!6565                  | QCJ!6565                  | 0.9019
# QAA8801X                  | QAA8801X                  | 0.9931
# --------------------------------------------------------------------------------
# [Epoch 13] iter 86/129, avg loss: 0.0374
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# PPD2622                   | PPD2622                   | 0.9962
# QAR53                     | QAR53                     | 0.9906
# AMQ!868                   | AMQ!868                   | 0.9462
# WC1484R                   | WC1484R                   | 0.9892
# WUT!2636                  | WUT!2636                  | 0.9261
# --------------------------------------------------------------------------------
# [Epoch 13] iter 129/129, avg loss: 0.0646
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QS2582P                   | QS2582P                   | 0.9652
# JRG6799                   | RRG6799                   | 0.8868
# WMW7786                   | WMW7786                   | 0.9580
# SM!2441                   | SM!2441                   | 0.9690
# WFS7393                   | WFS7393                   | 0.9875
# --------------------------------------------------------------------------------
# ==> Epoch 13 done in 9.3s | train_loss=0.0646  valid_loss=0.4351  valid_acc=71.14%
#
# no improvement for 1/100 epochs
#
# → Starting epoch 14  (printing every 43 iters)
# [Epoch 14] iter 43/129, avg loss: 0.0647
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# DCS3819                   | DCS3819                   | 0.9900
# QAB373                    | QAB373                    | 0.9750
# TBY9929                   | TBY9929                   | 0.9930
# VAJ4559                   | VAJ4559                   | 0.9956
# PPT549                    | PPT549                    | 0.9897
# --------------------------------------------------------------------------------
# [Epoch 14] iter 86/129, avg loss: 0.0571
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QCL8988                   | QCL8988                   | 0.9780
# WSM1382                   | WSM1382                   | 0.9921
# MCT8738                   | MCT8738                   | 0.9835
# RAQ!7877                  | RAQ!7877                  | 0.9092
# BNW5508                   | BNW5508                   | 0.9559
# --------------------------------------------------------------------------------
# [Epoch 14] iter 129/129, avg loss: 0.0504
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QBD9519                   | QBD9519                   | 0.9817
# T/JA6344                  | T/JA6344                  | 0.9620
# VCG9239                   | VCG9239                   | 0.9866
# DBX3112                   | DBX3112                   | 0.9499
# PMQ2551                   | PMQ2551                   | 0.9800
# --------------------------------------------------------------------------------
# ==> Epoch 14 done in 9.3s | train_loss=0.0504  valid_loss=0.3818  valid_acc=74.05%
#
# no improvement for 2/100 epochs
#
# → Starting epoch 15  (printing every 43 iters)
# [Epoch 15] iter 43/129, avg loss: 0.0180
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QAA7166M                  | QAA7166M                  | 0.9717
# VKP!3405                  | VKP!3405                  | 0.9672
# MAM!6063                  | MAM!6063                  | 0.9675
# QAA2892K                  | QAA2892K                  | 0.9973
# QM!5826G                  | QM!5826G                  | 0.9521
# --------------------------------------------------------------------------------
# [Epoch 15] iter 86/129, avg loss: 0.0444
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# PNX7192                   | PNX7192                   | 0.9865
# VGL5629                   | VGL5629                   | 0.9987
# DAG309                    | DAG309                    | 0.9864
# QCN8327                   | QCN8327                   | 0.9909
# NDM4685                   | NDM4685                   | 0.9780
# --------------------------------------------------------------------------------
# [Epoch 15] iter 129/129, avg loss: 0.0370
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QCE3983                   | QCE3983                   | 0.9780
# JNV4683                   | JNY4683                   | 0.9512
# QCA3252                   | QCA3252                   | 0.9822
# T/N7845                   | T/N7845                   | 0.9889
# NAP4617                   | NAP4617                   | 0.9592
# --------------------------------------------------------------------------------
# ==> Epoch 15 done in 9.0s | train_loss=0.0370  valid_loss=0.4125  valid_acc=72.89%
#
# no improvement for 3/100 epochs
#
# → Starting epoch 16  (printing every 43 iters)
# [Epoch 16] iter 43/129, avg loss: 0.0651
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# SJA8556                   | SJA8556                   | 0.9769
# MDV!8552                  | MDV!8552                  | 0.9043
# BRY8828                   | BRY8828                   | 0.9910
# WQP1991                   | WQP1991                   | 0.9956
# PPA!4817                  | PPA!4817                  | 0.9211
# --------------------------------------------------------------------------------
# [Epoch 16] iter 86/129, avg loss: 0.0623
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QKV9823                   | QKV9823                   | 0.9891
# QAB8116G                  | QAB8116G                  | 0.9953
# QAY4173                   | QAY4173                   | 0.9986
# QAQ1011                   | QAQ1011                   | 0.9957
# QKF!8656                  | QMF!8656                  | 0.9357
# --------------------------------------------------------------------------------
# [Epoch 16] iter 129/129, avg loss: 0.0522
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# ALX5554                   | ALX5554                   | 0.9909
# NDD6299                   | NDD6299                   | 0.9650
# JNU8226                   | JNU8226                   | 0.9695
# QRL5707                   | QRL5707                   | 0.9619
# SWH1319                   | SWH1319                   | 0.9982
# --------------------------------------------------------------------------------
# ==> Epoch 16 done in 8.8s | train_loss=0.0522  valid_loss=0.3354  valid_acc=77.55%
#
# 💾 New best model saved (epoch 16, val_acc=77.55%)
#
# → Starting epoch 17  (printing every 43 iters)
# [Epoch 17] iter 43/129, avg loss: 0.0188
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QAB5858                   | QAB5858                   | 0.9951
# VLD745                    | VLD745                    | 0.9852
# PFY3385                   | PFY3385                   | 0.9747
# BQX!3898                  | BQX!3898                  | 0.9515
# AMR9699                   | AMR9699                   | 0.9721
# --------------------------------------------------------------------------------
# [Epoch 17] iter 86/129, avg loss: 0.0206
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QCD6956                   | QCD6956                   | 0.9808
# QKH4199                   | QKH4199                   | 0.9789
# BGD7950                   | BGD7950                   | 0.9862
# MAM!6063                  | MAM!6063                  | 0.9639
# KER!3235                  | KER!3235                  | 0.9157
# --------------------------------------------------------------------------------
# [Epoch 17] iter 129/129, avg loss: 0.0190
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# JVB!7580                  | JVB!7580                  | 0.9573
# JV271                     | JV271                     | 0.9592
# VNQ2521                   | VNQ2521                   | 0.9828
# PLS!114                   | PLS!114                   | 0.9725
# KAK2779                   | KAK2779                   | 0.9953
# --------------------------------------------------------------------------------
# ==> Epoch 17 done in 9.2s | train_loss=0.0190  valid_loss=0.3078  valid_acc=78.43%
#
# 💾 New best model saved (epoch 17, val_acc=78.43%)
#
# → Starting epoch 18  (printing every 43 iters)
# [Epoch 18] iter 43/129, avg loss: 0.0161
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QAK!8791                  | QAK!8791                  | 0.9564
# QCJ4830                   | QCJ4830                   | 0.8744
# B3106A                    | B3106A                    | 0.9968
# QBC5425                   | QBC5425                   | 0.9985
# QAL315                    | QAL315                    | 0.9899
# --------------------------------------------------------------------------------
# [Epoch 18] iter 86/129, avg loss: 0.0194
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QS6338M                   | QS6338M                   | 0.9564
# VEQ6291                   | VEQ6291                   | 0.9945
# QBE!36                    | QBE!36                    | 0.9523
# VLU1213                   | VLU1213                   | 0.9776
# MADANI!9369               | MADANI!9669               | 0.7942
# --------------------------------------------------------------------------------
# [Epoch 18] iter 129/129, avg loss: 0.0357
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# VCQ7119                   | VCQ7119                   | 0.9746
# TAM!408                   | TAM!408                   | 0.9346
# WXA7223                   | WXA7223                   | 0.9699
# PRF!6163                  | PRF!6163                  | 0.9764
# RT1911                    | RT1911                    | 0.9741
# --------------------------------------------------------------------------------
# ==> Epoch 18 done in 10.6s | train_loss=0.0357  valid_loss=0.3745  valid_acc=69.68%
#
# no improvement for 1/100 epochs
#
# → Starting epoch 19  (printing every 43 iters)
# [Epoch 19] iter 43/129, avg loss: 0.0208
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QM5966P                   | QM5966P                   | 0.9788
# VHA6835                   | VHA6835                   | 0.9791
# JSL!6628                  | JSL!6628                  | 0.9796
# QAA!6846U                 | QAA!6846U                 | 0.9681
# QAA6192E                  | QAA6192E                  | 0.9861
# --------------------------------------------------------------------------------
# [Epoch 19] iter 86/129, avg loss: 0.0147
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QAB2288F                  | QAB2288F                  | 0.9896
# PC1811P                   | PC1811P                   | 0.9919
# T/AA823                   | T/AA823                   | 0.9710
# QAA!4494H                 | QAA!4494H                 | 0.9671
# VBY8203                   | VBY8203                   | 0.9810
# --------------------------------------------------------------------------------
# [Epoch 19] iter 129/129, avg loss: 0.0133
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# VM6611                    | VM6611                    | 0.9931
# QS9953S                   | QS9953S                   | 0.9990
# AKF!4463                  | AKF!4463                  | 0.9815
# WA8029J                   | WA8029J                   | 0.9956
# BEU!3104                  | BEU!3104                  | 0.9349
# --------------------------------------------------------------------------------
# ==> Epoch 19 done in 9.1s | train_loss=0.0133  valid_loss=0.3742  valid_acc=74.34%
#
# no improvement for 2/100 epochs
#
# → Starting epoch 20  (printing every 43 iters)
# [Epoch 20] iter 43/129, avg loss: 0.0168
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# BNN!2929                  | BNN!2929                  | 0.9742
# BEP3409                   | BEP3409                   | 0.9750
# WUT!2636                  | WUT!2636                  | 0.9632
# CES!4236                  | CES!4236                  | 0.9440
# WWL9209                   | WWL9209                   | 0.9958
# --------------------------------------------------------------------------------
# [Epoch 20] iter 86/129, avg loss: 0.0152
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QAA4058P                  | QAA4058P                  | 0.9948
# DAG309                    | DAG309                    | 0.9879
# WSJ8268                   | WSJ8268                   | 0.9711
# PMF!2507                  | PMF!2507                  | 0.9546
# RC!9863                   | RC!9863                   | 0.8867
# --------------------------------------------------------------------------------
# [Epoch 20] iter 129/129, avg loss: 0.0224
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QAN4488                   | QAN4488                   | 0.9815
# QTD33                     | QTD33                     | 0.9824
# TCM3335                   | TCM3335                   | 0.9864
# QKP3696                   | QKP3696                   | 0.9580
# K1688Q                    | K1688Q                    | 0.9344
# --------------------------------------------------------------------------------
# ==> Epoch 20 done in 9.1s | train_loss=0.0224  valid_loss=0.4447  valid_acc=70.85%
#
# no improvement for 3/100 epochs
#
# → Starting epoch 21  (printing every 43 iters)
# [Epoch 21] iter 43/129, avg loss: 0.0482
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QBC!666                   | QBC!666                   | 0.9687
# AHN!1732                  | AHN!1732                  | 0.9430
# PPA!4817                  | PPA!4817                  | 0.9660
# JLY2201                   | JLY2203                   | 0.9106
# NBV6243                   | NBV6243                   | 0.9844
# --------------------------------------------------------------------------------
# [Epoch 21] iter 86/129, avg loss: 0.0350
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# VCQ7119                   | VCQ7119                   | 0.9948
# WPH!317                   | WPH!317                   | 0.9725
# MCD9708                   | MCD9708                   | 0.9790
# QMS9397                   | QMS9397                   | 0.9829
# QAB2477H                  | QAB2477H                  | 0.9992
# --------------------------------------------------------------------------------
# [Epoch 21] iter 129/129, avg loss: 0.0291
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QCJ4830                   | QCJ4830                   | 0.8158
# QCS7968                   | QCS7968                   | 0.9849
# QDB7814                   | QDB7814                   | 0.9994
# QAA5823N                  | QAA5823N                  | 0.9890
# QCK8000                   | QCK8000                   | 0.9582
# --------------------------------------------------------------------------------
# ==> Epoch 21 done in 9.5s | train_loss=0.0291  valid_loss=0.3246  valid_acc=77.55%
#
# no improvement for 4/100 epochs
#
# → Starting epoch 22  (printing every 43 iters)
# [Epoch 22] iter 43/129, avg loss: 0.0108
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# DCS!3819                  | DCS!3819                  | 0.9750
# WXP416                    | WXP416                    | 0.9920
# RT1911                    | RT1911                    | 0.9826
# W763L                     | W763L                     | 0.9939
# NDD6299                   | NDD6299                   | 0.9897
# --------------------------------------------------------------------------------
# [Epoch 22] iter 86/129, avg loss: 0.0110
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# VFX447                    | VFX447                    | 0.9763
# SMH1061                   | SMH1061                   | 0.9691
# QAB751H                   | QAB751H                   | 0.9942
# QPA2092                   | QPA2092                   | 0.9976
# VGN2263                   | VGN2263                   | 0.9978
# --------------------------------------------------------------------------------
# [Epoch 22] iter 129/129, avg loss: 0.0126
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# PRM41                     | PRM41                     | 0.9477
# VH4089                    | VH4089                    | 0.9823
# MDC!8333                  | MDC!8333                  | 0.9664
# ANF8688                   | ANF8688                   | 0.9658
# WB1351J                   | WB1351J                   | 0.9971
# --------------------------------------------------------------------------------
# ==> Epoch 22 done in 9.1s | train_loss=0.0126  valid_loss=0.3412  valid_acc=77.84%
#
# no improvement for 5/100 epochs
#
# → Starting epoch 23  (printing every 43 iters)
# [Epoch 23] iter 43/129, avg loss: 0.0076
# ...
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QS1595E                   | QS1595E                   | 0.9737
# WNB6877                   | WNB6877                   | 0.9666
# BDR!2148                  | BDR!2148                  | 0.9817
# QS1016K                   | QS1016K                   | 0.9973
# TCF8978                   | TCF8978                   | 0.9757
# --------------------------------------------------------------------------------
# ==> Epoch 175 done in 9.0s | train_loss=0.0003  valid_loss=0.4027  valid_acc=78.13%
#
# no improvement for 93/100 epochs
#
# → Starting epoch 176  (printing every 43 iters)
# [Epoch 176] iter 43/129, avg loss: 0.0004
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# AHU!7727                  | AHU!7727                  | 0.9881
# WNF8992                   | WNF8992                   | 0.9988
# QS3366B                   | QS3366B                   | 0.9982
# AMC6830                   | AMC6830                   | 0.9994
# QAH7520                   | QAH7520                   | 0.9999
# --------------------------------------------------------------------------------
# [Epoch 176] iter 86/129, avg loss: 0.0003
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# KBJ5226                   | KBJ5226                   | 0.9986
# VFK!8102                  | VFK!8102                  | 0.9701
# QRR2912                   | QRR2912                   | 0.9918
# PMG7552                   | PMG7552                   | 0.9986
# NDL4631                   | NDL4631                   | 0.9997
# --------------------------------------------------------------------------------
# [Epoch 176] iter 129/129, avg loss: 0.0004
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# PZ171M                    | PZ171M                    | 0.9921
# VHW!6283                  | VHW!6283                  | 0.9743
# QCT7867                   | QCT7867                   | 0.9953
# MCV!3797                  | MCV!3797                  | 0.9989
# JMW!7452                  | JMW!7452                  | 0.9993
# --------------------------------------------------------------------------------
# ==> Epoch 176 done in 9.1s | train_loss=0.0004  valid_loss=0.3926  valid_acc=79.59%
#
# no improvement for 94/100 epochs
#
# → Starting epoch 177  (printing every 43 iters)
# [Epoch 177] iter 43/129, avg loss: 0.0003
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QBG411                    | QBG411                    | 0.9964
# FFF2966                   | FFF2966                   | 0.9953
# QCJ2794                   | QCJ2794                   | 0.9764
# QAA!4494H                 | QAA!4494H                 | 0.9817
# VNA!4207                  | VNA!4207                  | 0.9900
# --------------------------------------------------------------------------------
# [Epoch 177] iter 86/129, avg loss: 0.0009
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# SAC1674E                  | SAC1674E                  | 0.9987
# WVV2948                   | WVV2948                   | 0.9947
# KFT4037                   | KFT4037                   | 0.9845
# BHF2928                   | BHF2928                   | 0.9815
# RU8892                    | RU8892                    | 0.9791
# --------------------------------------------------------------------------------
# [Epoch 177] iter 129/129, avg loss: 0.0008
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# WUS4781                   | WUS4781                   | 0.9893
# KET5528                   | KET5528                   | 0.9996
# WSM1382                   | WSM1382                   | 1.0000
# JTD2383                   | JTD2383                   | 0.9956
# VFK!8102                  | VFK!8102                  | 0.9775
# --------------------------------------------------------------------------------
# ==> Epoch 177 done in 9.2s | train_loss=0.0008  valid_loss=0.4189  valid_acc=78.13%
#
# no improvement for 95/100 epochs
#
# → Starting epoch 178  (printing every 43 iters)
# [Epoch 178] iter 43/129, avg loss: 0.0013
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# JVD7333                   | JVD7333                   | 0.9996
# JWE!3023                  | JWE!3023                  | 0.9744
# JTU3636                   | JTU3636                   | 0.9909
# SAC!8630E                 | SAC!8630E                 | 0.9886
# JKN9008                   | JKN9008                   | 0.9988
# --------------------------------------------------------------------------------
# [Epoch 178] iter 86/129, avg loss: 0.0010
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# TBY9929                   | TBY9929                   | 0.9851
# VLM6493                   | VLM6493                   | 0.9914
# VKD9603                   | VKD9603                   | 0.9919
# PBW!9097                  | PBW!9097                  | 0.9934
# TBT9322                   | TBT9322                   | 0.9998
# --------------------------------------------------------------------------------
# [Epoch 178] iter 129/129, avg loss: 0.0007
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# JWW9378                   | JWW9378                   | 0.9901
# MDJ5126                   | MDJ5126                   | 0.9914
# JSH!4299                  | JSH!4299                  | 0.9903
# BRY8828                   | BRY8828                   | 0.9788
# PNX7192                   | PNX7192                   | 0.9996
# --------------------------------------------------------------------------------
# ==> Epoch 178 done in 9.1s | train_loss=0.0007  valid_loss=0.4255  valid_acc=80.47%
#
# no improvement for 96/100 epochs
#
# → Starting epoch 179  (printing every 43 iters)
# [Epoch 179] iter 43/129, avg loss: 0.0010
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# KAX1199                   | KAX1199                   | 0.9997
# QSV1707                   | QSV1707                   | 0.9999
# T/BD!1513                 | T/BD!1513                 | 0.9626
# WUV9209                   | WUV9209                   | 0.9943
# NAH!1048                  | NAH!1048                  | 0.9888
# --------------------------------------------------------------------------------
# [Epoch 179] iter 86/129, avg loss: 0.0006
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QM!7099P                  | QM!7099P                  | 0.9831
# WA!7920W                  | WA!7920W                  | 0.9961
# QLB7733                   | QLB7733                   | 0.9915
# VH6789                    | VH6789                    | 0.9647
# QAA3270T                  | QAA3270T                  | 0.9817
# --------------------------------------------------------------------------------
# [Epoch 179] iter 129/129, avg loss: 0.0006
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QM5966P                   | QM5966P                   | 0.9992
# BEQ8584                   | BEQ8584                   | 0.9366
# AMB!1960                  | AMB!1960                  | 0.9912
# QPA5959                   | QPA5959                   | 0.9995
# MDV!8552                  | MDV!8552                  | 0.9378
# --------------------------------------------------------------------------------
# ==> Epoch 179 done in 9.0s | train_loss=0.0006  valid_loss=0.4124  valid_acc=79.30%
#
# no improvement for 97/100 epochs
#
# → Starting epoch 180  (printing every 43 iters)
# [Epoch 180] iter 43/129, avg loss: 0.0007
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QAB9515H                  | QAB9515H                  | 0.9890
# BNG7883                   | BNG7883                   | 0.9957
# BLG7607                   | BLG7607                   | 0.9995
# CDR5920                   | CDR5920                   | 0.9972
# QKE9575                   | QKE9575                   | 0.9842
# --------------------------------------------------------------------------------
# [Epoch 180] iter 86/129, avg loss: 0.0006
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# WXQ9376                   | WXQ9376                   | 0.9886
# QCJ!6565                  | QCJ!6565                  | 0.9932
# QAB9668H                  | QAB9668H                  | 0.9987
# PLM!1311                  | PLM!1311                  | 0.9968
# PGL!2189                  | PGL!2189                  | 0.9977
# --------------------------------------------------------------------------------
# [Epoch 180] iter 129/129, avg loss: 0.0006
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QS9007H                   | QS9007H                   | 0.9998
# WUT!2636                  | WUT!2636                  | 0.9678
# WHL8046                   | WHL8046                   | 0.9776
# WTM!3755                  | WTM!3755                  | 0.9994
# BLY5998                   | BLY5998                   | 0.9989
# --------------------------------------------------------------------------------
# ==> Epoch 180 done in 9.2s | train_loss=0.0006  valid_loss=0.4117  valid_acc=79.30%
#
# no improvement for 98/100 epochs
#
# → Starting epoch 181  (printing every 43 iters)
# [Epoch 181] iter 43/129, avg loss: 0.0011
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QTY9455                   | QTY9455                   | 0.9984
# QKB1883                   | QKB1883                   | 0.9814
# VES!3744                  | VES!3744                  | 0.9947
# QKU9019                   | QKU9019                   | 0.9877
# MDP!3394                  | MDP!3394                  | 0.9996
# --------------------------------------------------------------------------------
# [Epoch 181] iter 86/129, avg loss: 0.0010
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QCJ2305                   | QCJ2305                   | 0.9943
# BNW!2744                  | BNW!2744                  | 0.9868
# WYV3365                   | WYV3365                   | 0.9997
# KER!3235                  | KER!3235                  | 0.9671
# QCS8636                   | QCS8636                   | 0.9989
# --------------------------------------------------------------------------------
# [Epoch 181] iter 129/129, avg loss: 0.0007
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QDB!448                   | QDB!448                   | 0.9785
# T/D1673                   | T/D1673                   | 0.9987
# QAB6918F                  | QAB6918F                  | 0.9999
# JVB6226                   | JVB6226                   | 0.9924
# VKN!4650                  | VKN!4650                  | 0.9913
# --------------------------------------------------------------------------------
# ==> Epoch 181 done in 9.2s | train_loss=0.0007  valid_loss=0.4090  valid_acc=79.01%
#
# no improvement for 99/100 epochs
#
# → Starting epoch 182  (printing every 43 iters)
# [Epoch 182] iter 43/129, avg loss: 0.0002
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# SYC2787                   | SYC2787                   | 0.9989
# VHE7588                   | VHE7588                   | 0.9806
# QAA!7135S                 | QAA!7135S                 | 0.9988
# QAB2288F                  | QAB2288F                  | 0.9984
# W1301R                    | W1301R                    | 0.9647
# --------------------------------------------------------------------------------
# [Epoch 182] iter 86/129, avg loss: 0.0002
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# BML1717                   | BML1717                   | 0.9637
# PMF!2507                  | PMF!2507                  | 0.9904
# NDN4403                   | NDN4403                   | 0.9988
# WTL9654                   | WTL9654                   | 0.9964
# CCP8081                   | CCP8081                   | 0.9950
# --------------------------------------------------------------------------------
# [Epoch 182] iter 129/129, avg loss: 0.0006
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# VDM!8068                  | VDM!8068                  | 0.9641
# NBS4847                   | NBS4847                   | 0.9975
# WCP8833                   | WCP8833                   | 0.9781
# QAA844Q                   | QAA844Q                   | 0.9936
# ST!8466X                  | ST!8466X                  | 0.9891
# --------------------------------------------------------------------------------
# ==> Epoch 182 done in 9.1s | train_loss=0.0006  valid_loss=0.4448  valid_acc=76.97%
#
# no improvement for 100/100 epochs
#
# 🔚 Early stopping: val_acc hasn't improved for 100 epochs.

# %%
clean_history = {
  'epoch':      history['epoch'],
  'train_loss': [x.cpu().item() if hasattr(x, 'cpu') else x for x in history['train_loss']],
  'val_loss':   [x.cpu().item() if hasattr(x, 'cpu') else x for x in history['val_loss']],
  'val_acc':    [x.cpu().item() if hasattr(x, 'cpu') else x for x in history['val_acc']],
}
df = pd.DataFrame(clean_history)
display(df)

plt.figure()
plt.plot(df['epoch'], df['train_loss'], label='Train Loss')
plt.plot(df['epoch'], df['val_loss'],   label='Val Loss')
plt.xlabel('Epoch'); plt.ylabel('Loss'); plt.legend()
plt.title('Loss over Epochs')
plt.show()

plt.figure()
plt.plot(df['epoch'], df['val_acc'],   label='Val Accuracy')
plt.xlabel('Epoch'); plt.ylabel('Accuracy (%)'); plt.legend()
plt.title('Val Accuracy over Epochs')
plt.show()
# Out:
#      epoch  train_loss  val_loss    val_acc
# 0        1    2.614358  1.949283   0.000000
# 1        2    1.597078  1.069742   3.206997
# 2        3    0.858380  0.718701  40.524781
# 3        4    0.529251  0.542846  61.224490
# 4        5    0.408434  0.513308  64.431487
# ..     ...         ...       ...        ...
# 177    178    0.000734  0.425546  80.466472
# 178    179    0.000648  0.412388  79.300292
# 179    180    0.000557  0.411702  79.300292
# 180    181    0.000734  0.409038  79.008746
# 181    182    0.000556  0.444837  76.967930
#
# [182 rows x 4 columns]

# %%
# # ─── Cell 9: ONNX export via isolated inference head ─────────────────────────
# import torch

# class CRNNInference(torch.nn.Module):
#     def __init__(self, crnn, max_len):
#         super().__init__()
#         # use exactly the names printed out by your inspection
#         self.Transformation     = crnn.Transformation
#         self.FeatureExtraction = crnn.FeatureExtraction
#         self.AdaptiveAvgPool    = crnn.AdaptiveAvgPool
#         self.SequenceModeling   = crnn.SequenceModeling
#         self.Prediction         = crnn.Prediction
#         self.max_len           = max_len
#         # adjust this if your converter stores start-token under a different key
#         self.start_id          = crnn.converter.dict['[GO]']

#     def forward(self, image):
#         # 1) Spatial‐transformer + feature CNN
#         x = self.Transformation(image)                     # [B, C, H, W]
#         x = self.FeatureExtraction(x)                      # [B, C, H, W]

#         # 2) Pool down height to 1
#         x = self.AdaptiveAvgPool(x)                        # [B, C, 1, W]
#         x = x.squeeze(2)                                   # [B, C, W]
#         x = x.permute(0, 2, 1)                             # [B, W, C]

#         # 3) 2‐layer BiLSTM
#         contextual = self.SequenceModeling(x)              # [B, W, hidden]

#         # 4) Dummy “[GO]” token vector
#         B = contextual.size(0)
#         dummy_text = torch.full(
#             (B,),
#             self.start_id,
#             dtype=torch.long,
#             device=image.device
#         )  # shape [B]

#         # 5) Attention decoder (inference path)
#         return self.Prediction(
#             batch_H           = contextual,
#             text              = dummy_text,
#             is_train          = False,
#             batch_max_length  = self.max_len
#         )

# # Wrap and export
# inference_model = CRNNInference(model, BATCH_MAX_LENGTH).eval()
# dummy_img       = torch.randn(1, INPUT_CHANNEL, IMG_HEIGHT, IMG_WIDTH, device=device)

# torch.onnx.export(
#     inference_model,
#     dummy_img,
#     "best_attention_crnn.onnx",
#     input_names   = ['image'],
#     output_names  = ['logits'],
#     dynamic_axes  = {
#         'image':  {0: 'batch'},
#         'logits': {0: 'batch', 1: 'time'}
#     },
#     opset_version = 13,
# )

# print("✅ Exported best_attention_crnn.onnx")

# %% [markdown]
# # DUMP

# %%
# # ─── cell 6: attention‐based training loop ──────────────────────────────────────
# for epoch in range(1, NUM_EPOCHS+1):
#     print(f"→ Starting epoch {epoch}  (printing every {PRINT_EVERY} iters)")
#     model.train()
#     epoch_loss = Averager()
#     start      = time.time()

#     for i, (images, texts) in enumerate(train_loader, 1):
#         images = images.to(device)

#         # encode with [GO] & [s]; also get lengths
#         text, length = converter.encode(texts, batch_max_length=BATCH_MAX_LENGTH)
#         text_input  = text[:, :-1].to(device)   # drop final [s]
#         text_target = text[:,  1:].to(device)   # everything after [GO]

#         # forward + loss
#         preds = model(images,
#                       text=text_input,
#                       is_train=True,
#                       batch_max_length=BATCH_MAX_LENGTH)  # [B, S, C]
#         B, S, C = preds.size()
#         loss = criterion(
#             preds.view(B * S, C),
#             text_target.contiguous().view(B * S)
#         )

#         optimizer.zero_grad()
#         loss.backward()
#         torch.nn.utils.clip_grad_norm_(model.parameters(), 5)
#         optimizer.step()
#         epoch_loss.add(loss)

#         if i % PRINT_EVERY == 0 or i == 1:
#             print(f"[Epoch {epoch}] iter {i}/{len(train_loader)}, avg loss: {epoch_loss.val():.4f}", flush=True)

#             # quick greedy‐decode
#             with torch.no_grad():
#                 probs        = preds.softmax(2)           # [B, S, C]
#                 max_vals, max_inds = probs.max(2)         # [B, S]
#                 pred_strs    = converter.decode(max_inds, length)
#                 pred_strs    = [s.split('[s]')[0] for s in pred_strs]

#             # print a mini‐table
#             print("-" * 80)
#             print(f"{'Ground Truth':25s} | {'Prediction':25s} | AvgConfidence")
#             print("-" * 80)
#             for gt, pr, conf_seq in zip(texts[:5], pred_strs[:5], max_vals[:5]):
#                 conf = conf_seq.mean().item()
#                 print(f"{gt:25s} | {pr:25s} | {conf:0.4f}")
#             print("-" * 80)

#     # end‐of‐epoch validation
#     val_loss, val_acc = validate(model, val_loader)
#     elapsed = time.time() - start
#     print(f"==> Epoch {epoch} done in {elapsed:.1f}s | "
#           f"train_loss={epoch_loss.val():.4f}"
#           f"  valid_loss={val_loss:.4f}  valid_acc={val_acc:.2f}%\n")
