# %%
# cell 1
import os
import time
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
import matplotlib.pyplot as plt
import pandas as pd
import random
import numpy as np

from config import (IMG_HEIGHT, IMG_WIDTH, NUM_FIDUCIAL,
                    INPUT_CHANNEL, OUTPUT_CHANNEL, HIDDEN_SIZE,
                    CHARACTERS, MAX_LABEL_LENGTH)
from dataset import LmdbDataset, AlignCollate
from utils import CTCLabelConverter, Averager
from torch.nn import CTCLoss
from model import CRNN
import torchvision.transforms as T
from PIL import Image

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print("Running on", device)
# Out:
# Running on cuda

# %%
# ─── cell 0: reproducibility ────────────────────────────────────────────────
SEED = 300188
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)

# Make cuDNN deterministic (slower but reproducible)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

print(f"All seeds set to {SEED}, cudnn.deterministic={torch.backends.cudnn.deterministic}")
# Out:
# All seeds set to 300188, cudnn.deterministic=True

# %% [markdown]
# ------ Added Augmentation ------

# %%
augment_pipeline = T.Compose([
    # rotate up to ±15°
    T.RandomRotation(15, expand=False, fill=255),

    # flip left ↔ right with 50% probability
    T.RandomHorizontalFlip(p=0.5),

    # shear by up to ±10°
    T.RandomAffine(degrees=0, shear=10, fill=255),

    # slight brightness jitter
    T.ColorJitter(brightness=0.2),

    # add gaussian noise in [0,1], then back to uint8
    T.Lambda(lambda img: (
        Image.fromarray(
            (
                np.clip(
                    np.array(img).astype(np.float32) / 255.0
                    + np.random.normal(0, 0.02, img.size[::-1]),
                    0.0, 1.0
                ) * 255.0
            ).astype(np.uint8)
        )
    )),
])

# %%
class AugmentedLmdbDataset(Dataset):
    def __init__(self, base_dataset, augment, num_aug):
        self.base     = base_dataset
        self.augment  = augment
        self.num_aug  = num_aug
        self.orig_len = len(base_dataset)

    def __len__(self):
        # each original plus `num_aug` variants
        return self.orig_len * (1 + self.num_aug)

    def __getitem__(self, idx):
        if idx < self.orig_len:
            # raw sample
            return self.base[idx]
        # augmented sample
        base_idx = idx % self.orig_len
        img, label = self.base[base_idx]
        return self.augment(img), label

# %%
# cell 2
# paths to your LMDBs
train_lmdb = "v4_lmdb_data_!/train"
val_lmdb   = "v4_lmdb_data_!/val"

# instantiate datasets
train_dataset = LmdbDataset(train_lmdb)
val_dataset   = LmdbDataset(val_lmdb)

# augmentations
NUM_AUG = 3   # → total factor = 1 (orig) + 2 aug = ×3
aug_train_dataset = AugmentedLmdbDataset(train_dataset, augment_pipeline, num_aug=NUM_AUG)
print(f"Original train images: {len(train_dataset)}")
print(f"After augmentation:    {len(aug_train_dataset)}  (×{1+NUM_AUG} total samples)")

# collate_fn resizes + normalizes
collate_fn = AlignCollate(
    imgH=IMG_HEIGHT, imgW=IMG_WIDTH, keep_ratio_with_pad=False
)

# loaders
BATCH_SIZE = 32
train_loader = DataLoader(
    aug_train_dataset, batch_size=BATCH_SIZE, shuffle=True,
    num_workers=0, collate_fn=collate_fn, pin_memory=True
)
val_loader = DataLoader(
    val_dataset, batch_size=BATCH_SIZE, shuffle=False,
    num_workers=0, collate_fn=collate_fn, pin_memory=True
)

print(f"{len(aug_train_dataset)} train / {len(val_dataset)} val samples")
# Out:
# Loaded 1372 valid samples from v4_lmdb_data_!/train
# Loaded 343 valid samples from v4_lmdb_data_!/val
# Original train images: 1372
# After augmentation:    5488  (×4 total samples)
# 5488 train / 343 val samples

# %%
converter   = CTCLabelConverter(CHARACTERS)
num_classes = len(converter.character)

model = CRNN(
    IMG_HEIGHT,      # imgH
    IMG_WIDTH,       # imgW
    INPUT_CHANNEL,   # input_channel
    OUTPUT_CHANNEL,  # output_channel
    HIDDEN_SIZE,     # hidden_size
    num_classes,     # num_classes (with GO/s)
    False,            # disable attention
    NUM_FIDUCIAL     # num_fiducial
).to(device)

criterion = CTCLoss(blank=0, reduction="mean", zero_infinity=True).to(device)
optimizer = optim.Adadelta(model.parameters(), lr=1.0)

# %%
# ─── cell 4: validate (Attention) ─────────────────────────────────────────────
NUM_EPOCHS       = 500
PRINT_EVERY      = len(aug_train_dataset) // BATCH_SIZE + 1
PATIENCE       = 100          # stop if no val_acc ↑ for 50 epochs

def validate_ctc(model, loader):
    model.eval()
    avg_loss = Averager()
    correct, total = 0, 0

    with torch.no_grad():
        for images, texts in loader:
            images = images.to(device)
            # encode targets & lengths:
            targets, target_lengths = converter.encode(
                texts, batch_max_length=MAX_LABEL_LENGTH
            )

            # model outputs logits [B, T, C]:
            logits    = model(images)                         # [B, T, C]
            log_probs = logits.log_softmax(2)                 # [B, T, C]
            log_probs = log_probs.permute(1, 0, 2)            # [T, B, C]

            input_lengths = torch.full(
                (log_probs.size(1),), log_probs.size(0),
                dtype=torch.long, device=device
            )

            # CTC loss
            loss = criterion(log_probs, targets, input_lengths, target_lengths)
            avg_loss.add(loss)

            # ── greedy CTC decode **over the full T** ─────────────────
            # get [B, T] argmax indices
            max_inds = log_probs.argmax(2).permute(1, 0).cpu().numpy()
            # assume every sequence is length T
            full_lengths = np.full((max_inds.shape[0],), max_inds.shape[1], dtype=int)
            # collapse repeats+blanks
            pred_strs = converter.decode(max_inds, full_lengths)

            total += len(texts)
            correct += sum(p == g for p, g in zip(pred_strs, texts))

    acc = correct / total * 100
    return avg_loss.val(), acc

# %%
# ─── cell 5: load pretrained CTC weights (skip old Prediction head) ────────────

from collections import OrderedDict

orig      = torch.load("pretrained_model/TPS-ResNet-BiLSTM-CTC.pth", map_location=device)
# strip off the "module." prefix if you wrapped in DataParallel
stripped  = OrderedDict((k[len("module."):], v)
                        for k, v in orig.items()
                        if k.startswith("module."))

own = model.state_dict()
for k, v in stripped.items():
    # skip the old attention head entirely
    if k.startswith("Prediction."):
        continue
    # only overwrite if shapes match
    if k in own and v.size() == own[k].size():
        own[k] = v

model.load_state_dict(own)
print("✅ Loaded pretrained CTC weights")
# Out:
# ✅ Loaded pretrained CTC weights

# %%
# ─── Cell 6: training w/ history, best‐model saving + EARLY STOPPING ───

# hyper-params
best_val_acc = 0.0
history = {'epoch': [], 'train_loss': [], 'val_loss': [], 'val_acc': []}
patience_cnt = 0  # how many epochs since last improvement

for epoch in range(1, NUM_EPOCHS + 1):
    print(f"→ Starting epoch {epoch}  (printing every {PRINT_EVERY} iters)")
    model.train()
    epoch_loss = Averager()
    start = time.time()

    for i, (images, texts) in enumerate(train_loader, 1):
        images = images.to(device)
        targets, target_lengths = converter.encode(texts, batch_max_length=MAX_LABEL_LENGTH)

        # forward + loss
        logits = model(images)                              # [B, T, C]
        log_probs = logits.log_softmax(2).permute(1, 0, 2)   # [T, B, C]
        input_lengths = torch.full(
            (log_probs.size(1),), log_probs.size(0),
            dtype=torch.long, device=device
        )
        loss = criterion(log_probs, targets, input_lengths, target_lengths)

        optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 5)
        optimizer.step()
        epoch_loss.add(loss)

        if i % PRINT_EVERY == 0:
            with torch.no_grad():
                # re-compute probs & best‐path over full sequence
                probs = logits.softmax(2)           # [B, T, C]
                max_vals, max_inds = probs.max(2)   # [B, T]

                # treat every sequence as length T for decoding
                full_lengths = np.full((max_inds.size(0),), max_inds.size(1), dtype=int)
                pred_strs = converter.decode(
                    max_inds.cpu().numpy(),
                    full_lengths
                )

            print("-" * 80)
            print(f"{'Ground Truth':25s} | {'Prediction':25s} | AvgConfidence")
            print("-" * 80)
            for gt, pr, conf_seq in zip(texts[:5], pred_strs[:5], max_vals[:5]):
                print(f"{gt:25s} | {pr:25s} | {conf_seq.mean().item():.4f}")
            print("-" * 80)

    # ─── validation ────────────────────────────────────────────────────────
    val_loss, val_acc = validate_ctc(model, val_loader)
    elapsed = time.time() - start
    train_l = epoch_loss.val()
    print(
        f"==> Epoch {epoch} done in {elapsed:.1f}s | "
        f"train_loss={train_l:.4f}  valid_loss={val_loss:.4f}  valid_acc={val_acc:.2f}%\n"
    )

    # ─── record history ───────────────────────────────────────────────────
    history['epoch'].append(epoch)
    history['train_loss'].append(train_l)
    history['val_loss'].append(val_loss)
    history['val_acc'].append(val_acc)

    # ─── best-model tracking & early-stopping logic ───────────────────────
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        torch.save(model.state_dict(), "best_ctc_crnn_!.pth")
        print(f"💾 New best model saved (epoch {epoch}, val_acc={val_acc:.2f}%)\n")
        patience_cnt = 0
    else:
        patience_cnt += 1
        print(f"no improvement for {patience_cnt}/{PATIENCE} epochs\n")
        if patience_cnt >= PATIENCE:
            print(f"🔚 Early stopping: val_acc hasn't improved for {PATIENCE} epochs.")
            break
# Out:
# → Starting epoch 1  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QAA3986N                  | QAA3986W                  | 0.9730
# VLM6493                   | VLM6493                   | 0.9786
# KFL!5361                  | JBW!5361                  | 0.8234
# SA1408K                   | QA00118                   | 0.8291
# ANB!9161                  | QA!1818                   | 0.7762
# --------------------------------------------------------------------------------
# ==> Epoch 1 done in 9.5s | train_loss=1.8281  valid_loss=0.5062  valid_acc=60.64%
#
# 💾 New best model saved (epoch 1, val_acc=60.64%)
#
# → Starting epoch 2  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QS!6618B                  | SM!6618B                  | 0.8636
# QS2025K                   | QS2025K                   | 0.9945
# VJR!1999                  | QCB!1999                  | 0.8421
# WTK7060                   | WTK7060                   | 0.9924
# SWM7576                   | SWM7576                   | 0.9890
# --------------------------------------------------------------------------------
# ==> Epoch 2 done in 9.3s | train_loss=1.1286  valid_loss=0.4161  valid_acc=68.51%
#
# 💾 New best model saved (epoch 2, val_acc=68.51%)
#
# → Starting epoch 3  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# VFT!2934                  | 4H!423                    | 0.8210
# WGQ3709                   | WGQ3709                   | 0.9925
# PLH7338                   | PLH7338                   | 0.9971
# VHB3371                   | VHB3371                   | 0.9997
# NCP!9457                  | VAW!9457                  | 0.8771
# --------------------------------------------------------------------------------
# ==> Epoch 3 done in 9.2s | train_loss=0.9523  valid_loss=0.4285  valid_acc=68.51%
#
# no improvement for 1/100 epochs
#
# → Starting epoch 4  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QCH9191                   | QCH9191                   | 0.9755
# BJM9030                   | BJM9230                   | 0.9671
# VBKL364                   | VT3335                    | 0.8980
# VHA6835                   | VHA6835                   | 0.9963
# QCE40                     | QCE40                     | 0.9919
# --------------------------------------------------------------------------------
# ==> Epoch 4 done in 8.9s | train_loss=0.8117  valid_loss=0.4686  valid_acc=65.60%
#
# no improvement for 2/100 epochs
#
# → Starting epoch 5  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# WA8029J                   | WAA022A                   | 0.9211
# QRQ!7277                  | VAB!7277                  | 0.8694
# QAK!8791                  | QAN!8291                  | 0.8440
# QMU969                    | QMU963                    | 0.9431
# WXP416                    | WXP416                    | 0.9858
# --------------------------------------------------------------------------------
# ==> Epoch 5 done in 9.0s | train_loss=0.6686  valid_loss=0.4654  valid_acc=67.06%
#
# no improvement for 3/100 epochs
#
# → Starting epoch 6  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# SYP3885                   | SYY3885                   | 0.9667
# WTE8384                   | WTE8384                   | 0.9953
# QCP5533                   | QCG5337                   | 0.9302
# QCK8000                   | QCK8000                   | 0.9999
# QAA!8698P                 | QAA!98888                 | 0.8512
# --------------------------------------------------------------------------------
# ==> Epoch 6 done in 8.9s | train_loss=0.5532  valid_loss=0.4641  valid_acc=67.64%
#
# no improvement for 4/100 epochs
#
# → Starting epoch 7  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# WVL713                    | WVL713                    | 0.9933
# QLA8686                   | QLA8486                   | 0.9887
# PRR6999                   | PRR6999                   | 0.9947
# QA                        | QA                        | 0.9939
# VTQ1924                   | VDQ1924                   | 0.9862
# --------------------------------------------------------------------------------
# ==> Epoch 7 done in 9.1s | train_loss=0.4593  valid_loss=0.4860  valid_acc=66.47%
#
# no improvement for 5/100 epochs
#
# → Starting epoch 8  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# G!4653                    | S!4653                    | 0.9127
# JLK5650                   | JLM5660                   | 0.9946
# QAA!7324R                 | QAA!7324R                 | 0.9916
# QTE!4766                  | AS!6766                   | 0.8738
# WXT3305                   | WXT3305                   | 0.9805
# --------------------------------------------------------------------------------
# ==> Epoch 8 done in 9.1s | train_loss=0.4031  valid_loss=0.5215  valid_acc=65.89%
#
# no improvement for 6/100 epochs
#
# → Starting epoch 9  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# TCN!8474                  | TDC!8474                  | 0.9245
# BHS5465                   | BHS5465                   | 0.9996
# QCS7968                   | QCS7968                   | 0.9764
# QCJ4164                   | QCJ14464                  | 0.9547
# VMQ981                    | VMQ981                    | 0.9878
# --------------------------------------------------------------------------------
# ==> Epoch 9 done in 9.1s | train_loss=0.3310  valid_loss=0.5174  valid_acc=68.51%
#
# no improvement for 7/100 epochs
#
# → Starting epoch 10  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# AMB!1960                  | VA!1960                   | 0.8763
# QAN8882                   | QAN8882                   | 0.9830
# JNU8226                   | JNU8226                   | 0.9982
# TCJ!8981                  | TC!8981                   | 0.9251
# QAA377P                   | QAA377P                   | 0.9569
# --------------------------------------------------------------------------------
# ==> Epoch 10 done in 9.1s | train_loss=0.2737  valid_loss=0.5850  valid_acc=65.60%
#
# no improvement for 8/100 epochs
#
# → Starting epoch 11  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# MCY8232                   | MCY8232                   | 0.9978
# WVB5362                   | WVB5362                   | 0.9845
# PD5855G                   | PD5855G                   | 1.0000
# PNV!4846                  | PNW!4846                  | 0.9294
# VKD9639                   | VKD9639                   | 0.9999
# --------------------------------------------------------------------------------
# ==> Epoch 11 done in 8.9s | train_loss=0.2277  valid_loss=0.5873  valid_acc=67.64%
#
# no improvement for 9/100 epochs
#
# → Starting epoch 12  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# VFD892                    | JFD898                    | 0.9528
# JSF2692                   | JSF2692                   | 0.9827
# NAAM1997                  | NAAM1997                  | 0.9979
# QAA8656V                  | QAA8656V                  | 0.9981
# QAB7401J                  | QAB7401J                  | 0.9993
# --------------------------------------------------------------------------------
# ==> Epoch 12 done in 8.6s | train_loss=0.2042  valid_loss=0.6144  valid_acc=65.89%
#
# no improvement for 10/100 epochs
#
# → Starting epoch 13  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# WXQ9376                   | WXQ9376                   | 1.0000
# VK2618                    | VK2618                    | 0.9916
# PD5855G                   | PD5855G                   | 0.9968
# MDJ!6389                  | MDH!6569                  | 0.9281
# WYX8694                   | WYX8694                   | 0.9857
# --------------------------------------------------------------------------------
# ==> Epoch 13 done in 8.8s | train_loss=0.1773  valid_loss=0.6260  valid_acc=69.39%
#
# 💾 New best model saved (epoch 13, val_acc=69.39%)
#
# → Starting epoch 14  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QS5039N                   | QS5039N                   | 0.9883
# T/WC3060                  | T/WC3060                  | 0.9827
# VE9696                    | VF9696                    | 0.9725
# VNQ2521                   | VNQ2521                   | 0.9764
# VDA4811                   | VDA4811                   | 0.9976
# --------------------------------------------------------------------------------
# ==> Epoch 14 done in 9.1s | train_loss=0.1491  valid_loss=0.7036  valid_acc=64.72%
#
# no improvement for 1/100 epochs
#
# → Starting epoch 15  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# VKS!4174                  | VKAA!4174                 | 0.9226
# RT9009                    | RT9009                    | 0.9999
# KFT4037                   | KFT4037                   | 0.9978
# NCH!6650                  | NCH!6650                  | 0.9824
# QAY9700                   | QAY9700                   | 0.9880
# --------------------------------------------------------------------------------
# ==> Epoch 15 done in 9.2s | train_loss=0.1212  valid_loss=0.6826  valid_acc=69.10%
#
# no improvement for 2/100 epochs
#
# → Starting epoch 16  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# DR4467                    | DR4467                    | 0.9993
# WXW8900                   | WXW8900                   | 0.9903
# BPC!9173                  | BPC!9173                  | 0.9823
# KED9988                   | KED9986                   | 0.9757
# QAB7401J                  | QAB7401J                  | 0.9572
# --------------------------------------------------------------------------------
# ==> Epoch 16 done in 9.1s | train_loss=0.1130  valid_loss=0.6791  valid_acc=68.80%
#
# no improvement for 3/100 epochs
#
# → Starting epoch 17  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# PPR3334                   | PPP2294                   | 0.9472
# QAA4693Q                  | QAA4693D                  | 0.9753
# T/BF!6897                 | T/BF!6897                 | 0.9801
# QCH9191                   | QCH9191                   | 1.0000
# WJT342                    | WJT342                    | 0.9794
# --------------------------------------------------------------------------------
# ==> Epoch 17 done in 9.0s | train_loss=0.1119  valid_loss=0.6944  valid_acc=67.93%
#
# no improvement for 4/100 epochs
#
# → Starting epoch 18  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# VLT!8466                  | VLT!8466                  | 0.9317
# RW6398                    | RW6398                    | 0.9954
# JSD3681                   | JSD3681                   | 1.0000
# NEA5163                   | NEA5163                   | 0.9977
# BDA8389                   | BDA8389                   | 0.9997
# --------------------------------------------------------------------------------
# ==> Epoch 18 done in 9.0s | train_loss=0.1021  valid_loss=0.7101  valid_acc=68.51%
#
# no improvement for 5/100 epochs
#
# → Starting epoch 19  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# BHX5241                   | BHX5241                   | 0.9986
# ANM7267                   | ANM7267                   | 0.9959
# VM6611                    | VM6611                    | 0.9832
# KDB9833                   | KDB9833                   | 0.9831
# QAB7859A                  | QAB7859A                  | 0.9771
# --------------------------------------------------------------------------------
# ==> Epoch 19 done in 9.1s | train_loss=0.0675  valid_loss=0.7845  valid_acc=65.60%
#
# no improvement for 6/100 epochs
#
# → Starting epoch 20  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# JUK!276                   | JUK!276                   | 0.9969
# KDN!86                    | KDN!86                    | 0.9771
# MDV!8552                  | MDV!8562                  | 0.9778
# QCN1432                   | QCN1432                   | 0.9994
# SB!6436D                  | SB!6436D                  | 0.9554
# --------------------------------------------------------------------------------
# ==> Epoch 20 done in 9.1s | train_loss=0.0725  valid_loss=0.8355  valid_acc=69.10%
#
# no improvement for 7/100 epochs
#
# → Starting epoch 21  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# JXC679                    | JXC679                    | 0.9873
# QSP!5188                  | QSP!5188                  | 0.9900
# VLM6493                   | VLM6493                   | 0.9998
# QAA3955H                  | QAA3955H                  | 0.9964
# UNIMAS6119                | UNIMAS6119                | 0.9852
# --------------------------------------------------------------------------------
# ==> Epoch 21 done in 9.0s | train_loss=0.0615  valid_loss=0.7660  valid_acc=67.35%
#
# no improvement for 8/100 epochs
#
# → Starting epoch 22  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# BLR!9830                  | BLR!9830                  | 0.9450
# WXQ9376                   | WXQ9376                   | 0.9999
# QMS9397                   | QMS9397                   | 0.9977
# WFX7807                   | WFX7807                   | 0.9997
# BJA!2450                  | BJA!2450                  | 0.9768
# --------------------------------------------------------------------------------
# ==> Epoch 22 done in 9.1s | train_loss=0.0537  valid_loss=0.7512  valid_acc=66.76%
#
# no improvement for 9/100 epochs
#
# → Starting epoch 23  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# MCT8738                   | MCT8738                   | 0.9986
# PMU3220                   | PMU3220                   | 0.9959
# JLX6457                   | JLX6457                   | 0.9998
# BDP4954                   | BDP4954                   | 0.9977
# MBY7861                   | MBY7861                   | 0.9996
# --------------------------------------------------------------------------------
# ==> Epoch 23 done in 8.8s | train_loss=0.0559  valid_loss=0.8073  valid_acc=67.06%
#
# no improvement for 10/100 epochs
#
# → Starting epoch 24  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# WNL3044                   | WNL3044                   | 0.9998
# AHU7727                   | AHU7727                   | 0.9891
# SME489                    | SME489                    | 0.9881
# WJE4152                   | WJE4152                   | 0.9966
# WAW8593                   | WAW8593                   | 0.9980
# --------------------------------------------------------------------------------
# ==> Epoch 24 done in 8.7s | train_loss=0.0594  valid_loss=0.8336  valid_acc=68.22%
#
# no improvement for 11/100 epochs
#
# → Starting epoch 25  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# JSD809                    | JSD809                    | 0.9992
# QAB373                    | QAB373                    | 0.9844
# KAK!2474                  | KAK!2474                  | 0.9917
# QAA!9363P                 | QA!9363P                  | 0.9849
# SMJ1366                   | SMJ1366                   | 0.9861
# --------------------------------------------------------------------------------
# ==> Epoch 25 done in 8.9s | train_loss=0.0503  valid_loss=0.8380  valid_acc=65.60%
#
# no improvement for 12/100 epochs
#
# → Starting epoch 26  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QAA4693N                  | QAA4693N                  | 0.9998
# ZC!3873                   | ZC!3873                   | 0.9725
# WFH6380                   | WFH6380                   | 0.9953
# QAA2660J                  | QAA26603                  | 0.9754
# JNU8226                   | JNU8226                   | 0.9847
# --------------------------------------------------------------------------------
# ==> Epoch 26 done in 8.8s | train_loss=0.0847  valid_loss=0.8037  valid_acc=67.06%
#
# no improvement for 13/100 epochs
#
# → Starting epoch 27  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# BDW!7792                  | BDW!7792                  | 0.9937
# QAB8959B                  | QAB8959B                  | 0.9988
# WXQ9376                   | WXQ9376                   | 0.9941
# JLX!1296                  | JLX!1296                  | 0.9983
# WUG4754                   | WUG4754                   | 0.9998
# --------------------------------------------------------------------------------
# ==> Epoch 27 done in 8.7s | train_loss=0.0467  valid_loss=0.8374  valid_acc=66.76%
#
# no improvement for 14/100 epochs
#
# → Starting epoch 28  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# WCP8833                   | WCP8833                   | 0.9973
# QAA1783C                  | QAA1183C                  | 0.9443
# GOLD5564                  | GOLD5564                  | 0.9997
# PPR3334                   | PPR3334                   | 0.9895
# BDW!7792                  | BDW!7792                  | 0.9935
# --------------------------------------------------------------------------------
# ==> Epoch 28 done in 8.9s | train_loss=0.0434  valid_loss=0.8265  valid_acc=64.43%
#
# no improvement for 15/100 epochs
#
# → Starting epoch 29  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# HWE8782                   | HWE8782                   | 0.9998
# JVH9798                   | JVH9798                   | 0.9989
# PLH7338                   | PLH7338                   | 0.9999
# QCH7638                   | QCH7638                   | 0.9772
# WTP210                    | WTP210                    | 0.9999
# --------------------------------------------------------------------------------
# ==> Epoch 29 done in 8.8s | train_loss=0.0459  valid_loss=0.8696  valid_acc=65.01%
#
# no improvement for 16/100 epochs
#
# → Starting epoch 30  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QAA2705N                  | QAA2705N                  | 0.9999
# QAB8959B                  | QAB8959B                  | 0.9756
# WXT2433                   | WXT2433                   | 0.9817
# QPA3725                   | QPA3725                   | 1.0000
# VFK!8102                  | VFK!8102                  | 0.9861
# --------------------------------------------------------------------------------
# ==> Epoch 30 done in 8.6s | train_loss=0.0456  valid_loss=0.8150  valid_acc=64.72%
#
# no improvement for 17/100 epochs
#
# → Starting epoch 31  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# VKD2793                   | VKD94                     | 0.8553
# QRN!8598                  | QKN!8598                  | 0.9339
# QAA3323X                  | QAA3323X                  | 0.9891
# VFV!2696                  | VFV!2696                  | 0.9778
# MDV!8552                  | MDV!8552                  | 0.9815
# --------------------------------------------------------------------------------
# ==> Epoch 31 done in 8.8s | train_loss=0.0517  valid_loss=0.8727  valid_acc=65.01%
#
# no improvement for 18/100 epochs
#
# → Starting epoch 32  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# VGK9975                   | VGK9975                   | 1.0000
# BDA8389                   | BDA8389                   | 0.9991
# WTT!1097                  | WTT!1097                  | 0.9943
# SAB8373                   | SAB8373                   | 1.0000
# WFB!6925                  | WFB!6925                  | 0.9802
# --------------------------------------------------------------------------------
# ==> Epoch 32 done in 8.8s | train_loss=0.0376  valid_loss=0.8048  valid_acc=68.51%
#
# no improvement for 19/100 epochs
#
# → Starting epoch 33  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QAA5191E                  | QAA5191E                  | 0.9572
# QCG1016                   | QCG1016                   | 0.9914
# WLP6892                   | WLP6892                   | 0.9876
# QAA5191E                  | QAA5191E                  | 0.9952
# QLA8686                   | QLA8886                   | 0.9968
# --------------------------------------------------------------------------------
# ==> Epoch 33 done in 8.8s | train_loss=0.0340  valid_loss=0.8536  valid_acc=64.72%
#
# no improvement for 20/100 epochs
#
# → Starting epoch 34  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# VFM6378                   | VFM6378                   | 0.9995
# BNW5508                   | BNW5508                   | 0.9835
# T/N4541                   | T/N4541                   | 0.9620
# QRN!8598                  | BRN!8599                  | 0.9460
# QS4848D                   | QS4848D                   | 0.9984
# --------------------------------------------------------------------------------
# ==> Epoch 34 done in 8.8s | train_loss=0.0298  valid_loss=0.8959  valid_acc=67.06%
#
# no improvement for 21/100 epochs
#
# → Starting epoch 35  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# JRG6799                   | JRG6799                   | 0.9999
# SAC1674E                  | SAC1674E                  | 0.9963
# AGX7136                   | AGX7136                   | 0.9997
# QMU969                    | QMU969                    | 0.9997
# SM2004                    | SM2004                    | 0.9916
# --------------------------------------------------------------------------------
# ==> Epoch 35 done in 8.8s | train_loss=0.0331  valid_loss=0.7815  valid_acc=68.51%
#
# no improvement for 22/100 epochs
#
# → Starting epoch 36  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# BEP3409                   | BEP3409                   | 1.0000
# VLM3621                   | VLM3621                   | 0.9684
# PZ171M                    | PZ171M                    | 1.0000
# TCN!6262                  | TCN!6262                  | 0.9863
# QAB7672J                  | QAB7672J                  | 0.9977
# --------------------------------------------------------------------------------
# ==> Epoch 36 done in 8.7s | train_loss=0.0283  valid_loss=0.8857  valid_acc=67.93%
#
# no improvement for 23/100 epochs
#
# → Starting epoch 37  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QS1815T                   | QS1815T                   | 1.0000
# QAA!9363P                 | QAA!9363P                 | 0.9865
# XOIC29                    | XOIC29                    | 0.9997
# QCH7638                   | QCH7638                   | 0.9990
# VCQ7119                   | VCQ7119                   | 0.9998
# --------------------------------------------------------------------------------
# ==> Epoch 37 done in 8.7s | train_loss=0.0216  valid_loss=0.8464  valid_acc=66.47%
#
# no improvement for 24/100 epochs
#
# → Starting epoch 38  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# AJJ2772                   | AJJ2772                   | 0.9998
# QS5652S                   | QS5652S                   | 1.0000
# QCE3369                   | QCE3369                   | 0.9874
# AMN3223                   | AMN3223                   | 1.0000
# DFC4000                   | PFC4000                   | 0.9844
# --------------------------------------------------------------------------------
# ==> Epoch 38 done in 8.7s | train_loss=0.0229  valid_loss=0.8865  valid_acc=65.31%
#
# no improvement for 25/100 epochs
#
# → Starting epoch 39  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# VKP!3405                  | VKP!3405                  | 0.9968
# QRL1169                   | QRL1169                   | 0.9564
# QKF!8656                  | QKF!8656                  | 0.9948
# QP4444                    | QP4444                    | 0.9997
# QM2377M                   | QM2377M                   | 1.0000
# --------------------------------------------------------------------------------
# ==> Epoch 39 done in 8.7s | train_loss=0.0230  valid_loss=0.8755  valid_acc=67.06%
#
# no improvement for 26/100 epochs
#
# → Starting epoch 40  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QCR6004                   | QCR6004                   | 0.9999
# PRR6999                   | PRR6999                   | 0.9932
# VGN2263                   | VGN2263                   | 0.9999
# WQN8002                   | WQN8032                   | 0.9479
# QAB8000C                  | QAB8000C                  | 0.9923
# --------------------------------------------------------------------------------
# ==> Epoch 40 done in 8.8s | train_loss=0.0231  valid_loss=0.8650  valid_acc=66.47%
#
# no improvement for 27/100 epochs
#
# → Starting epoch 41  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# MU!6275                   | MU!6275                   | 0.9837
# BHP!7067                  | BHP!7067                  | 0.9551
# QPB3033                   | QPB3033                   | 0.9977
# WVL713                    | WVL713                    | 1.0000
# QAA6493D                  | QAA6493Q                  | 0.9993
# --------------------------------------------------------------------------------
# ==> Epoch 41 done in 8.8s | train_loss=0.0237  valid_loss=0.8418  valid_acc=67.93%
#
# no improvement for 28/100 epochs
#
# → Starting epoch 42  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QKV465                    | QKV465                    | 0.9954
# RAQ!7277                  | RAQ!7277                  | 0.9729
# NAP4617                   | NAP4617                   | 0.9997
# T/JA213                   | T/JA213                   | 0.9966
# KFT4037                   | KFT4037                   | 0.9998
# --------------------------------------------------------------------------------
# ==> Epoch 42 done in 8.8s | train_loss=0.0215  valid_loss=0.8667  valid_acc=68.51%
#
# no improvement for 29/100 epochs
#
# → Starting epoch 43  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QS9007H                   | QS9007H                   | 1.0000
# SYD7215                   | SYD7215                   | 0.9993
# MADANI!9369               | MADANI!9369               | 0.9732
# TCD!6404                  | TCD!6404                  | 0.9643
# QAA8020Q                  | QAA8020Q                  | 1.0000
# --------------------------------------------------------------------------------
# ==> Epoch 43 done in 8.7s | train_loss=0.0199  valid_loss=0.9122  valid_acc=68.51%
#
# no improvement for 30/100 epochs
#
# → Starting epoch 44  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# VGT9721                   | VGT9721                   | 0.9959
# QAA6411                   | QAA6411                   | 0.9711
# QAA!7135S                 | QAA!7135S                 | 0.9996
# QAB9731D                  | QAB9731D                  | 0.9974
# VBH6554                   | VBH6554                   | 0.9989
# --------------------------------------------------------------------------------
# ==> Epoch 44 done in 8.8s | train_loss=0.0160  valid_loss=0.8719  valid_acc=68.80%
#
# no improvement for 31/100 epochs
#
# → Starting epoch 45  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# TCF8978                   | TCF8978                   | 1.0000
# MCN!7929                  | MCN!7929                  | 0.9922
# QS!8095L                  | QS!8095L                  | 0.9921
# QAA8052M                  | QAA8052M                  | 0.9989
# BSE!6665                  | BSE!6665                  | 0.9948
# --------------------------------------------------------------------------------
# ==> Epoch 45 done in 8.8s | train_loss=0.0221  valid_loss=0.8873  valid_acc=68.51%
#
# no improvement for 32/100 epochs
#
# → Starting epoch 46  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# DAF7469                   | DAF7469                   | 0.9862
# QM!339L                   | QM!339L                   | 0.9788
# QAX!2076                  | QAX!2076                  | 0.9899
# WYX!1232                  | MYX!1232                  | 0.9577
# QCE1128                   | QCE1128                   | 0.9978
# --------------------------------------------------------------------------------
# ==> Epoch 46 done in 8.7s | train_loss=0.0277  valid_loss=0.8667  valid_acc=66.47%
#
# no improvement for 33/100 epochs
#
# → Starting epoch 47  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# KFL!5361                  | KFL!5361                  | 0.9970
# QAU4660                   | QAU4660                   | 0.9758
# VEQ6031                   | VEQ6031                   | 0.9963
# KDU!3612                  | KDU!3612                  | 0.9705
# QAC2127                   | QAC2127                   | 0.9932
# --------------------------------------------------------------------------------
# ==> Epoch 47 done in 9.0s | train_loss=0.0173  valid_loss=0.8867  valid_acc=67.35%
#
# no improvement for 34/100 epochs
#
# → Starting epoch 48  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# RS6069                    | RS6069                    | 0.9998
# VE9696                    | VE9696                    | 0.9811
# SMM4960                   | SMM4960                   | 0.9986
# MCN!7929                  | MCN!7929                  | 0.9945
# MDT7793                   | MDT7793                   | 0.9975
# --------------------------------------------------------------------------------
# ==> Epoch 48 done in 9.1s | train_loss=0.0151  valid_loss=0.8929  valid_acc=66.18%
#
# no improvement for 35/100 epochs
#
# → Starting epoch 49  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# KEN7203                   | KEN7203                   | 0.9999
# ABE8012                   | ABE8012                   | 1.0000
# QCK5599                   | QCK5599                   | 0.9999
# WKX!6755                  | WKX!6755                  | 0.9982
# WNC8559                   | WNC8559                   | 0.9999
# --------------------------------------------------------------------------------
# ==> Epoch 49 done in 9.1s | train_loss=0.0221  valid_loss=0.9523  valid_acc=64.72%
#
# no improvement for 36/100 epochs
#
# → Starting epoch 50  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QCJ5838                   | QCJ5838                   | 1.0000
# QTP9129                   | QTP9129                   | 0.9998
# DCS!3819                  | DCS!3819                  | 0.9960
# VLB768                    | VLB768                    | 1.0000
# W5384D                    | W5384D                    | 1.0000
# --------------------------------------------------------------------------------
# ==> Epoch 50 done in 9.0s | train_loss=0.0133  valid_loss=0.9168  valid_acc=67.06%
#
# no improvement for 37/100 epochs
#
# → Starting epoch 51  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# NBG!6607                  | NBG!6607                  | 0.9883
# JHN6661                   | JHN6661                   | 1.0000
# NDL4631                   | NDL4631                   | 0.9936
# NBG!6607                  | NBG!6607                  | 0.9998
# QP4444                    | QP4444                    | 0.9931
# --------------------------------------------------------------------------------
# ==> Epoch 51 done in 9.1s | train_loss=0.0128  valid_loss=0.9042  valid_acc=67.64%
#
# no improvement for 38/100 epochs
#
# → Starting epoch 52  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# VDV7199                   | VDV7199                   | 0.9937
# QB97                      | QB97                      | 0.9942
# QCJ2305                   | QCJ2305                   | 0.9826
# VK2618                    | VK2618                    | 1.0000
# VX2808                    | VX2808                    | 0.9942
# --------------------------------------------------------------------------------
# ==> Epoch 52 done in 9.0s | train_loss=0.0168  valid_loss=0.9046  valid_acc=67.93%
#
# no improvement for 39/100 epochs
#
# → Starting epoch 53  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QCB3330                   | QCB3330                   | 0.9855
# 104101DC                  | 104101DC                  | 0.9924
# JLY2201                   | JLY2201                   | 0.9998
# DCS3819                   | DCS3819                   | 1.0000
# QAK1881                   | QAK1881                   | 0.9930
# --------------------------------------------------------------------------------
# ==> Epoch 53 done in 8.9s | train_loss=0.0175  valid_loss=0.9332  valid_acc=68.80%
#
# no improvement for 40/100 epochs
#
# → Starting epoch 54  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# JNB388                    | JNB388                    | 1.0000
# QTS6613                   | QTS6613                   | 0.9865
# VGX3935                   | VGX3935                   | 1.0000
# QS437C                    | QS437C                    | 0.9999
# JSB675                    | JSB675                    | 0.9998
# --------------------------------------------------------------------------------
# ==> Epoch 54 done in 8.9s | train_loss=0.0155  valid_loss=0.9171  valid_acc=68.51%
#
# no improvement for 41/100 epochs
#
# → Starting epoch 55  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QKS8556                   | QKS8556                   | 0.9971
# LE7021                    | LE7021                    | 1.0000
# QAA8133S                  | QAA8133S                  | 0.9972
# QAA8823M                  | QAA8823M                  | 0.9997
# WA868H                    | WA868H                    | 0.9991
# --------------------------------------------------------------------------------
# ==> Epoch 55 done in 8.9s | train_loss=0.0169  valid_loss=0.9178  valid_acc=67.35%
#
# no improvement for 42/100 epochs
#
# → Starting epoch 56  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QDB!448                   | QDB!448                   | 0.9735
# T/AA823                   | T/AA823                   | 0.9991
# DEY!9981                  | DEY!981                   | 0.9955
# VEJ6785                   | VEJ6785                   | 0.9999
# AGX7136                   | AGX7136                   | 1.0000
# --------------------------------------------------------------------------------
# ==> Epoch 56 done in 9.0s | train_loss=0.0199  valid_loss=0.9171  valid_acc=68.22%
#
# no improvement for 43/100 epochs
#
# → Starting epoch 57  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# WFR9497                   | WFR9497                   | 0.9996
# AMT5830                   | AMT5830                   | 0.9877
# W5870P                    | W5870P                    | 0.9968
# FC9447                    | FC9447                    | 0.9854
# QS!8095L                  | QS!8095L                  | 0.9954
# --------------------------------------------------------------------------------
# ==> Epoch 57 done in 9.2s | train_loss=0.0160  valid_loss=0.9506  valid_acc=67.93%
#
# no improvement for 44/100 epochs
#
# → Starting epoch 58  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QCP6838                   | QCP6838                   | 0.9985
# QCB3330                   | QCB3330                   | 0.9981
# WC1484R                   | WC1484R                   | 1.0000
# WA3593F                   | WA3593F                   | 0.9998
# QKS8556                   | QKS8556                   | 1.0000
# --------------------------------------------------------------------------------
# ==> Epoch 58 done in 9.3s | train_loss=0.0134  valid_loss=0.9540  valid_acc=67.06%
#
# no improvement for 45/100 epochs
#
# → Starting epoch 59  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# SB218F                    | SB218F                    | 0.9998
# QKH1409                   | QKH1409                   | 0.9696
# ANU7888                   | ANU7888                   | 0.9996
# QMU595                    | QMU59                     | 0.9931
# FD10                      | FD10                      | 0.9971
# --------------------------------------------------------------------------------
# ==> Epoch 59 done in 9.2s | train_loss=0.0132  valid_loss=0.9877  valid_acc=67.64%
#
# no improvement for 46/100 epochs
#
# → Starting epoch 60  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# JHW4868                   | JHW4868                   | 0.9940
# WFB!6925                  | WFB!6925                  | 0.9781
# QS5007G                   | QS5007G                   | 0.9998
# QAB9218                   | QAB9218                   | 0.9996
# VKP                       | VKP                       | 0.9884
# --------------------------------------------------------------------------------
# ==> Epoch 60 done in 9.0s | train_loss=0.0145  valid_loss=0.9225  valid_acc=68.80%
#
# no improvement for 47/100 epochs
#
# → Starting epoch 61  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# JWW9278                   | JWW9278                   | 1.0000
# ...
#
# → Starting epoch 94  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QAA6659V                  | QAA6659V                  | 0.9998
# QRR9945                   | QRR9945                   | 0.9853
# QAB371C                   | QAB371C                   | 0.9840
# QAB3641H                  | QAB3641H                  | 0.9994
# 426                       | 426                       | 0.9999
# --------------------------------------------------------------------------------
# ==> Epoch 94 done in 9.4s | train_loss=0.0099  valid_loss=0.9071  valid_acc=67.35%
#
# no improvement for 81/100 epochs
#
# → Starting epoch 95  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QSP!5188                  | QSP!5188                  | 0.9861
# JLC!8890                  | JLC!8890                  | 0.9942
# QS2878F                   | QS2878F                   | 0.9958
# VHW!6283                  | VHW!6283                  | 0.9942
# VEQ6291                   | VEQ6291                   | 0.9999
# --------------------------------------------------------------------------------
# ==> Epoch 95 done in 9.2s | train_loss=0.0093  valid_loss=0.9075  valid_acc=67.64%
#
# no improvement for 82/100 epochs
#
# → Starting epoch 96  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# AHA3878                   | AHA3878                   | 0.9996
# QS8621R                   | QS8621R                   | 1.0000
# VAX9343                   | VAX9343                   | 1.0000
# MAM!6063                  | MAM!6063                  | 0.9664
# WCG!7220                  | WCG!7220                  | 0.9960
# --------------------------------------------------------------------------------
# ==> Epoch 96 done in 9.2s | train_loss=0.0060  valid_loss=0.9344  valid_acc=69.39%
#
# no improvement for 83/100 epochs
#
# → Starting epoch 97  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# SA24M                     | SA24M                     | 1.0000
# WKR!8393                  | WKR!8393                  | 0.9888
# QAR6858                   | QAR6858                   | 0.9947
# JRG!3303                  | JRG!3303                  | 0.9999
# CDR5920                   | CDR5920                   | 1.0000
# --------------------------------------------------------------------------------
# ==> Epoch 97 done in 9.1s | train_loss=0.0075  valid_loss=0.9600  valid_acc=66.47%
#
# no improvement for 84/100 epochs
#
# → Starting epoch 98  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QS4332S                   | QS4332S                   | 1.0000
# KEG!9999                  | KEG!9999                  | 0.9835
# VNP3597                   | VNP3597                   | 0.9956
# QPB615                    | QPB615                    | 0.9836
# JVB5509                   | JVB5509                   | 0.9999
# --------------------------------------------------------------------------------
# ==> Epoch 98 done in 9.1s | train_loss=0.0093  valid_loss=0.9581  valid_acc=67.93%
#
# no improvement for 85/100 epochs
#
# → Starting epoch 99  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QRU2519                   | QRU2519                   | 0.9992
# AMT5830                   | AMT5830                   | 1.0000
# DCS3819                   | DCS3819                   | 0.9996
# QCA2869                   | QCA2869                   | 0.9999
# WSL8189                   | WSL8189                   | 0.9872
# --------------------------------------------------------------------------------
# ==> Epoch 99 done in 9.2s | train_loss=0.0094  valid_loss=0.9428  valid_acc=67.06%
#
# no improvement for 86/100 epochs
#
# → Starting epoch 100  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QKM!9995                  | QKM!9995                  | 0.9989
# WXX!2093                  | WXX!2093                  | 0.9785
# WB3407Q                   | WB3407Q                   | 0.9991
# QM2377M                   | QM2477M                   | 0.9983
# BDP4954                   | BDP4954                   | 0.9945
# --------------------------------------------------------------------------------
# ==> Epoch 100 done in 9.0s | train_loss=0.0128  valid_loss=1.0385  valid_acc=66.47%
#
# no improvement for 87/100 epochs
#
# → Starting epoch 101  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QAA!9381W                 | QAA!9381W                 | 0.9887
# WWL9209                   | WWL9209                   | 1.0000
# QAA9201H                  | QAA9201H                  | 0.9999
# PRF6163                   | PRF6163                   | 0.9999
# WKR!8393                  | WKR!8393                  | 0.9780
# --------------------------------------------------------------------------------
# ==> Epoch 101 done in 9.0s | train_loss=0.0065  valid_loss=1.0958  valid_acc=66.76%
#
# no improvement for 88/100 epochs
#
# → Starting epoch 102  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QKV465                    | QKV465                    | 0.9822
# QKL88                     | QKL88                     | 0.9993
# MD3426Q                   | MD3426Q                   | 0.9989
# MDJ50                     | MDJ50                     | 0.9997
# AJA!8335                  | AJA!8335                  | 0.9646
# --------------------------------------------------------------------------------
# ==> Epoch 102 done in 9.0s | train_loss=0.0089  valid_loss=1.0453  valid_acc=67.35%
#
# no improvement for 89/100 epochs
#
# → Starting epoch 103  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# BLR!9830                  | BLR!9830                  | 0.9950
# JRK1292                   | JRK1292                   | 0.9829
# QAA844Q                   | QAA844Q                   | 0.9958
# QCT7867                   | QCT7867                   | 0.9997
# NCQ2205                   | NCQ2205                   | 1.0000
# --------------------------------------------------------------------------------
# ==> Epoch 103 done in 9.0s | train_loss=0.0080  valid_loss=0.9858  valid_acc=67.93%
#
# no improvement for 90/100 epochs
#
# → Starting epoch 104  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# AJH9714                   | AJH9714                   | 0.9999
# QAL8533                   | QAL8533                   | 1.0000
# T/AA823                   | T/AA823                   | 0.9927
# QCN8327                   | QCN8327                   | 1.0000
# QAB9218                   | QAB9218                   | 1.0000
# --------------------------------------------------------------------------------
# ==> Epoch 104 done in 9.0s | train_loss=0.0066  valid_loss=1.0420  valid_acc=67.06%
#
# no improvement for 91/100 epochs
#
# → Starting epoch 105  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QTQ8857                   | QTQ8857                   | 1.0000
# CDR5920                   | CDR5920                   | 0.9998
# PLX8764                   | PLX8764                   | 0.9998
# NDD6299                   | NDD6299                   | 0.9996
# QAB9515H                  | QAB9515H                  | 0.9993
# --------------------------------------------------------------------------------
# ==> Epoch 105 done in 9.0s | train_loss=0.0063  valid_loss=1.0255  valid_acc=68.22%
#
# no improvement for 92/100 epochs
#
# → Starting epoch 106  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QSV1707                   | QSV1707                   | 0.9891
# W763L                     | W763L                     | 1.0000
# WDC!4844                  | WDC!4844                  | 0.9909
# WQN4163                   | WQN4163                   | 0.9995
# BFP7470                   | BFP7470                   | 0.9956
# --------------------------------------------------------------------------------
# ==> Epoch 106 done in 9.0s | train_loss=0.0063  valid_loss=1.0034  valid_acc=67.06%
#
# no improvement for 93/100 epochs
#
# → Starting epoch 107  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# ADU7533                   | ADU7533                   | 0.9988
# QAW2391                   | QAW2391                   | 0.9909
# VHV!300                   | VHV!300                   | 0.9985
# QCS!8822                  | QCS!8822                  | 0.9735
# QBG411                    | QBG411                    | 0.9818
# --------------------------------------------------------------------------------
# ==> Epoch 107 done in 9.0s | train_loss=0.0064  valid_loss=1.0146  valid_acc=67.06%
#
# no improvement for 94/100 epochs
#
# → Starting epoch 108  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QM203E                    | QM203E                    | 0.9992
# WQX3834                   | WQX3834                   | 1.0000
# QCS5289                   | QCS5289                   | 1.0000
# SMJ1366                   | SMJ1366                   | 0.9999
# VH4089                    | VH4089                    | 1.0000
# --------------------------------------------------------------------------------
# ==> Epoch 108 done in 9.0s | train_loss=0.0053  valid_loss=1.0412  valid_acc=65.31%
#
# no improvement for 95/100 epochs
#
# → Starting epoch 109  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# VJG3205                   | VJG3205                   | 0.9795
# QS8621R                   | QS8621R                   | 1.0000
# PAC!6969                  | PAC!6969                  | 0.9812
# AMR9464                   | AMR9464                   | 0.9979
# QAP8890                   | QAP8890                   | 1.0000
# --------------------------------------------------------------------------------
# ==> Epoch 109 done in 9.1s | train_loss=0.0046  valid_loss=1.0763  valid_acc=64.72%
#
# no improvement for 96/100 epochs
#
# → Starting epoch 110  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# NDP9388                   | NDP9388                   | 0.9995
# VEQ6031                   | VEQ6031                   | 1.0000
# QAA8801X                  | QAA8801X                  | 1.0000
# JVH9798                   | JVH9798                   | 1.0000
# QMU595                    | QMU595                    | 0.9999
# --------------------------------------------------------------------------------
# ==> Epoch 110 done in 9.0s | train_loss=0.0069  valid_loss=1.0988  valid_acc=66.47%
#
# no improvement for 97/100 epochs
#
# → Starting epoch 111  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# NBC771                    | NBC771                    | 0.9953
# QTM8880                   | QTN8880                   | 0.9954
# AM9232                    | AM9232                    | 0.9988
# VEB806                    | VEB806                    | 0.9947
# MCR5505                   | MCR5505                   | 1.0000
# --------------------------------------------------------------------------------
# ==> Epoch 111 done in 9.0s | train_loss=0.0068  valid_loss=1.0601  valid_acc=65.89%
#
# no improvement for 98/100 epochs
#
# → Starting epoch 112  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QCJ6959                   | QCJ6959                   | 0.9990
# AMN3223                   | AMN3223                   | 0.9998
# QAA8656V                  | QAA8656V                  | 0.9999
# WXX!2093                  | WXX!2093                  | 0.9818
# QAB3187H                  | QAB3187H                  | 1.0000
# --------------------------------------------------------------------------------
# ==> Epoch 112 done in 9.1s | train_loss=0.0076  valid_loss=1.0633  valid_acc=68.51%
#
# no improvement for 99/100 epochs
#
# → Starting epoch 113  (printing every 172 iters)
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QS3366B                   | QS3366B                   | 1.0000
# VS5705                    | VS5705                    | 0.9906
# TAM!408                   | TYM!408                   | 0.9565
# WDQ1009                   | WDQ1009                   | 1.0000
# BNF8126                   | BNF8126                   | 0.9998
# --------------------------------------------------------------------------------
# ==> Epoch 113 done in 9.0s | train_loss=0.0101  valid_loss=1.0043  valid_acc=67.06%
#
# no improvement for 100/100 epochs
#
# 🔚 Early stopping: val_acc hasn't improved for 100 epochs.

# %%
clean_history = {
  'epoch':      history['epoch'],
  'train_loss': [x.cpu().item() if hasattr(x, 'cpu') else x for x in history['train_loss']],
  'val_loss':   [x.cpu().item() if hasattr(x, 'cpu') else x for x in history['val_loss']],
  'val_acc':    [x.cpu().item() if hasattr(x, 'cpu') else x for x in history['val_acc']],
}
df = pd.DataFrame(clean_history)
display(df)

plt.figure()
plt.plot(df['epoch'], df['train_loss'], label='Train Loss')
plt.plot(df['epoch'], df['val_loss'],   label='Val Loss')
plt.xlabel('Epoch'); plt.ylabel('Loss'); plt.legend()
plt.title('Loss over Epochs')
plt.show()

plt.figure()
plt.plot(df['epoch'], df['val_acc'],   label='Val Accuracy')
plt.xlabel('Epoch'); plt.ylabel('Accuracy (%)'); plt.legend()
plt.title('Val Accuracy over Epochs')
plt.show()
# Out:
#      epoch  train_loss  val_loss    val_acc
# 0        1    1.828067  0.506218  60.641399
# 1        2    1.128554  0.416136  68.513120
# 2        3    0.952304  0.428540  68.513120
# 3        4    0.811681  0.468594  65.597668
# 4        5    0.668607  0.465403  67.055394
# ..     ...         ...       ...        ...
# 108    109    0.004638  1.076302  64.723032
# 109    110    0.006876  1.098817  66.472303
# 110    111    0.006826  1.060102  65.889213
# 111    112    0.007567  1.063325  68.513120
# 112    113    0.010071  1.004321  67.055394
#
# [113 rows x 4 columns]

# %%
# # ─── Cell 9: ONNX export via isolated inference head ─────────────────────────
# import torch

# class CRNNInference(torch.nn.Module):
#     def __init__(self, crnn, max_len):
#         super().__init__()
#         # use exactly the names printed out by your inspection
#         self.Transformation     = crnn.Transformation
#         self.FeatureExtraction = crnn.FeatureExtraction
#         self.AdaptiveAvgPool    = crnn.AdaptiveAvgPool
#         self.SequenceModeling   = crnn.SequenceModeling
#         self.Prediction         = crnn.Prediction
#         self.max_len           = max_len
#         # adjust this if your converter stores start-token under a different key
#         self.start_id          = crnn.converter.dict['[GO]']

#     def forward(self, image):
#         # 1) Spatial‐transformer + feature CNN
#         x = self.Transformation(image)                     # [B, C, H, W]
#         x = self.FeatureExtraction(x)                      # [B, C, H, W]

#         # 2) Pool down height to 1
#         x = self.AdaptiveAvgPool(x)                        # [B, C, 1, W]
#         x = x.squeeze(2)                                   # [B, C, W]
#         x = x.permute(0, 2, 1)                             # [B, W, C]

#         # 3) 2‐layer BiLSTM
#         contextual = self.SequenceModeling(x)              # [B, W, hidden]

#         # 4) Dummy “[GO]” token vector
#         B = contextual.size(0)
#         dummy_text = torch.full(
#             (B,),
#             self.start_id,
#             dtype=torch.long,
#             device=image.device
#         )  # shape [B]

#         # 5) Attention decoder (inference path)
#         return self.Prediction(
#             batch_H           = contextual,
#             text              = dummy_text,
#             is_train          = False,
#             batch_max_length  = self.max_len
#         )

# # Wrap and export
# inference_model = CRNNInference(model, BATCH_MAX_LENGTH).eval()
# dummy_img       = torch.randn(1, INPUT_CHANNEL, IMG_HEIGHT, IMG_WIDTH, device=device)

# torch.onnx.export(
#     inference_model,
#     dummy_img,
#     "best_attention_crnn.onnx",
#     input_names   = ['image'],
#     output_names  = ['logits'],
#     dynamic_axes  = {
#         'image':  {0: 'batch'},
#         'logits': {0: 'batch', 1: 'time'}
#     },
#     opset_version = 13,
# )

# print("✅ Exported best_attention_crnn.onnx")

# %% [markdown]
# # DUMP

# %%
# # ─── cell 6: attention‐based training loop ──────────────────────────────────────
# for epoch in range(1, NUM_EPOCHS+1):
#     print(f"→ Starting epoch {epoch}  (printing every {PRINT_EVERY} iters)")
#     model.train()
#     epoch_loss = Averager()
#     start      = time.time()

#     for i, (images, texts) in enumerate(train_loader, 1):
#         images = images.to(device)

#         # encode with [GO] & [s]; also get lengths
#         text, length = converter.encode(texts, batch_max_length=BATCH_MAX_LENGTH)
#         text_input  = text[:, :-1].to(device)   # drop final [s]
#         text_target = text[:,  1:].to(device)   # everything after [GO]

#         # forward + loss
#         preds = model(images,
#                       text=text_input,
#                       is_train=True,
#                       batch_max_length=BATCH_MAX_LENGTH)  # [B, S, C]
#         B, S, C = preds.size()
#         loss = criterion(
#             preds.view(B * S, C),
#             text_target.contiguous().view(B * S)
#         )

#         optimizer.zero_grad()
#         loss.backward()
#         torch.nn.utils.clip_grad_norm_(model.parameters(), 5)
#         optimizer.step()
#         epoch_loss.add(loss)

#         if i % PRINT_EVERY == 0 or i == 1:
#             print(f"[Epoch {epoch}] iter {i}/{len(train_loader)}, avg loss: {epoch_loss.val():.4f}", flush=True)

#             # quick greedy‐decode
#             with torch.no_grad():
#                 probs        = preds.softmax(2)           # [B, S, C]
#                 max_vals, max_inds = probs.max(2)         # [B, S]
#                 pred_strs    = converter.decode(max_inds, length)
#                 pred_strs    = [s.split('[s]')[0] for s in pred_strs]

#             # print a mini‐table
#             print("-" * 80)
#             print(f"{'Ground Truth':25s} | {'Prediction':25s} | AvgConfidence")
#             print("-" * 80)
#             for gt, pr, conf_seq in zip(texts[:5], pred_strs[:5], max_vals[:5]):
#                 conf = conf_seq.mean().item()
#                 print(f"{gt:25s} | {pr:25s} | {conf:0.4f}")
#             print("-" * 80)

#     # end‐of‐epoch validation
#     val_loss, val_acc = validate(model, val_loader)
#     elapsed = time.time() - start
#     print(f"==> Epoch {epoch} done in {elapsed:.1f}s | "
#           f"train_loss={epoch_loss.val():.4f}"
#           f"  valid_loss={val_loss:.4f}  valid_acc={val_acc:.2f}%\n")

# %%
# # ─── Cell 6: training w/ history, best‐model saving ───

# # hyper‐params
# best_val_acc    = 0.0
# history         = {'epoch': [], 'train_loss': [], 'val_loss': [], 'val_acc': []}

# for epoch in range(1, NUM_EPOCHS+1):
#     print(f"→ Starting epoch {epoch}  (printing every {PRINT_EVERY} iters)")
#     model.train()
#     epoch_loss = Averager()
#     start = time.time()

#     # ─── training ─────────────────────────────────────────────────────────────
#     for i, (images, texts) in enumerate(train_loader, 1):
#         images = images.to(device)

#         text, length   = converter.encode(texts, batch_max_length=MAX_LABEL_LENGTH)
#         text_input     = text[:, :-1].to(device)
#         text_target    = text[:,  1:].to(device)

#         preds = model(
#             images,
#             text=text_input,
#             is_train=True,
#             batch_max_length=MAX_LABEL_LENGTH
#         )  # [B, S, C]
#         B, S, C = preds.size()
#         loss = criterion(
#             preds.view(B * S, C),
#             text_target.contiguous().view(B * S)
#         )

#         optimizer.zero_grad()
#         loss.backward()
#         torch.nn.utils.clip_grad_norm_(model.parameters(), 5)
#         optimizer.step()
#         epoch_loss.add(loss)

#         # mini‐table prints
#         if i % PRINT_EVERY == 0:
#             print(f"[Epoch {epoch}] iter {i}/{len(train_loader)}, avg loss: {epoch_loss.val():.4f}", flush=True)
#             with torch.no_grad():
#                 probs     = preds.softmax(2)
#                 max_vals, max_inds = probs.max(2)
#                 pred_strs = converter.decode(max_inds, length)
#                 pred_strs = [s.split('[s]')[0] for s in pred_strs]

#             print("-" * 80)
#             print(f"{'Ground Truth':25s} | {'Prediction':25s} | AvgConfidence")
#             print("-" * 80)
#             for gt, pr, conf_seq in zip(texts[:5], pred_strs[:5], max_vals[:5]):
#                 conf = conf_seq.mean().item()
#                 print(f"{gt:25s} | {pr:25s} | {conf_seq.mean().item():.4f}")
#             print("-" * 80)

#     # ─── validation ────────────────────────────────────────────────────────────
#     val_loss, val_acc = validate(model, val_loader)
#     elapsed = time.time() - start
#     train_l = epoch_loss.val()
#     print(f"==> Epoch {epoch} done in {elapsed:.1f}s | "
#           f"train_loss={train_l:.4f}  valid_loss={val_loss:.4f}  valid_acc={val_acc:.2f}%\n")

#     # ─── record history & save best ──────────────────────────────────────────
#     history['epoch'].append(epoch)
#     history['train_loss'].append(train_l)
#     history['val_loss'].append(val_loss)
#     history['val_acc'].append(val_acc)

#     if val_acc > best_val_acc:
#         best_val_acc = val_acc
#         torch.save(model.state_dict(), "best_attention_crnn_!.pth")
#         print(f"💾 New best model saved (epoch {epoch}, val_acc={val_acc:.2f}%)\n")
