# %%
# cell 1
import os
import time
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import pandas as pd
import random
import numpy as np

from config import (IMG_HEIGHT, IMG_WIDTH, NUM_FIDUCIAL,
                    INPUT_CHANNEL, OUTPUT_CHANNEL, HIDDEN_SIZE,
                    CHARACTERS, MAX_LABEL_LENGTH)
from dataset import LmdbDataset, AlignCollate
# from utils import CTCLabelConverter, Averager
from utils import AttnLabelConverter, Averager
from model import CRNN

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print("Running on", device)
# Out:
# Running on cuda

# %%
# ─── cell 0: reproducibility ────────────────────────────────────────────────
SEED = 300188
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)

# Make cuDNN deterministic (slower but reproducible)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

print(f"All seeds set to {SEED}, cudnn.deterministic={torch.backends.cudnn.deterministic}")
# Out:
# All seeds set to 300188, cudnn.deterministic=True

# %%
# cell 2
# paths to your LMDBs
train_lmdb = "v4_lmdb_data_!/train"
val_lmdb   = "v4_lmdb_data_!/val"

# instantiate datasets
train_dataset = LmdbDataset(train_lmdb)
val_dataset   = LmdbDataset(val_lmdb)

# collate_fn resizes + normalizes
collate_fn = AlignCollate(
    imgH=IMG_HEIGHT, imgW=IMG_WIDTH, keep_ratio_with_pad=False
)

# loaders
BATCH_SIZE = 32
train_loader = DataLoader(
    train_dataset, batch_size=BATCH_SIZE, shuffle=True,
    num_workers=0, collate_fn=collate_fn, pin_memory=True
)
val_loader = DataLoader(
    val_dataset, batch_size=BATCH_SIZE, shuffle=False,
    num_workers=0, collate_fn=collate_fn, pin_memory=True
)

print(f"{len(train_dataset)} train / {len(val_dataset)} val samples")
# Out:
# Loaded 1372 valid samples from v4_lmdb_data_!/train
# Loaded 343 valid samples from v4_lmdb_data_!/val
# 1372 train / 343 val samples

# %%
batch = next(iter(train_loader))
texts = batch[1]             # list of ground‑truth strings
print("First 20 labels from loader:")
print(texts[:20])
# Out:
# First 20 labels from loader:
# ['PPA!4817', 'VFT8338', 'QBE9168', 'RAU!369', 'QS3469R', 'VGX3935', 'WXM1116', 'VES!3744', 'BKJ!3569', 'WNH553', 'VJL3065', 'QAA6162E', 'QS9698N', 'QAB7672J', 'VJY4021', 'BKB!9642', 'QAA5515N', 'QAB8907B', 'SYQ!44', 'PLH7338']

# %%
converter   = AttnLabelConverter(CHARACTERS)
num_classes = len(converter.character)   # includes [GO] and [s]

model = CRNN(
    IMG_HEIGHT,      # imgH
    IMG_WIDTH,       # imgW
    INPUT_CHANNEL,   # input_channel
    OUTPUT_CHANNEL,  # output_channel
    HIDDEN_SIZE,     # hidden_size
    num_classes,     # num_classes (with GO/s)
    True,            # use_attention
    NUM_FIDUCIAL     # num_fiducial
).to(device)

criterion = nn.CrossEntropyLoss(ignore_index=0).to(device)
optimizer = optim.Adadelta(model.parameters(), lr=1.0)

# %%
# ─── cell 4: validate (Attention) ─────────────────────────────────────────────
NUM_EPOCHS       = 500
PRINT_EVERY      = len(train_dataset) // BATCH_SIZE + 1
PATIENCE       = 100          # stop if no val_acc ↑ for 50 epochs

def validate(model, loader):
    model.eval()
    avg_loss = Averager()
    correct, total = 0, 0

    with torch.no_grad():
        for images, texts in loader:
            images = images.to(device)

            # encode full text → shape [B, L+1], plus lengths
            text, length = converter.encode(texts, batch_max_length=MAX_LABEL_LENGTH)
            text_input  = text[:, :-1].to(device)  # drop final [s]
            text_target = text[:,  1:].to(device)  # everything after [GO]

            # forward
            preds = model(images, text_input, is_train=False,
                          batch_max_length=MAX_LABEL_LENGTH)
            B, S, C = preds.size()

            # cross‐entropy over (B×S) predictions
            loss = criterion(
                preds.view(B * S, C),
                text_target.contiguous().view(B * S)
            )
            avg_loss.add(loss)

            # greedy decode
            _, pred_inds = preds.max(2)                   # [B, S]
            pred_strs = converter.decode(pred_inds, length)  # pass length

            # strip off anything after the "[s]" token
            pred_strs = [s.split('[s]')[0] for s in pred_strs]

            total += len(texts)
            correct += sum(p == g for p, g in zip(pred_strs, texts))

    acc = correct / total * 100
    return avg_loss.val(), acc

# %%
# ─── cell 5: load pretrained CTC weights (skip old Prediction head) ────────────

from collections import OrderedDict

orig      = torch.load("pretrained_model/TPS-ResNet-BiLSTM-Attn.pth", map_location=device)
# strip off the "module." prefix if you wrapped in DataParallel
stripped  = OrderedDict((k[len("module."):], v)
                        for k, v in orig.items()
                        if k.startswith("module."))

own = model.state_dict()
for k, v in stripped.items():
    # skip the old attention head entirely
    if k.startswith("Prediction."):
        continue
    # only overwrite if shapes match
    if k in own and v.size() == own[k].size():
        own[k] = v

model.load_state_dict(own)
print("✅ Loaded pretrained Attn weights")
# Out:
# ✅ Loaded pretrained Attn weights

# %%
# ─── Cell 6: training w/ history, best‐model saving + EARLY STOPPING ───

# hyper‑params
best_val_acc   = 0.0
history        = {'epoch': [], 'train_loss': [], 'val_loss': [], 'val_acc': []}

patience_cnt   = 0           # how many epochs since last improvement

for epoch in range(1, NUM_EPOCHS+1):
    print(f"→ Starting epoch {epoch}  (printing every {PRINT_EVERY} iters)")
    model.train()
    epoch_loss = Averager()
    start = time.time()

    # ─── training ──────────────────────────────────────────────────────────
    for i, (images, texts) in enumerate(train_loader, 1):
        images = images.to(device)

        text, length   = converter.encode(texts, batch_max_length=MAX_LABEL_LENGTH)
        text_input     = text[:, :-1].to(device)
        text_target    = text[:,  1:].to(device)

        preds = model(
            images,
            text=text_input,
            is_train=True,
            batch_max_length=MAX_LABEL_LENGTH
        )  # [B, S, C]
        B, S, C = preds.size()
        loss = criterion(
            preds.view(B * S, C),
            text_target.contiguous().view(B * S)
        )

        optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 5)
        optimizer.step()
        epoch_loss.add(loss)

        # mini‐table prints
        if i % PRINT_EVERY == 0:
            print(f"[Epoch {epoch}] iter {i}/{len(train_loader)}, avg loss: {epoch_loss.val():.4f}", flush=True)
            with torch.no_grad():
                probs     = preds.softmax(2)
                max_vals, max_inds = probs.max(2)
                pred_strs = converter.decode(max_inds, length)
                pred_strs = [s.split('[s]')[0] for s in pred_strs]

            print("-" * 80)
            print(f"{'Ground Truth':25s} | {'Prediction':25s} | AvgConfidence")
            print("-" * 80)
            for gt, pr, conf_seq in zip(texts[:5], pred_strs[:5], max_vals[:5]):
                conf = conf_seq.mean().item()
                print(f"{gt:25s} | {pr:25s} | {conf_seq.mean().item():.4f}")
            print("-" * 80)

    # ─── validation ────────────────────────────────────────────────────────
    val_loss, val_acc = validate(model, val_loader)
    elapsed   = time.time() - start
    train_l   = epoch_loss.val()
    print(f"==> Epoch {epoch} done in {elapsed:.1f}s | "
          f"train_loss={train_l:.4f}  valid_loss={val_loss:.4f}  valid_acc={val_acc:.2f}%\n")

    # ─── record history ───────────────────────────────────────────────────
    history['epoch'].append(epoch)
    history['train_loss'].append(train_l)
    history['val_loss'].append(val_loss)
    history['val_acc'].append(val_acc)

    # ─── best‑model tracking & early‑stopping logic ───────────────────────
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        torch.save(model.state_dict(), "best_attention_crnn_!.pth")
        print(f"💾 New best model saved (epoch {epoch}, val_acc={val_acc:.2f}%)\n")
        patience_cnt = 0                          # reset counter
    else:
        patience_cnt += 1
        print(f"no improvement for {patience_cnt}/{PATIENCE} epochs\n")
        if patience_cnt >= PATIENCE:
            print(f"🔚 Early stopping: val_acc hasn't improved for {PATIENCE} epochs.")
            break
# Out:
# → Starting epoch 1  (printing every 43 iters)
# [Epoch 1] iter 43/43, avg loss: 3.1271
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QKS8556                   | QA!!11111111              | 0.1308
# QCP6838                   | QAA888777777777777777     | 0.1368
# QAA9552A                  | AAAA42211111111111111     | 0.1554
# MU!6275                   | Q!!!!!!77777777777777     | 0.1672
# VJB1968                   | QA1111111111111111111     | 0.2081
# --------------------------------------------------------------------------------
# ==> Epoch 1 done in 3.6s | train_loss=3.1271  valid_loss=2.8414  valid_acc=0.00%
#
# no improvement for 1/100 epochs
#
# → Starting epoch 2  (printing every 43 iters)
# [Epoch 2] iter 43/43, avg loss: 2.5201
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# WXP3314                   | QB333333                  | 0.4012
# QAW2391                   | QQB33333                  | 0.3396
# ALN8722                   | QW2222222                 | 0.4015
# QAA3440                   | QAA444                    | 0.4044
# QAA3618X                  | QAA111                    | 0.3178
# --------------------------------------------------------------------------------
# ==> Epoch 2 done in 3.5s | train_loss=2.5201  valid_loss=2.2693  valid_acc=0.00%
#
# no improvement for 2/100 epochs
#
# → Starting epoch 3  (printing every 43 iters)
# [Epoch 3] iter 43/43, avg loss: 2.1377
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QAH1581                   | QA511                     | 0.3421
# QKS8556                   | QS5555                    | 0.4561
# BNY!4363                  | QA!!66                    | 0.4326
# PHY2884                   | QB888                     | 0.3785
# WB!2177K                  | QT7777                    | 0.4269
# --------------------------------------------------------------------------------
# ==> Epoch 3 done in 3.4s | train_loss=2.1377  valid_loss=2.0709  valid_acc=0.00%
#
# no improvement for 3/100 epochs
#
# → Starting epoch 4  (printing every 43 iters)
# [Epoch 4] iter 43/43, avg loss: 1.8440
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QCN8327                   | QCC88877                  | 0.5376
# SWK426                    | VKL46666                  | 0.4165
# QAM6622                   | QMM66622                  | 0.5126
# QTN3878                   | QAN388888                 | 0.4413
# PLM!1311                  | QA!!!1111                 | 0.4800
# --------------------------------------------------------------------------------
# ==> Epoch 4 done in 3.3s | train_loss=1.8440  valid_loss=1.7746  valid_acc=0.00%
#
# no improvement for 4/100 epochs
#
# → Starting epoch 5  (printing every 43 iters)
# [Epoch 5] iter 43/43, avg loss: 1.5427
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QCS3236                   | QC336                     | 0.6937
# B3106A                    | BB1QQAAAAAAAAAAAAAAAA     | 0.3750
# W8723V                    | WW25                      | 0.4537
# QCH9191                   | QC9111                    | 0.6695
# 1M4U3172                  | MM417                     | 0.5103
# --------------------------------------------------------------------------------
# ==> Epoch 5 done in 3.4s | train_loss=1.5427  valid_loss=1.6453  valid_acc=0.00%
#
# no improvement for 5/100 epochs
#
# → Starting epoch 6  (printing every 43 iters)
# [Epoch 6] iter 43/43, avg loss: 1.2256
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# BSE!6665                  | QC!!666                   | 0.6359
# QPA3382                   | QPA3322                   | 0.7565
# WJT342                    | WJT3422                   | 0.7114
# AKK!4491                  | VA!!441                   | 0.5670
# PLS!114                   | QC!!111                   | 0.6184
# --------------------------------------------------------------------------------
# ==> Epoch 6 done in 3.4s | train_loss=1.2256  valid_loss=0.9681  valid_acc=17.20%
#
# 💾 New best model saved (epoch 6, val_acc=17.20%)
#
# → Starting epoch 7  (printing every 43 iters)
# [Epoch 7] iter 43/43, avg loss: 0.9745
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# BHP7067                   | BHP7667                   | 0.7590
# SYQ9881                   | SYQ9881                   | 0.7379
# LE7021                    | LLT0211                   | 0.6758
# VNQ4338                   | VNQ43388                  | 0.7692
# QAB3641H                  | QAB3611H                  | 0.6909
# --------------------------------------------------------------------------------
# ==> Epoch 7 done in 3.2s | train_loss=0.9745  valid_loss=0.7932  valid_acc=30.03%
#
# 💾 New best model saved (epoch 7, val_acc=30.03%)
#
# → Starting epoch 8  (printing every 43 iters)
# [Epoch 8] iter 43/43, avg loss: 0.7391
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QRR9945                   | QRR9945                   | 0.8903
# VEH!6204                  | VGG!6204                  | 0.5844
# QBD9519                   | QBD9519                   | 0.8067
# MDJ5126                   | MDJ5126                   | 0.8019
# QAA2892K                  | QAA2892KKKKKAAA299KK      | 0.6925
# --------------------------------------------------------------------------------
# ==> Epoch 8 done in 3.3s | train_loss=0.7391  valid_loss=0.7028  valid_acc=44.31%
#
# 💾 New best model saved (epoch 8, val_acc=44.31%)
#
# → Starting epoch 9  (printing every 43 iters)
# [Epoch 9] iter 43/43, avg loss: 0.5864
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# VEH!6204                  | WCH!6244                  | 0.6258
# JLY2201                   | JLY2201                   | 0.8753
# QAA8951J                  | QAA895JJ                  | 0.8510
# QMU969                    | QMU969                    | 0.9188
# QSV1707                   | QSV1007                   | 0.8715
# --------------------------------------------------------------------------------
# ==> Epoch 9 done in 3.3s | train_loss=0.5864  valid_loss=1.0415  valid_acc=3.79%
#
# no improvement for 1/100 epochs
#
# → Starting epoch 10  (printing every 43 iters)
# [Epoch 10] iter 43/43, avg loss: 0.5532
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QCM5317                   | QCM5317                   | 0.8643
# JRG6799                   | JRG6799                   | 0.9172
# 8559                      | SS555                     | 0.6395
# QAA8020Q                  | QAA8020Q                  | 0.8618
# KDN!1893                  | BCC!1893                  | 0.6806
# --------------------------------------------------------------------------------
# ==> Epoch 10 done in 3.2s | train_loss=0.5532  valid_loss=0.8785  valid_acc=15.16%
#
# no improvement for 2/100 epochs
#
# → Starting epoch 11  (printing every 43 iters)
# [Epoch 11] iter 43/43, avg loss: 0.4616
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QS6811S                   | QS6811                    | 0.8654
# QAA844Q                   | QAA844Q                   | 0.9300
# CDD!8169                  | BCB!8169                  | 0.7292
# QCB1918                   | QCB1918                   | 0.9098
# XOIC29                    | XD1229                    | 0.7132
# --------------------------------------------------------------------------------
# ==> Epoch 11 done in 3.2s | train_loss=0.4616  valid_loss=0.5379  valid_acc=58.02%
#
# 💾 New best model saved (epoch 11, val_acc=58.02%)
#
# → Starting epoch 12  (printing every 43 iters)
# [Epoch 12] iter 43/43, avg loss: 0.4095
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# ANU7888                   | ANU7888                   | 0.9699
# QS9953S                   | QS9953S                   | 0.9325
# VN815                     | VN815                     | 0.8922
# QKM5112                   | QKM5112                   | 0.9618
# WDM!5963                  | WMW!5963                  | 0.7246
# --------------------------------------------------------------------------------
# ==> Epoch 12 done in 3.2s | train_loss=0.4095  valid_loss=0.5178  valid_acc=58.60%
#
# 💾 New best model saved (epoch 12, val_acc=58.60%)
#
# → Starting epoch 13  (printing every 43 iters)
# [Epoch 13] iter 43/43, avg loss: 0.3444
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# WEH8092                   | WEH8092                   | 0.9501
# QCA6734                   | QCA6734                   | 0.9814
# QAA6198S                  | QAA6198S                  | 0.9490
# QCG7936                   | QCG7936                   | 0.9430
# VDM!8068                  | WMW!8068                  | 0.7287
# --------------------------------------------------------------------------------
# ==> Epoch 13 done in 3.3s | train_loss=0.3444  valid_loss=0.5182  valid_acc=61.52%
#
# 💾 New best model saved (epoch 13, val_acc=61.52%)
#
# → Starting epoch 14  (printing every 43 iters)
# [Epoch 14] iter 43/43, avg loss: 0.3937
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# JLX!6457                  | PAP!6457                  | 0.6152
# VJL3065                   | VJL3065                   | 0.8644
# SMH1061                   | SMH1061                   | 0.9372
# RP!5366                   | BBB!5366                  | 0.6656
# VHC5744                   | VHC5744                   | 0.9568
# --------------------------------------------------------------------------------
# ==> Epoch 14 done in 3.4s | train_loss=0.3937  valid_loss=0.6030  valid_acc=51.90%
#
# no improvement for 1/100 epochs
#
# → Starting epoch 15  (printing every 43 iters)
# [Epoch 15] iter 43/43, avg loss: 0.2956
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# VK2618                    | VK2618                    | 0.9082
# MDH7007                   | MDH7007                   | 0.9616
# LD9188                    | LD9188                    | 0.9132
# JXP!4469                  | PKA!4469                  | 0.7881
# WLH6202                   | WLH6202                   | 0.9644
# --------------------------------------------------------------------------------
# ==> Epoch 15 done in 3.3s | train_loss=0.2956  valid_loss=1.5341  valid_acc=7.00%
#
# no improvement for 2/100 epochs
#
# → Starting epoch 16  (printing every 43 iters)
# [Epoch 16] iter 43/43, avg loss: 0.3567
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QCH7638                   | QCH7638                   | 0.9850
# JTD2383                   | JTD2383                   | 0.9607
# QAM6622                   | QAM6622                   | 0.9542
# WTM!3755                  | VMW!3755                  | 0.7683
# JUC9711                   | JUC9711                   | 0.9523
# --------------------------------------------------------------------------------
# ==> Epoch 16 done in 3.4s | train_loss=0.3567  valid_loss=0.4804  valid_acc=65.89%
#
# 💾 New best model saved (epoch 16, val_acc=65.89%)
#
# → Starting epoch 17  (printing every 43 iters)
# [Epoch 17] iter 43/43, avg loss: 0.2700
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# VCV3619                   | VCV3619                   | 0.9834
# QAA5823N                  | QAA5823N                  | 0.9445
# QS1016K                   | QS1016K                   | 0.9572
# VES!3744                  | VKK!3744                  | 0.7875
# SYY9112                   | SYY9112                   | 0.9636
# --------------------------------------------------------------------------------
# ==> Epoch 17 done in 3.3s | train_loss=0.2700  valid_loss=0.4886  valid_acc=63.56%
#
# no improvement for 1/100 epochs
#
# → Starting epoch 18  (printing every 43 iters)
# [Epoch 18] iter 43/43, avg loss: 0.1711
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QMU6123                   | QMU6123                   | 0.9796
# JSB675                    | JSB675                    | 0.9753
# QPB615                    | QPB615                    | 0.9250
# QCT1194                   | QCT1194                   | 0.9850
# TBB4878                   | TBB4878                   | 0.9725
# --------------------------------------------------------------------------------
# ==> Epoch 18 done in 3.3s | train_loss=0.1711  valid_loss=0.5327  valid_acc=65.01%
#
# no improvement for 2/100 epochs
#
# → Starting epoch 19  (printing every 43 iters)
# [Epoch 19] iter 43/43, avg loss: 0.1360
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# WLC52                     | WLC52                     | 0.9664
# QAA3618X                  | QAA3618X                  | 0.9820
# 104101DC                  | 104101DC                  | 0.9351
# ANB!9161                  | BNB!9161                  | 0.8602
# QAB1928E                  | QAB1928E                  | 0.9607
# --------------------------------------------------------------------------------
# ==> Epoch 19 done in 3.3s | train_loss=0.1360  valid_loss=0.5012  valid_acc=65.01%
#
# no improvement for 3/100 epochs
#
# → Starting epoch 20  (printing every 43 iters)
# [Epoch 20] iter 43/43, avg loss: 0.1161
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# TBE9333                   | TBE9333                   | 0.9861
# QAA3858U                  | QAA3858U                  | 0.9682
# QAA5191E                  | QAA5191E                  | 0.9828
# BLR!9830                  | BLR!9830                  | 0.8530
# MCV!3797                  | MDV!3797                  | 0.8520
# --------------------------------------------------------------------------------
# ==> Epoch 20 done in 3.5s | train_loss=0.1161  valid_loss=0.4869  valid_acc=65.89%
#
# no improvement for 4/100 epochs
#
# → Starting epoch 21  (printing every 43 iters)
# [Epoch 21] iter 43/43, avg loss: 0.1847
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# UNIMAS6119                | UNNMAS619                 | 0.8316
# QM!9C                     | QM!99                     | 0.8726
# ADY!2688                  | ADL!2688                  | 0.8826
# WB2261T                   | WB2261T                   | 0.9682
# SM2004                    | SM2004                    | 0.9600
# --------------------------------------------------------------------------------
# ==> Epoch 21 done in 3.4s | train_loss=0.1847  valid_loss=0.5061  valid_acc=63.27%
#
# no improvement for 5/100 epochs
#
# → Starting epoch 22  (printing every 43 iters)
# [Epoch 22] iter 43/43, avg loss: 0.1323
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# WXY6928                   | WXY6928                   | 0.9566
# VDL4789                   | VDL4789                   | 0.9582
# QAA!9401U                 | QAA!9401U                 | 0.9567
# QS4848D                   | QS4848D                   | 0.9605
# QAA686G                   | QAA686G                   | 0.9806
# --------------------------------------------------------------------------------
# ==> Epoch 22 done in 3.4s | train_loss=0.1323  valid_loss=0.4275  valid_acc=67.64%
#
# 💾 New best model saved (epoch 22, val_acc=67.64%)
#
# → Starting epoch 23  (printing every 43 iters)
# [Epoch 23] iter 43/43, avg loss: 0.0922
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# JVY1699                   | JVY1699                   | 0.9859
# QPA3725                   | QPA3725                   | 0.9815
# WA1309F                   | WA1309F                   | 0.9920
# SYF8254                   | SYF8254                   | 0.9795
# QMW!65                    | QMM!65                    | 0.8923
# --------------------------------------------------------------------------------
# ==> Epoch 23 done in 3.3s | train_loss=0.0922  valid_loss=0.5270  valid_acc=63.27%
#
# no improvement for 1/100 epochs
#
# → Starting epoch 24  (printing every 43 iters)
# [Epoch 24] iter 43/43, avg loss: 0.0962
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QLD2696                   | QLD2696                   | 0.9571
# QLC8072                   | QLC8072                   | 0.9354
# QAA3440                   | QAA3440                   | 0.9576
# JFR4363                   | JFR4363                   | 0.9649
# T/JJ115                   | T/JJ115                   | 0.9656
# --------------------------------------------------------------------------------
# ==> Epoch 24 done in 3.1s | train_loss=0.0962  valid_loss=0.9757  valid_acc=42.27%
#
# no improvement for 2/100 epochs
#
# → Starting epoch 25  (printing every 43 iters)
# [Epoch 25] iter 43/43, avg loss: 0.1827
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# WJE4152                   | WJE4152                   | 0.9834
# QLB7733                   | QLB7733                   | 0.9613
# W8723V                    | W8723V                    | 0.9075
# CCP8081                   | CCP8081                   | 0.9508
# NCH!6650                  | NCH!6650                  | 0.9383
# --------------------------------------------------------------------------------
# ==> Epoch 25 done in 3.0s | train_loss=0.1827  valid_loss=0.3599  valid_acc=68.51%
#
# 💾 New best model saved (epoch 25, val_acc=68.51%)
#
# → Starting epoch 26  (printing every 43 iters)
# [Epoch 26] iter 43/43, avg loss: 0.0465
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# WXX!2093                  | WXX!2093                  | 0.9003
# ADY!2688                  | ADY!2688                  | 0.9022
# QAE2205                   | QAE2205                   | 0.9567
# NAD!9748                  | AAD!9748                  | 0.8589
# BNB!8655                  | BNB!8655                  | 0.8656
# --------------------------------------------------------------------------------
# ==> Epoch 26 done in 3.2s | train_loss=0.0465  valid_loss=0.4793  valid_acc=62.97%
#
# no improvement for 1/100 epochs
#
# → Starting epoch 27  (printing every 43 iters)
# [Epoch 27] iter 43/43, avg loss: 0.1484
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# JRA!7032                  | JRA!7032                  | 0.9174
# W5870P                    | W5870P                    | 0.9231
# QCP9736                   | QCP9736                   | 0.9843
# QRR9945                   | QRR9945                   | 0.9858
# VAJ4559                   | VAJ4559                   | 0.9811
# --------------------------------------------------------------------------------
# ==> Epoch 27 done in 3.3s | train_loss=0.1484  valid_loss=0.4093  valid_acc=66.18%
#
# no improvement for 2/100 epochs
#
# → Starting epoch 28  (printing every 43 iters)
# [Epoch 28] iter 43/43, avg loss: 0.0541
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QTS6613                   | QTS6613                   | 0.9859
# QAA8678A                  | QAA8678A                  | 0.9741
# UMK!8883                  | UMK!8883                  | 0.8519
# JNU8226                   | JNU8266                   | 0.9887
# WC1484R                   | WC1484R                   | 0.9821
# --------------------------------------------------------------------------------
# ==> Epoch 28 done in 3.4s | train_loss=0.0541  valid_loss=0.4738  valid_acc=62.10%
#
# no improvement for 3/100 epochs
#
# → Starting epoch 29  (printing every 43 iters)
# [Epoch 29] iter 43/43, avg loss: 0.1069
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# VJG3205                   | VJG3205                   | 0.9458
# QLC8072                   | QLC8072                   | 0.9855
# PLE8999                   | PLE8999                   | 0.9719
# DDK!6794                  | DDK!6794                  | 0.9361
# TBT!3323                  | TAT!3323                  | 0.8610
# --------------------------------------------------------------------------------
# ==> Epoch 29 done in 3.4s | train_loss=0.1069  valid_loss=0.3670  valid_acc=71.72%
#
# 💾 New best model saved (epoch 29, val_acc=71.72%)
#
# → Starting epoch 30  (printing every 43 iters)
# [Epoch 30] iter 43/43, avg loss: 0.0262
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# MU!6275                   | MU!6275                   | 0.9781
# JXC679                    | JXC679                    | 0.9893
# BRK!9118                  | BRK!9118                  | 0.9304
# QAA!9328G                 | QAA!9328G                 | 0.9373
# QRR9945                   | QRR9945                   | 0.9852
# --------------------------------------------------------------------------------
# ==> Epoch 30 done in 3.4s | train_loss=0.0262  valid_loss=0.3465  valid_acc=73.47%
#
# 💾 New best model saved (epoch 30, val_acc=73.47%)
#
# → Starting epoch 31  (printing every 43 iters)
# [Epoch 31] iter 43/43, avg loss: 0.0199
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QM!155J                   | QM!155J                   | 0.9314
# VAM!9906                  | VAM!9906                  | 0.9370
# QAC2127                   | QAC2127                   | 0.9957
# CEW!485                   | CEW!485                   | 0.9270
# SYM!4893                  | SYM!4893                  | 0.9549
# --------------------------------------------------------------------------------
# ==> Epoch 31 done in 3.2s | train_loss=0.0199  valid_loss=0.3617  valid_acc=75.51%
#
# 💾 New best model saved (epoch 31, val_acc=75.51%)
#
# → Starting epoch 32  (printing every 43 iters)
# [Epoch 32] iter 43/43, avg loss: 0.0144
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# WVB5362                   | WVB5362                   | 0.9766
# WC8869U                   | WC8869U                   | 0.9862
# VGL5629                   | VGL5629                   | 0.9755
# ABS8858                   | ABS8858                   | 0.9876
# NCB!7903                  | NCB!79033                 | 0.9140
# --------------------------------------------------------------------------------
# ==> Epoch 32 done in 3.2s | train_loss=0.0144  valid_loss=0.3963  valid_acc=74.64%
#
# no improvement for 1/100 epochs
#
# → Starting epoch 33  (printing every 43 iters)
# [Epoch 33] iter 43/43, avg loss: 0.0100
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# WAW8593                   | WAW8593                   | 0.9728
# SJG7119                   | SJG7119                   | 0.9654
# QCP9736                   | QCP9736                   | 0.9913
# VC6786                    | VC6786                    | 0.9654
# CCP8081                   | CCP8081                   | 0.9681
# --------------------------------------------------------------------------------
# ==> Epoch 33 done in 3.3s | train_loss=0.0100  valid_loss=0.3675  valid_acc=78.13%
#
# 💾 New best model saved (epoch 33, val_acc=78.13%)
#
# → Starting epoch 34  (printing every 43 iters)
# [Epoch 34] iter 43/43, avg loss: 0.0067
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# 426                       | 426                       | 0.9747
# VBH6554                   | VBH6554                   | 0.9499
# SU5174J                   | SU5174J                   | 0.9570
# QAB5858                   | QAB5858                   | 0.9797
# TCT2301                   | TCT2301                   | 0.9769
# --------------------------------------------------------------------------------
# ==> Epoch 34 done in 3.3s | train_loss=0.0067  valid_loss=0.3548  valid_acc=77.26%
#
# no improvement for 1/100 epochs
#
# → Starting epoch 35  (printing every 43 iters)
# [Epoch 35] iter 43/43, avg loss: 0.0076
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# VJJ!5970                  | VJJ!5970                  | 0.9682
# QAA9839E                  | QAA9839E                  | 0.9779
# VBY8203                   | VBY8203                   | 0.9443
# VMC3545                   | VMC3545                   | 0.9771
# QAA2269Y                  | QAA2269Y                  | 0.9666
# --------------------------------------------------------------------------------
# ==> Epoch 35 done in 3.2s | train_loss=0.0076  valid_loss=0.3497  valid_acc=76.97%
#
# no improvement for 2/100 epochs
#
# → Starting epoch 36  (printing every 43 iters)
# [Epoch 36] iter 43/43, avg loss: 0.0054
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# KAK!2474                  | KAK!2474                  | 0.9188
# QTY9455                   | QTY9455                   | 0.9761
# RX8899                    | RX8899                    | 0.9677
# QM!7099P                  | QM!7099P                  | 0.9397
# QCR2878                   | QCR2878                   | 0.9913
# --------------------------------------------------------------------------------
# ==> Epoch 36 done in 3.3s | train_loss=0.0054  valid_loss=0.3702  valid_acc=77.26%
#
# no improvement for 3/100 epochs
#
# → Starting epoch 37  (printing every 43 iters)
# [Epoch 37] iter 43/43, avg loss: 0.0047
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QAA9552A                  | QAA9552A                  | 0.9691
# VBV198                    | VBV198                    | 0.9870
# WXQ6691                   | WXQ6691                   | 0.9804
# SD3933P                   | SD3933P                   | 0.9694
# BJA!2450                  | BJA!2450                  | 0.9738
# --------------------------------------------------------------------------------
# ==> Epoch 37 done in 3.3s | train_loss=0.0047  valid_loss=0.3708  valid_acc=76.97%
#
# no improvement for 4/100 epochs
#
# → Starting epoch 38  (printing every 43 iters)
# [Epoch 38] iter 43/43, avg loss: 0.0038
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# WD8974A                   | WD8974A                   | 0.9810
# T/BB578                   | T/BB578                   | 0.9804
# BLJ6613                   | BLJ6613                   | 0.9756
# FFF2966                   | FFF2966                   | 0.9820
# WC3688R                   | WC3688R                   | 0.9626
# --------------------------------------------------------------------------------
# ==> Epoch 38 done in 3.3s | train_loss=0.0038  valid_loss=0.3829  valid_acc=76.97%
#
# no improvement for 5/100 epochs
#
# → Starting epoch 39  (printing every 43 iters)
# [Epoch 39] iter 43/43, avg loss: 0.0258
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# MCN!7929                  | MCN!7929                  | 0.9448
# SD288V                    | SD288V                    | 0.9853
# QMY4519                   | QMY4519                   | 0.9558
# QAA4693Q                  | QAA4693Q                  | 0.9909
# QCG9631                   | QCG9631                   | 0.9953
# --------------------------------------------------------------------------------
# ==> Epoch 39 done in 3.4s | train_loss=0.0258  valid_loss=0.4153  valid_acc=72.59%
#
# no improvement for 6/100 epochs
#
# → Starting epoch 40  (printing every 43 iters)
# [Epoch 40] iter 43/43, avg loss: 0.0087
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# WFH6380                   | WFH6380                   | 0.9684
# QAA!9381W                 | QAA!9381W                 | 0.9714
# QAA7961C                  | QAA7961C                  | 0.9954
# AHN!1732                  | AHN!1732                  | 0.9638
# QKW5158                   | QKW5158                   | 0.9742
# --------------------------------------------------------------------------------
# ==> Epoch 40 done in 3.3s | train_loss=0.0087  valid_loss=0.4008  valid_acc=76.97%
#
# no improvement for 7/100 epochs
#
# → Starting epoch 41  (printing every 43 iters)
# [Epoch 41] iter 43/43, avg loss: 0.0038
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# PMF!2507                  | PMF!2507                  | 0.9608
# PJN!538                   | PJN!538                   | 0.9182
# VAH!7666                  | VAH!7666                  | 0.9796
# BPA!4342                  | BPA!4342                  | 0.9550
# QAB9656H                  | QAB9656H                  | 0.9402
# --------------------------------------------------------------------------------
# ==> Epoch 41 done in 3.3s | train_loss=0.0038  valid_loss=0.3915  valid_acc=76.68%
#
# no improvement for 8/100 epochs
#
# → Starting epoch 42  (printing every 43 iters)
# [Epoch 42] iter 43/43, avg loss: 0.0065
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# MCV1838                   | MCV1838                   | 0.9592
# QAB401E                   | QAB401E                   | 0.9331
# QPB615                    | QPB615                    | 0.9153
# JV271                     | JV271                     | 0.9343
# JJE!2328                  | JJE!2328                  | 0.9216
# --------------------------------------------------------------------------------
# ==> Epoch 42 done in 3.5s | train_loss=0.0065  valid_loss=0.4713  valid_acc=67.93%
#
# no improvement for 9/100 epochs
#
# → Starting epoch 43  (printing every 43 iters)
# [Epoch 43] iter 43/43, avg loss: 0.0054
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# VNF1215                   | VNF1215                   | 0.9822
# VDV7199                   | VDV7199                   | 0.9907
# QMY4519                   | QMY4519                   | 0.9843
# VHG1732                   | VHG1732                   | 0.9745
# BRY8828                   | BRY8828                   | 0.9947
# --------------------------------------------------------------------------------
# ==> Epoch 43 done in 3.3s | train_loss=0.0054  valid_loss=0.4100  valid_acc=74.93%
#
# no improvement for 10/100 epochs
#
# → Starting epoch 44  (printing every 43 iters)
# [Epoch 44] iter 43/43, avg loss: 0.0025
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# T/BD8758                  | T/BD8758                  | 0.9717
# TBE9333                   | TBE9333                   | 0.9907
# W1301R                    | W1301R                    | 0.9923
# QSP!5188                  | QSP!5188                  | 0.9511
# KEG!9999                  | KEG!9999                  | 0.9565
# --------------------------------------------------------------------------------
# ==> Epoch 44 done in 3.2s | train_loss=0.0025  valid_loss=0.4173  valid_acc=76.97%
#
# no improvement for 11/100 epochs
#
# → Starting epoch 45  (printing every 43 iters)
# [Epoch 45] iter 43/43, avg loss: 0.0017
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# PMV4916                   | PMV4916                   | 0.9806
# QAA1918D                  | QAA1918D                  | 0.9866
# NEA1254                   | NEA1254                   | 0.9821
# WUX4391                   | WUX4391                   | 0.9801
# AHN!1732                  | AHN!1732                  | 0.9675
# --------------------------------------------------------------------------------
# ==> Epoch 45 done in 3.2s | train_loss=0.0017  valid_loss=0.3960  valid_acc=77.26%
#
# no improvement for 12/100 epochs
#
# → Starting epoch 46  (printing every 43 iters)
# [Epoch 46] iter 43/43, avg loss: 0.0015
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# VDV7199                   | VDV7199                   | 0.9751
# QCH2778                   | QCH2778                   | 0.9908
# QMU969                    | QMU969                    | 0.9947
# JNB!9682                  | JNB!9682                  | 0.9269
# SJF!5203                  | SJF!5203                  | 0.9666
# --------------------------------------------------------------------------------
# ==> Epoch 46 done in 3.2s | train_loss=0.0015  valid_loss=0.3920  valid_acc=77.26%
#
# no improvement for 13/100 epochs
#
# → Starting epoch 47  (printing every 43 iters)
# [Epoch 47] iter 43/43, avg loss: 0.0014
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# JRK1292                   | JRK1292                   | 0.9873
# VLL!1474                  | VLL!1474                  | 0.9814
# QLB8533                   | QLB8533                   | 0.9785
# CCP8081                   | CCP8081                   | 0.9936
# T/JA6344                  | T/JA6344                  | 0.9800
# --------------------------------------------------------------------------------
# ==> Epoch 47 done in 3.2s | train_loss=0.0014  valid_loss=0.3919  valid_acc=77.26%
#
# no improvement for 14/100 epochs
#
# → Starting epoch 48  (printing every 43 iters)
# [Epoch 48] iter 43/43, avg loss: 0.0013
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# MAG!7025                  | MAG!7025                  | 0.9643
# CFB3006                   | CFB3006                   | 0.9917
# QAA!9381W                 | QAA!9381W                 | 0.9321
# RT1911                    | RT1911                    | 0.9346
# T/BD!8333                 | T/BD!8333                 | 0.9470
# --------------------------------------------------------------------------------
# ==> Epoch 48 done in 3.2s | train_loss=0.0013  valid_loss=0.3989  valid_acc=77.26%
#
# no improvement for 15/100 epochs
#
# → Starting epoch 49  (printing every 43 iters)
# [Epoch 49] iter 43/43, avg loss: 0.0013
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QAA8801X                  | QAA8801X                  | 0.9752
# QAB221                    | QAB221                    | 0.9828
# QAM5330                   | QAM5330                   | 0.9887
# QSX2233                   | QSX2233                   | 0.9868
# VNH9099                   | VNH9099                   | 0.9873
# --------------------------------------------------------------------------------
# ==> Epoch 49 done in 3.2s | train_loss=0.0013  valid_loss=0.3940  valid_acc=77.55%
#
# no improvement for 16/100 epochs
#
# → Starting epoch 50  (printing every 43 iters)
# [Epoch 50] iter 43/43, avg loss: 0.0011
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# B3106A                    | B3106A                    | 0.9816
# PMU!3220                  | PMU!3220                  | 0.9761
# QAA!8698P                 | QAA!8698P                 | 0.9627
# PGX9411                   | PGX9411                   | 0.9778
# UNIMAS6119                | UNIMAS6119                | 0.8899
# --------------------------------------------------------------------------------
# ==> Epoch 50 done in 3.4s | train_loss=0.0011  valid_loss=0.3979  valid_acc=77.55%
#
# no improvement for 17/100 epochs
#
# → Starting epoch 51  (printing every 43 iters)
# [Epoch 51] iter 43/43, avg loss: 0.0010
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QCM4320                   | QCM4320                   | 0.9964
# VGF!4942                  | VGF!4942                  | 0.9642
# QAK1881                   | QAK1881                   | 0.9948
# VGK9975                   | VGK9975                   | 0.9857
# JNA5822                   | JNA5822                   | 0.9768
# --------------------------------------------------------------------------------
# ==> Epoch 51 done in 3.4s | train_loss=0.0010  valid_loss=0.3920  valid_acc=79.01%
#
# 💾 New best model saved (epoch 51, val_acc=79.01%)
#
# → Starting epoch 52  (printing every 43 iters)
# [Epoch 52] iter 43/43, avg loss: 0.0009
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# SW2769                    | SW2769                    | 0.9724
# VJR!1999                  | VJR!1999                  | 0.9531
# WB1351J                   | WB1351J                   | 0.9681
# W3426P                    | W3426P                    | 0.9698
# WQX3834                   | WQX3834                   | 0.9815
# --------------------------------------------------------------------------------
# ==> Epoch 52 done in 3.2s | train_loss=0.0009  valid_loss=0.3995  valid_acc=77.84%
#
# no improvement for 1/100 epochs
#
# → Starting epoch 53  (printing every 43 iters)
# [Epoch 53] iter 43/43, avg loss: 0.0009
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# WD1915A                   | WD1915A                   | 0.9878
# SM2004                    | SM2004                    | 0.9874
# QM3245P                   | QM3245P                   | 0.9899
# QCJ6959                   | QCJ6959                   | 0.9964
# AEP!7737                  | AEP!7737                  | 0.9908
# --------------------------------------------------------------------------------
# ==> Epoch 53 done in 3.5s | train_loss=0.0009  valid_loss=0.3933  valid_acc=78.43%
#
# no improvement for 2/100 epochs
#
# → Starting epoch 54  (printing every 43 iters)
# [Epoch 54] iter 43/43, avg loss: 0.0009
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# VHR7459                   | VHR7459                   | 0.9846
# WDC!4844                  | WDC!4844                  | 0.9628
# QAB1879C                  | QAB1879C                  | 0.9605
# BHS5465                   | BHS5465                   | 0.9939
# JV271                     | JV271                     | 0.9662
# --------------------------------------------------------------------------------
# ==> Epoch 54 done in 3.5s | train_loss=0.0009  valid_loss=0.3997  valid_acc=78.43%
#
# no improvement for 3/100 epochs
#
# → Starting epoch 55  (printing every 43 iters)
# [Epoch 55] iter 43/43, avg loss: 0.0008
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# W1301R                    | W1301R                    | 0.9922
# QCP8767                   | QCP8767                   | 0.9962
# WCP3338                   | WCP3338                   | 0.9959
# WTL9654                   | WTL9654                   | 0.9865
# WGS3960                   | WGS3960                   | 0.9628
# --------------------------------------------------------------------------------
# ==> Epoch 55 done in 3.3s | train_loss=0.0008  valid_loss=0.4039  valid_acc=77.55%
#
# no improvement for 4/100 epochs
#
# → Starting epoch 56  (printing every 43 iters)
# [Epoch 56] iter 43/43, avg loss: 0.0007
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QAM1008                   | QAM1008                   | 0.9942
# JVD7333                   | JVD7333                   | 0.9783
# QBC!4734                  | QBC!4734                  | 0.9457
# XOIC29                    | XOIC29                    | 0.9805
# QLE5670                   | QLE5670                   | 0.9876
# --------------------------------------------------------------------------------
# ==> Epoch 56 done in 3.3s | train_loss=0.0007  valid_loss=0.4076  valid_acc=77.55%
#
# no improvement for 5/100 epochs
#
# → Starting epoch 57  (printing every 43 iters)
# [Epoch 57] iter 43/43, avg loss: 0.0007
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# NBC771                    | NBC771                    | 0.9812
# KDC!4153                  | KDC!4153                  | 0.9318
# CFB3006                   | CFB3006                   | 0.9898
# QBG411                    | QBG411                    | 0.9716
# MDJ!6389                  | MDJ!6389                  | 0.9661
# --------------------------------------------------------------------------------
# ==> Epoch 57 done in 3.4s | train_loss=0.0007  valid_loss=0.4035  valid_acc=78.13%
#
# no improvement for 6/100 epochs
#
# → Starting epoch 58  (printing every 43 iters)
# [Epoch 58] iter 43/43, avg loss: 0.0007
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# ...
#
# no improvement for 81/100 epochs
#
# → Starting epoch 289  (printing every 43 iters)
# [Epoch 289] iter 43/43, avg loss: 0.0001
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# TBH1267                   | TBH1267                   | 0.9807
# STA2829A                  | STA2829A                  | 0.9818
# QRU2519                   | QRU2519                   | 0.9937
# SA24M                     | SA24M                     | 0.9983
# JVV4188                   | JVV4188                   | 0.9739
# --------------------------------------------------------------------------------
# ==> Epoch 289 done in 3.2s | train_loss=0.0001  valid_loss=0.4102  valid_acc=82.22%
#
# no improvement for 82/100 epochs
#
# → Starting epoch 290  (printing every 43 iters)
# [Epoch 290] iter 43/43, avg loss: 0.0001
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# BRV!1389                  | BRV!1389                  | 0.9623
# QKD4636                   | QKD4636                   | 0.9850
# PJN!538                   | PJN!538                   | 0.9545
# ACS!237                   | ACS!237                   | 0.9929
# JSY!1378                  | JSY!1378                  | 0.9914
# --------------------------------------------------------------------------------
# ==> Epoch 290 done in 3.3s | train_loss=0.0001  valid_loss=0.4103  valid_acc=82.51%
#
# no improvement for 83/100 epochs
#
# → Starting epoch 291  (printing every 43 iters)
# [Epoch 291] iter 43/43, avg loss: 0.0001
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QAA3827W                  | QAA3827W                  | 0.9635
# QAT!6517                  | QAT!6517                  | 0.9928
# QKD4636                   | QKD4636                   | 0.9905
# MDS7934                   | MDS7934                   | 0.9910
# DAG309                    | DAG309                    | 0.9814
# --------------------------------------------------------------------------------
# ==> Epoch 291 done in 3.3s | train_loss=0.0001  valid_loss=0.4057  valid_acc=82.22%
#
# no improvement for 84/100 epochs
#
# → Starting epoch 292  (printing every 43 iters)
# [Epoch 292] iter 43/43, avg loss: 0.0001
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# CEY1822                   | CEY1822                   | 0.9741
# VNQ2521                   | VNQ2521                   | 0.9932
# CEW!485                   | CEW!485                   | 0.9989
# VIP6464                   | VIP6464                   | 0.9759
# QLD2696                   | QLD2696                   | 0.9954
# --------------------------------------------------------------------------------
# ==> Epoch 292 done in 3.2s | train_loss=0.0001  valid_loss=0.4075  valid_acc=82.51%
#
# no improvement for 85/100 epochs
#
# → Starting epoch 293  (printing every 43 iters)
# [Epoch 293] iter 43/43, avg loss: 0.0001
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QAE2205                   | QAE2205                   | 0.9983
# QPB8855                   | QPB8855                   | 0.9839
# QCR2878                   | QCR2878                   | 0.9705
# TCM3335                   | TCM3335                   | 0.9723
# VBY8203                   | VBY8203                   | 0.9806
# --------------------------------------------------------------------------------
# ==> Epoch 293 done in 3.2s | train_loss=0.0001  valid_loss=0.4135  valid_acc=81.92%
#
# no improvement for 86/100 epochs
#
# → Starting epoch 294  (printing every 43 iters)
# [Epoch 294] iter 43/43, avg loss: 0.0001
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# ZC!3873                   | ZC!3873                   | 0.9679
# QAB4631C                  | QAB4631C                  | 0.9739
# JWW9378                   | JWW9378                   | 0.9914
# W1301R                    | W1301R                    | 0.9714
# DAG309                    | DAG309                    | 0.9801
# --------------------------------------------------------------------------------
# ==> Epoch 294 done in 3.2s | train_loss=0.0001  valid_loss=0.4152  valid_acc=82.22%
#
# no improvement for 87/100 epochs
#
# → Starting epoch 295  (printing every 43 iters)
# [Epoch 295] iter 43/43, avg loss: 0.0001
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# WDM!5963                  | WDM!5963                  | 0.9685
# T/BF!6897                 | T/BF!6897                 | 0.9445
# PGC9892                   | PGC9892                   | 0.9993
# QLC8072                   | QLC8072                   | 0.9778
# TCA7899                   | TCA7899                   | 0.9885
# --------------------------------------------------------------------------------
# ==> Epoch 295 done in 3.2s | train_loss=0.0001  valid_loss=0.4140  valid_acc=82.22%
#
# no improvement for 88/100 epochs
#
# → Starting epoch 296  (printing every 43 iters)
# [Epoch 296] iter 43/43, avg loss: 0.0001
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# ANM3637                   | ANM3637                   | 0.9984
# QAY4173                   | QAY4173                   | 0.9982
# CEW!485                   | CEW!485                   | 0.9966
# BJM9030                   | BJM9030                   | 0.9904
# PMU3220                   | PMU3220                   | 0.9822
# --------------------------------------------------------------------------------
# ==> Epoch 296 done in 3.2s | train_loss=0.0001  valid_loss=0.4101  valid_acc=81.92%
#
# no improvement for 89/100 epochs
#
# → Starting epoch 297  (printing every 43 iters)
# [Epoch 297] iter 43/43, avg loss: 0.0001
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# JLX!1296                  | JLX!1296                  | 0.9876
# VLX7844                   | VLX7844                   | 0.9955
# BNE4434                   | BNE4434                   | 0.9755
# QAA!8383R                 | QAA!8383R                 | 0.9328
# VEB806                    | VEB806                    | 0.9788
# --------------------------------------------------------------------------------
# ==> Epoch 297 done in 3.2s | train_loss=0.0001  valid_loss=0.4120  valid_acc=82.22%
#
# no improvement for 90/100 epochs
#
# → Starting epoch 298  (printing every 43 iters)
# [Epoch 298] iter 43/43, avg loss: 0.0001
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# BAK!5940                  | BAK!5940                  | 0.9817
# QKH4199                   | QKH4199                   | 0.9956
# QSX2233                   | QSX2233                   | 0.9833
# WCE!1598                  | WCE!1598                  | 0.9883
# KCT6037                   | KCT6037                   | 0.9956
# --------------------------------------------------------------------------------
# ==> Epoch 298 done in 3.3s | train_loss=0.0001  valid_loss=0.4146  valid_acc=82.51%
#
# no improvement for 91/100 epochs
#
# → Starting epoch 299  (printing every 43 iters)
# [Epoch 299] iter 43/43, avg loss: 0.0001
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# VNP3597                   | VNP3597                   | 0.9973
# NBW7154                   | NBW7154                   | 0.9879
# PRP!5757                  | PRP!5757                  | 0.9793
# QAB707K                   | QAB707K                   | 0.9838
# VMQ981                    | VMQ981                    | 0.9946
# --------------------------------------------------------------------------------
# ==> Epoch 299 done in 3.4s | train_loss=0.0001  valid_loss=0.4105  valid_acc=82.22%
#
# no improvement for 92/100 epochs
#
# → Starting epoch 300  (printing every 43 iters)
# [Epoch 300] iter 43/43, avg loss: 0.0001
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# WUV!7830                  | WUV!7830                  | 0.9785
# QCB!3923                  | QCB!3923                  | 0.9599
# PMU!3220                  | PMU!3220                  | 0.9729
# WYC8600                   | WYC8600                   | 0.9731
# WUX4391                   | WUX4391                   | 0.9819
# --------------------------------------------------------------------------------
# ==> Epoch 300 done in 3.5s | train_loss=0.0001  valid_loss=0.4121  valid_acc=82.22%
#
# no improvement for 93/100 epochs
#
# → Starting epoch 301  (printing every 43 iters)
# [Epoch 301] iter 43/43, avg loss: 0.0001
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# VE9696                    | VE9696                    | 0.9956
# QCB1918                   | QCB1918                   | 0.9764
# QBA6681                   | QBA6681                   | 0.9757
# T/WB434                   | T/WB434                   | 0.9831
# QAA6858M                  | QAA6858M                  | 0.9882
# --------------------------------------------------------------------------------
# ==> Epoch 301 done in 3.2s | train_loss=0.0001  valid_loss=0.4134  valid_acc=82.51%
#
# no improvement for 94/100 epochs
#
# → Starting epoch 302  (printing every 43 iters)
# [Epoch 302] iter 43/43, avg loss: 0.0001
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# AMB8327                   | AMB8327                   | 0.9836
# MDJ50                     | MDJ50                     | 0.9589
# QS74V                     | QS74V                     | 0.9709
# PMW!7851                  | PMW!7851                  | 0.9699
# TBC28                     | TBC28                     | 0.9938
# --------------------------------------------------------------------------------
# ==> Epoch 302 done in 3.2s | train_loss=0.0001  valid_loss=0.4174  valid_acc=82.51%
#
# no improvement for 95/100 epochs
#
# → Starting epoch 303  (printing every 43 iters)
# [Epoch 303] iter 43/43, avg loss: 0.0001
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QD!4211                   | QD!4211                   | 0.9791
# PPL!9185                  | PPL!9185                  | 0.9546
# AMN3223                   | AMN3223                   | 0.9804
# KEN!7203                  | KEN!7203                  | 0.9697
# JRG!3303                  | JRG!3303                  | 0.9719
# --------------------------------------------------------------------------------
# ==> Epoch 303 done in 3.2s | train_loss=0.0001  valid_loss=0.4141  valid_acc=82.22%
#
# no improvement for 96/100 epochs
#
# → Starting epoch 304  (printing every 43 iters)
# [Epoch 304] iter 43/43, avg loss: 0.0001
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# WC178M                    | WC178M                    | 0.9655
# SK3694F                   | SK3694F                   | 0.9826
# T/BD8758                  | T/BD8758                  | 0.9916
# QCL8988                   | QCL8988                   | 0.9816
# ANM7267                   | ANM7267                   | 0.9836
# --------------------------------------------------------------------------------
# ==> Epoch 304 done in 3.2s | train_loss=0.0001  valid_loss=0.4124  valid_acc=81.92%
#
# no improvement for 97/100 epochs
#
# → Starting epoch 305  (printing every 43 iters)
# [Epoch 305] iter 43/43, avg loss: 0.0001
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QAA9638U                  | QAA9638U                  | 0.9550
# VGK9975                   | VGK9975                   | 0.9843
# VFC!331                   | VFC!331                   | 0.9897
# BLJ6613                   | BLJ6613                   | 0.9991
# QAB9218                   | QAB9218                   | 0.9843
# --------------------------------------------------------------------------------
# ==> Epoch 305 done in 3.2s | train_loss=0.0001  valid_loss=0.4045  valid_acc=81.92%
#
# no improvement for 98/100 epochs
#
# → Starting epoch 306  (printing every 43 iters)
# [Epoch 306] iter 43/43, avg loss: 0.0001
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# VAU6344                   | VAU6344                   | 0.9764
# QKV465                    | QKV465                    | 0.9988
# WFN4042                   | WFN4042                   | 0.9786
# NDP9388                   | NDP9388                   | 0.9854
# VKN!4650                  | VKN!4650                  | 0.9573
# --------------------------------------------------------------------------------
# ==> Epoch 306 done in 3.2s | train_loss=0.0001  valid_loss=0.4142  valid_acc=82.51%
#
# no improvement for 99/100 epochs
#
# → Starting epoch 307  (printing every 43 iters)
# [Epoch 307] iter 43/43, avg loss: 0.0001
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# CEN2010                   | CEN2010                   | 0.9829
# KDU!3612                  | KDU!3612                  | 0.9526
# QAB3330B                  | QAB3330B                  | 0.9966
# JRG2793                   | JRG2793                   | 0.9883
# AMM5551                   | AMM5551                   | 0.9875
# --------------------------------------------------------------------------------
# ==> Epoch 307 done in 3.2s | train_loss=0.0001  valid_loss=0.4160  valid_acc=82.22%
#
# no improvement for 100/100 epochs
#
# 🔚 Early stopping: val_acc hasn't improved for 100 epochs.

# %%
clean_history = {
  'epoch':      history['epoch'],
  'train_loss': [x.cpu().item() if hasattr(x, 'cpu') else x for x in history['train_loss']],
  'val_loss':   [x.cpu().item() if hasattr(x, 'cpu') else x for x in history['val_loss']],
  'val_acc':    [x.cpu().item() if hasattr(x, 'cpu') else x for x in history['val_acc']],
}
df = pd.DataFrame(clean_history)
display(df)

plt.figure()
plt.plot(df['epoch'], df['train_loss'], label='Train Loss')
plt.plot(df['epoch'], df['val_loss'],   label='Val Loss')
plt.xlabel('Epoch'); plt.ylabel('Loss'); plt.legend()
plt.title('Loss over Epochs')
plt.show()

plt.figure()
plt.plot(df['epoch'], df['val_acc'],   label='Val Accuracy')
plt.xlabel('Epoch'); plt.ylabel('Accuracy (%)'); plt.legend()
plt.title('Val Accuracy over Epochs')
plt.show()
# Out:
#      epoch  train_loss  val_loss    val_acc
# 0        1    3.127073  2.841395   0.000000
# 1        2    2.520072  2.269305   0.000000
# 2        3    2.137695  2.070928   0.000000
# 3        4    1.844033  1.774577   0.000000
# 4        5    1.542656  1.645301   0.000000
# ..     ...         ...       ...        ...
# 302    303    0.000079  0.414096  82.215743
# 303    304    0.000077  0.412356  81.924198
# 304    305    0.000077  0.404491  81.924198
# 305    306    0.000076  0.414183  82.507289
# 306    307    0.000075  0.415962  82.215743
#
# [307 rows x 4 columns]

# %%
# # ─── Cell 9: ONNX export via isolated inference head ─────────────────────────
# import torch

# class CRNNInference(torch.nn.Module):
#     def __init__(self, crnn, max_len):
#         super().__init__()
#         # use exactly the names printed out by your inspection
#         self.Transformation     = crnn.Transformation
#         self.FeatureExtraction = crnn.FeatureExtraction
#         self.AdaptiveAvgPool    = crnn.AdaptiveAvgPool
#         self.SequenceModeling   = crnn.SequenceModeling
#         self.Prediction         = crnn.Prediction
#         self.max_len           = max_len
#         # adjust this if your converter stores start-token under a different key
#         self.start_id          = crnn.converter.dict['[GO]']

#     def forward(self, image):
#         # 1) Spatial‐transformer + feature CNN
#         x = self.Transformation(image)                     # [B, C, H, W]
#         x = self.FeatureExtraction(x)                      # [B, C, H, W]

#         # 2) Pool down height to 1
#         x = self.AdaptiveAvgPool(x)                        # [B, C, 1, W]
#         x = x.squeeze(2)                                   # [B, C, W]
#         x = x.permute(0, 2, 1)                             # [B, W, C]

#         # 3) 2‐layer BiLSTM
#         contextual = self.SequenceModeling(x)              # [B, W, hidden]

#         # 4) Dummy “[GO]” token vector
#         B = contextual.size(0)
#         dummy_text = torch.full(
#             (B,),
#             self.start_id,
#             dtype=torch.long,
#             device=image.device
#         )  # shape [B]

#         # 5) Attention decoder (inference path)
#         return self.Prediction(
#             batch_H           = contextual,
#             text              = dummy_text,
#             is_train          = False,
#             batch_max_length  = self.max_len
#         )

# # Wrap and export
# inference_model = CRNNInference(model, BATCH_MAX_LENGTH).eval()
# dummy_img       = torch.randn(1, INPUT_CHANNEL, IMG_HEIGHT, IMG_WIDTH, device=device)

# torch.onnx.export(
#     inference_model,
#     dummy_img,
#     "best_attention_crnn.onnx",
#     input_names   = ['image'],
#     output_names  = ['logits'],
#     dynamic_axes  = {
#         'image':  {0: 'batch'},
#         'logits': {0: 'batch', 1: 'time'}
#     },
#     opset_version = 13,
# )

# print("✅ Exported best_attention_crnn.onnx")

# %% [markdown]
# # DUMP

# %%
# # ─── cell 6: attention‐based training loop ──────────────────────────────────────
# for epoch in range(1, NUM_EPOCHS+1):
#     print(f"→ Starting epoch {epoch}  (printing every {PRINT_EVERY} iters)")
#     model.train()
#     epoch_loss = Averager()
#     start      = time.time()

#     for i, (images, texts) in enumerate(train_loader, 1):
#         images = images.to(device)

#         # encode with [GO] & [s]; also get lengths
#         text, length = converter.encode(texts, batch_max_length=BATCH_MAX_LENGTH)
#         text_input  = text[:, :-1].to(device)   # drop final [s]
#         text_target = text[:,  1:].to(device)   # everything after [GO]

#         # forward + loss
#         preds = model(images,
#                       text=text_input,
#                       is_train=True,
#                       batch_max_length=BATCH_MAX_LENGTH)  # [B, S, C]
#         B, S, C = preds.size()
#         loss = criterion(
#             preds.view(B * S, C),
#             text_target.contiguous().view(B * S)
#         )

#         optimizer.zero_grad()
#         loss.backward()
#         torch.nn.utils.clip_grad_norm_(model.parameters(), 5)
#         optimizer.step()
#         epoch_loss.add(loss)

#         if i % PRINT_EVERY == 0 or i == 1:
#             print(f"[Epoch {epoch}] iter {i}/{len(train_loader)}, avg loss: {epoch_loss.val():.4f}", flush=True)

#             # quick greedy‐decode
#             with torch.no_grad():
#                 probs        = preds.softmax(2)           # [B, S, C]
#                 max_vals, max_inds = probs.max(2)         # [B, S]
#                 pred_strs    = converter.decode(max_inds, length)
#                 pred_strs    = [s.split('[s]')[0] for s in pred_strs]

#             # print a mini‐table
#             print("-" * 80)
#             print(f"{'Ground Truth':25s} | {'Prediction':25s} | AvgConfidence")
#             print("-" * 80)
#             for gt, pr, conf_seq in zip(texts[:5], pred_strs[:5], max_vals[:5]):
#                 conf = conf_seq.mean().item()
#                 print(f"{gt:25s} | {pr:25s} | {conf:0.4f}")
#             print("-" * 80)

#     # end‐of‐epoch validation
#     val_loss, val_acc = validate(model, val_loader)
#     elapsed = time.time() - start
#     print(f"==> Epoch {epoch} done in {elapsed:.1f}s | "
#           f"train_loss={epoch_loss.val():.4f}"
#           f"  valid_loss={val_loss:.4f}  valid_acc={val_acc:.2f}%\n")

# %%
# # ─── Cell 6: training w/ history, best‐model saving ───

# # hyper‐params
# best_val_acc    = 0.0
# history         = {'epoch': [], 'train_loss': [], 'val_loss': [], 'val_acc': []}

# for epoch in range(1, NUM_EPOCHS+1):
#     print(f"→ Starting epoch {epoch}  (printing every {PRINT_EVERY} iters)")
#     model.train()
#     epoch_loss = Averager()
#     start = time.time()

#     # ─── training ─────────────────────────────────────────────────────────────
#     for i, (images, texts) in enumerate(train_loader, 1):
#         images = images.to(device)

#         text, length   = converter.encode(texts, batch_max_length=MAX_LABEL_LENGTH)
#         text_input     = text[:, :-1].to(device)
#         text_target    = text[:,  1:].to(device)

#         preds = model(
#             images,
#             text=text_input,
#             is_train=True,
#             batch_max_length=MAX_LABEL_LENGTH
#         )  # [B, S, C]
#         B, S, C = preds.size()
#         loss = criterion(
#             preds.view(B * S, C),
#             text_target.contiguous().view(B * S)
#         )

#         optimizer.zero_grad()
#         loss.backward()
#         torch.nn.utils.clip_grad_norm_(model.parameters(), 5)
#         optimizer.step()
#         epoch_loss.add(loss)

#         # mini‐table prints
#         if i % PRINT_EVERY == 0:
#             print(f"[Epoch {epoch}] iter {i}/{len(train_loader)}, avg loss: {epoch_loss.val():.4f}", flush=True)
#             with torch.no_grad():
#                 probs     = preds.softmax(2)
#                 max_vals, max_inds = probs.max(2)
#                 pred_strs = converter.decode(max_inds, length)
#                 pred_strs = [s.split('[s]')[0] for s in pred_strs]

#             print("-" * 80)
#             print(f"{'Ground Truth':25s} | {'Prediction':25s} | AvgConfidence")
#             print("-" * 80)
#             for gt, pr, conf_seq in zip(texts[:5], pred_strs[:5], max_vals[:5]):
#                 conf = conf_seq.mean().item()
#                 print(f"{gt:25s} | {pr:25s} | {conf_seq.mean().item():.4f}")
#             print("-" * 80)

#     # ─── validation ────────────────────────────────────────────────────────────
#     val_loss, val_acc = validate(model, val_loader)
#     elapsed = time.time() - start
#     train_l = epoch_loss.val()
#     print(f"==> Epoch {epoch} done in {elapsed:.1f}s | "
#           f"train_loss={train_l:.4f}  valid_loss={val_loss:.4f}  valid_acc={val_acc:.2f}%\n")

#     # ─── record history & save best ──────────────────────────────────────────
#     history['epoch'].append(epoch)
#     history['train_loss'].append(train_l)
#     history['val_loss'].append(val_loss)
#     history['val_acc'].append(val_acc)

#     if val_acc > best_val_acc:
#         best_val_acc = val_acc
#         torch.save(model.state_dict(), "best_attention_crnn_!.pth")
#         print(f"💾 New best model saved (epoch {epoch}, val_acc={val_acc:.2f}%)\n")
