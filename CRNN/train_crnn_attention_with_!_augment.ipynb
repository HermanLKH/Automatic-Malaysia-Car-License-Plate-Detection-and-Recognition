# %%
# cell 1
import os
import time
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
import matplotlib.pyplot as plt
import pandas as pd
import random
import numpy as np

from config import (IMG_HEIGHT, IMG_WIDTH, NUM_FIDUCIAL,
                    INPUT_CHANNEL, OUTPUT_CHANNEL, HIDDEN_SIZE,
                    CHARACTERS, MAX_LABEL_LENGTH)
from dataset import LmdbDataset, AlignCollate
# from utils import CTCLabelConverter, Averager
from utils import AttnLabelConverter, Averager
from model import CRNN
import torchvision.transforms as T
from PIL import Image

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print("Running on", device)
# Out:
# Running on cuda

# %%
# ─── cell 0: reproducibility ────────────────────────────────────────────────
SEED = 300188
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)

# Make cuDNN deterministic (slower but reproducible)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

print(f"All seeds set to {SEED}, cudnn.deterministic={torch.backends.cudnn.deterministic}")
# Out:
# All seeds set to 300188, cudnn.deterministic=True

# %% [markdown]
# ------ Added Augmentation ------

# %%
augment_pipeline = T.Compose([
    # rotate up to ±15°
    T.RandomRotation(15, expand=False, fill=255),

    # flip left ↔ right with 50% probability
    T.RandomHorizontalFlip(p=0.5),

    # shear by up to ±10°
    T.RandomAffine(degrees=0, shear=10, fill=255),

    # slight brightness jitter
    T.ColorJitter(brightness=0.2),

    # add gaussian noise in [0,1], then back to uint8
    T.Lambda(lambda img: (
        Image.fromarray(
            (
                np.clip(
                    np.array(img).astype(np.float32) / 255.0
                    + np.random.normal(0, 0.02, img.size[::-1]),
                    0.0, 1.0
                ) * 255.0
            ).astype(np.uint8)
        )
    )),
])

# %%
class AugmentedLmdbDataset(Dataset):
    def __init__(self, base_dataset, augment, num_aug):
        self.base     = base_dataset
        self.augment  = augment
        self.num_aug  = num_aug
        self.orig_len = len(base_dataset)

    def __len__(self):
        # each original plus `num_aug` variants
        return self.orig_len * (1 + self.num_aug)

    def __getitem__(self, idx):
        if idx < self.orig_len:
            # raw sample
            return self.base[idx]
        # augmented sample
        base_idx = idx % self.orig_len
        img, label = self.base[base_idx]
        return self.augment(img), label

# %%
# cell 2
# paths to your LMDBs
train_lmdb = "v4_lmdb_data_!/train"
val_lmdb   = "v4_lmdb_data_!/val"

# instantiate datasets
train_dataset = LmdbDataset(train_lmdb)
val_dataset   = LmdbDataset(val_lmdb)

# augmentations
NUM_AUG = 3   # → total factor = 1 (orig) + 2 aug = ×3
aug_train_dataset = AugmentedLmdbDataset(train_dataset, augment_pipeline, num_aug=NUM_AUG)
print(f"Original train images: {len(train_dataset)}")
print(f"After augmentation:    {len(aug_train_dataset)}  (×{1+NUM_AUG} total samples)")

# collate_fn resizes + normalizes
collate_fn = AlignCollate(
    imgH=IMG_HEIGHT, imgW=IMG_WIDTH, keep_ratio_with_pad=False
)

# loaders
BATCH_SIZE = 32
train_loader = DataLoader(
    aug_train_dataset, batch_size=BATCH_SIZE, shuffle=True,
    num_workers=0, collate_fn=collate_fn, pin_memory=True
)
val_loader = DataLoader(
    val_dataset, batch_size=BATCH_SIZE, shuffle=False,
    num_workers=0, collate_fn=collate_fn, pin_memory=True
)

print(f"{len(aug_train_dataset)} train / {len(val_dataset)} val samples")
# Out:
# Loaded 1372 valid samples from v4_lmdb_data_!/train
# Loaded 343 valid samples from v4_lmdb_data_!/val
# Original train images: 1372
# After augmentation:    5488  (×4 total samples)
# 5488 train / 343 val samples

# %%
converter   = AttnLabelConverter(CHARACTERS)
num_classes = len(converter.character)   # includes [GO] and [s]

model = CRNN(
    IMG_HEIGHT,      # imgH
    IMG_WIDTH,       # imgW
    INPUT_CHANNEL,   # input_channel
    OUTPUT_CHANNEL,  # output_channel
    HIDDEN_SIZE,     # hidden_size
    num_classes,     # num_classes (with GO/s)
    True,            # use_attention
    NUM_FIDUCIAL     # num_fiducial
).to(device)

criterion = nn.CrossEntropyLoss(ignore_index=0).to(device)
optimizer = optim.Adadelta(model.parameters(), lr=1.0)

# %%
# ─── cell 4: validate (Attention) ─────────────────────────────────────────────
NUM_EPOCHS       = 500
PRINT_EVERY      = len(aug_train_dataset) // BATCH_SIZE + 1
PATIENCE       = 100          # stop if no val_acc ↑ for 50 epochs

def validate(model, loader):
    model.eval()
    avg_loss = Averager()
    correct, total = 0, 0

    with torch.no_grad():
        for images, texts in loader:
            images = images.to(device)

            # encode full text → shape [B, L+1], plus lengths
            text, length = converter.encode(texts, batch_max_length=MAX_LABEL_LENGTH)
            text_input  = text[:, :-1].to(device)  # drop final [s]
            text_target = text[:,  1:].to(device)  # everything after [GO]

            # forward
            preds = model(images, text_input, is_train=False,
                          batch_max_length=MAX_LABEL_LENGTH)
            B, S, C = preds.size()

            # cross‐entropy over (B×S) predictions
            loss = criterion(
                preds.view(B * S, C),
                text_target.contiguous().view(B * S)
            )
            avg_loss.add(loss)

            # greedy decode
            _, pred_inds = preds.max(2)                   # [B, S]
            pred_strs = converter.decode(pred_inds, length)  # pass length

            # strip off anything after the "[s]" token
            pred_strs = [s.split('[s]')[0] for s in pred_strs]

            total += len(texts)
            correct += sum(p == g for p, g in zip(pred_strs, texts))

    acc = correct / total * 100
    return avg_loss.val(), acc

# %%
# ─── cell 5: load pretrained CTC weights (skip old Prediction head) ────────────

from collections import OrderedDict

orig      = torch.load("pretrained_model/TPS-ResNet-BiLSTM-Attn.pth", map_location=device)
# strip off the "module." prefix if you wrapped in DataParallel
stripped  = OrderedDict((k[len("module."):], v)
                        for k, v in orig.items()
                        if k.startswith("module."))

own = model.state_dict()
for k, v in stripped.items():
    # skip the old attention head entirely
    if k.startswith("Prediction."):
        continue
    # only overwrite if shapes match
    if k in own and v.size() == own[k].size():
        own[k] = v

model.load_state_dict(own)
print("✅ Loaded pretrained Attn weights")
# Out:
# ✅ Loaded pretrained Attn weights

# %%
# ─── Cell 6: training w/ history, best‐model saving + EARLY STOPPING ───

# hyper‑params
best_val_acc   = 0.0
history        = {'epoch': [], 'train_loss': [], 'val_loss': [], 'val_acc': []}

patience_cnt   = 0           # how many epochs since last improvement

for epoch in range(1, NUM_EPOCHS+1):
    print(f"→ Starting epoch {epoch}  (printing every {PRINT_EVERY} iters)")
    model.train()
    epoch_loss = Averager()
    start = time.time()

    # ─── training ──────────────────────────────────────────────────────────
    for i, (images, texts) in enumerate(train_loader, 1):
        images = images.to(device)

        text, length   = converter.encode(texts, batch_max_length=MAX_LABEL_LENGTH)
        text_input     = text[:, :-1].to(device)
        text_target    = text[:,  1:].to(device)

        preds = model(
            images,
            text=text_input,
            is_train=True,
            batch_max_length=MAX_LABEL_LENGTH
        )  # [B, S, C]
        B, S, C = preds.size()
        loss = criterion(
            preds.view(B * S, C),
            text_target.contiguous().view(B * S)
        )

        optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 5)
        optimizer.step()
        epoch_loss.add(loss)

        # mini‐table prints
        if i % PRINT_EVERY == 0:
            print(f"[Epoch {epoch}] iter {i}/{len(train_loader)}, avg loss: {epoch_loss.val():.4f}", flush=True)
            with torch.no_grad():
                probs     = preds.softmax(2)
                max_vals, max_inds = probs.max(2)
                pred_strs = converter.decode(max_inds, length)
                pred_strs = [s.split('[s]')[0] for s in pred_strs]

            print("-" * 80)
            print(f"{'Ground Truth':25s} | {'Prediction':25s} | AvgConfidence")
            print("-" * 80)
            for gt, pr, conf_seq in zip(texts[:5], pred_strs[:5], max_vals[:5]):
                conf = conf_seq.mean().item()
                print(f"{gt:25s} | {pr:25s} | {conf_seq.mean().item():.4f}")
            print("-" * 80)

    # ─── validation ────────────────────────────────────────────────────────
    val_loss, val_acc = validate(model, val_loader)
    elapsed   = time.time() - start
    train_l   = epoch_loss.val()
    print(f"==> Epoch {epoch} done in {elapsed:.1f}s | "
          f"train_loss={train_l:.4f}  valid_loss={val_loss:.4f}  valid_acc={val_acc:.2f}%\n")

    # ─── record history ───────────────────────────────────────────────────
    history['epoch'].append(epoch)
    history['train_loss'].append(train_l)
    history['val_loss'].append(val_loss)
    history['val_acc'].append(val_acc)

    # ─── best‑model tracking & early‑stopping logic ───────────────────────
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        torch.save(model.state_dict(), "best_attention_crnn_!_augment.pth")
        print(f"💾 New best model saved (epoch {epoch}, val_acc={val_acc:.2f}%)\n")
        patience_cnt = 0                          # reset counter
    else:
        patience_cnt += 1
        print(f"no improvement for {patience_cnt}/{PATIENCE} epochs\n")
        if patience_cnt >= PATIENCE:
            print(f"🔚 Early stopping: val_acc hasn't improved for {PATIENCE} epochs.")
            break
# Out:
# → Starting epoch 1  (printing every 172 iters)
# [Epoch 1] iter 172/172, avg loss: 2.5813
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# BLY5998                   | VVL9999                   | 0.3667
# JSG1987                   | QAB3333                   | 0.3883
# QCR271                    | QAA7770                   | 0.3750
# JRW5859                   | VVN5555                   | 0.3756
# BJF5469                   | QAA6666                   | 0.4196
# --------------------------------------------------------------------------------
# ==> Epoch 1 done in 11.9s | train_loss=2.5813  valid_loss=2.4301  valid_acc=0.00%
#
# no improvement for 1/100 epochs
#
# → Starting epoch 2  (printing every 172 iters)
# [Epoch 2] iter 172/172, avg loss: 1.5690
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# WTP2102                   | WP22102                   | 0.7692
# MDS7658                   | QCT7658                   | 0.6351
# JRG!3303                  | WEE!3333                  | 0.5860
# QAA377P                   | QAA7777                   | 0.8039
# JCY7217                   | JCY721                    | 0.6816
# --------------------------------------------------------------------------------
# ==> Epoch 2 done in 11.8s | train_loss=1.5690  valid_loss=1.1586  valid_acc=12.83%
#
# 💾 New best model saved (epoch 2, val_acc=12.83%)
#
# → Starting epoch 3  (printing every 172 iters)
# [Epoch 3] iter 172/172, avg loss: 0.8402
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# VNH9099                   | VHH9099                   | 0.8571
# WTL9654                   | WTL9654                   | 0.8805
# BAK!5940                  | PPK!3994                  | 0.5052
# VK1800                    | VKB800                    | 0.6770
# JXL9880                   | JXL9880                   | 0.8846
# --------------------------------------------------------------------------------
# ==> Epoch 3 done in 11.7s | train_loss=0.8402  valid_loss=0.6788  valid_acc=43.15%
#
# 💾 New best model saved (epoch 3, val_acc=43.15%)
#
# → Starting epoch 4  (printing every 172 iters)
# [Epoch 4] iter 172/172, avg loss: 0.5000
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QSU9715                   | QSU9715                   | 0.9460
# MDJ5126                   | MDJ5126                   | 0.9365
# ZC!3873                   | BS!!3883                  | 0.5801
# VJE3434                   | VJE3434                   | 0.9119
# QBF7591                   | QBF7591                   | 0.9654
# --------------------------------------------------------------------------------
# ==> Epoch 4 done in 11.1s | train_loss=0.5000  valid_loss=0.5248  valid_acc=54.23%
#
# 💾 New best model saved (epoch 4, val_acc=54.23%)
#
# → Starting epoch 5  (printing every 172 iters)
# [Epoch 5] iter 172/172, avg loss: 0.3189
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# TCA7789                   | TCA7789                   | 0.9077
# PNB6727                   | PNB6727                   | 0.9610
# MBX7368                   | WBX7368                   | 0.9306
# RAJ519                    | RAJ5199                   | 0.8919
# WYJ7760                   | WYL7760                   | 0.8610
# --------------------------------------------------------------------------------
# ==> Epoch 5 done in 11.4s | train_loss=0.3189  valid_loss=0.3944  valid_acc=65.60%
#
# 💾 New best model saved (epoch 5, val_acc=65.60%)
#
# → Starting epoch 6  (printing every 172 iters)
# [Epoch 6] iter 172/172, avg loss: 0.3020
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QCQ9249                   | QCQ8249                   | 0.8114
# JWW9278                   | JMW9278                   | 0.8873
# VHA6835                   | VHA6835                   | 0.9703
# QS2878F                   | QS2878F                   | 0.9300
# QBF!2288                  | QBF!2288                  | 0.7746
# --------------------------------------------------------------------------------
# ==> Epoch 6 done in 11.2s | train_loss=0.3020  valid_loss=0.4326  valid_acc=59.18%
#
# no improvement for 1/100 epochs
#
# → Starting epoch 7  (printing every 172 iters)
# [Epoch 7] iter 172/172, avg loss: 0.2128
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# MDV!8552                  | MDV!8552                  | 0.9583
# SK3694F                   | SK369441                  | 0.7953
# WMW7786                   | WMW77868                  | 0.8399
# TAE2798                   | TAE22798                  | 0.8338
# W!2547C                   | W55427CC                  | 0.4441
# --------------------------------------------------------------------------------
# ==> Epoch 7 done in 11.1s | train_loss=0.2128  valid_loss=0.6252  valid_acc=31.49%
#
# no improvement for 2/100 epochs
#
# → Starting epoch 8  (printing every 172 iters)
# [Epoch 8] iter 172/172, avg loss: 0.1761
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QAB3330B                  | QAB3330B                  | 0.9514
# ALC!3644                  | ALC!3644                  | 0.9192
# ALW!4851                  | ALW!4851                  | 0.9521
# T/D1673                   | JTD1673                   | 0.8693
# WWN1840                   | WWN1840                   | 0.9788
# --------------------------------------------------------------------------------
# ==> Epoch 8 done in 11.0s | train_loss=0.1761  valid_loss=0.3087  valid_acc=76.38%
#
# 💾 New best model saved (epoch 8, val_acc=76.38%)
#
# → Starting epoch 9  (printing every 172 iters)
# [Epoch 9] iter 172/172, avg loss: 0.1278
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# BLJ6613                   | BLJ6613                   | 0.9574
# JNA3294                   | JNA3294                   | 0.9675
# QKC1927                   | QKC1927                   | 0.9563
# JXP!4469                  | JXP!4469                  | 0.9090
# PKV4279                   | PKV4279                   | 0.9558
# --------------------------------------------------------------------------------
# ==> Epoch 9 done in 11.2s | train_loss=0.1278  valid_loss=0.2978  valid_acc=73.47%
#
# no improvement for 1/100 epochs
#
# → Starting epoch 10  (printing every 172 iters)
# [Epoch 10] iter 172/172, avg loss: 0.1041
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# CEG8119                   | CEG8119                   | 0.9845
# QAA7388S                  | QAA7388S                  | 0.9633
# VLD745                    | VJD745                    | 0.9026
# VLM6493                   | VLM6493                   | 0.9878
# QBC5425                   | QBC5425                   | 0.9840
# --------------------------------------------------------------------------------
# ==> Epoch 10 done in 10.9s | train_loss=0.1041  valid_loss=0.3093  valid_acc=74.64%
#
# no improvement for 2/100 epochs
#
# → Starting epoch 11  (printing every 172 iters)
# [Epoch 11] iter 172/172, avg loss: 0.0928
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# SD5508L                   | SD5508J                   | 0.9267
# PRF!6163                  | PRF!6163                  | 0.9744
# MY!3045                   | WY!3045                   | 0.8735
# VK2618                    | VK2618                    | 0.9266
# PZ171M                    | PS111M                    | 0.8705
# --------------------------------------------------------------------------------
# ==> Epoch 11 done in 11.1s | train_loss=0.0928  valid_loss=0.3736  valid_acc=71.43%
#
# no improvement for 3/100 epochs
#
# → Starting epoch 12  (printing every 172 iters)
# [Epoch 12] iter 172/172, avg loss: 0.0719
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QTP9129                   | QTP9120                   | 0.9354
# AND!897                   | AND!897                   | 0.9181
# PNV!4846                  | PNV!4846                  | 0.9936
# QCE1128                   | QCE1128                   | 0.9937
# BHF2928                   | BHF2928                   | 0.9793
# --------------------------------------------------------------------------------
# ==> Epoch 12 done in 10.9s | train_loss=0.0719  valid_loss=0.3130  valid_acc=74.64%
#
# no improvement for 4/100 epochs
#
# → Starting epoch 13  (printing every 172 iters)
# [Epoch 13] iter 172/172, avg loss: 0.0586
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QCJ!9999                  | QCJ!9999                  | 0.9853
# NDL4631                   | NDL4631                   | 0.9781
# AML!6313                  | AML!6313                  | 0.9431
# AMC6830                   | AMC6830                   | 0.9408
# WA!7920W                  | WAA79211                  | 0.8184
# --------------------------------------------------------------------------------
# ==> Epoch 13 done in 11.0s | train_loss=0.0586  valid_loss=0.2602  valid_acc=77.26%
#
# 💾 New best model saved (epoch 13, val_acc=77.26%)
#
# → Starting epoch 14  (printing every 172 iters)
# [Epoch 14] iter 172/172, avg loss: 0.0679
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# WB!302Q                   | WB!3020                   | 0.9276
# WYC8600                   | WYC8600                   | 0.9957
# QAN!23                    | QAN!23                    | 0.9398
# PKV4279                   | PKV4279                   | 0.9855
# WQC4674                   | WQC4674                   | 0.9697
# --------------------------------------------------------------------------------
# ==> Epoch 14 done in 11.2s | train_loss=0.0679  valid_loss=0.2741  valid_acc=78.72%
#
# 💾 New best model saved (epoch 14, val_acc=78.72%)
#
# → Starting epoch 15  (printing every 172 iters)
# [Epoch 15] iter 172/172, avg loss: 0.0571
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# AMC6830                   | AMC6830                   | 0.9898
# JUS8529                   | JUS8529                   | 0.9745
# VET612                    | VET612                    | 0.9837
# PLE8999                   | PLE8999                   | 0.9879
# VLM6493                   | VLM6493                   | 0.9839
# --------------------------------------------------------------------------------
# ==> Epoch 15 done in 11.1s | train_loss=0.0571  valid_loss=0.2807  valid_acc=77.55%
#
# no improvement for 1/100 epochs
#
# → Starting epoch 16  (printing every 172 iters)
# [Epoch 16] iter 172/172, avg loss: 0.0673
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# T/WC3                     | T/WC3                     | 0.8883
# VGF!4942                  | VGF!4942                  | 0.9886
# QCN8327                   | QCN8327                   | 0.9619
# MDV!8552                  | MDV!8552                  | 0.9735
# QAA8127S                  | QAA9127S                  | 0.9475
# --------------------------------------------------------------------------------
# ==> Epoch 16 done in 10.9s | train_loss=0.0673  valid_loss=0.2748  valid_acc=78.13%
#
# no improvement for 2/100 epochs
#
# → Starting epoch 17  (printing every 172 iters)
# [Epoch 17] iter 172/172, avg loss: 0.0651
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# SJF!5203                  | SJF!5203                  | 0.9406
# SYX3611                   | SYX3611                   | 0.9927
# WXJ911                    | WXJ9118                   | 0.9775
# PRM41                     | PRM41                     | 0.9176
# QSP!5188                  | QSP!5188                  | 0.9844
# --------------------------------------------------------------------------------
# ==> Epoch 17 done in 11.2s | train_loss=0.0651  valid_loss=0.2704  valid_acc=77.26%
#
# no improvement for 3/100 epochs
#
# → Starting epoch 18  (printing every 172 iters)
# [Epoch 18] iter 172/172, avg loss: 0.0619
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QAA2809X                  | QAA2809X                  | 0.9672
# QKB1883                   | QKB1887                   | 0.9080
# VNQ4338                   | VNQ4338                   | 0.9502
# QTQ1531                   | QTQ1531                   | 0.9748
# QBE!2772                  | QBE!2772                  | 0.9909
# --------------------------------------------------------------------------------
# ==> Epoch 18 done in 11.1s | train_loss=0.0619  valid_loss=0.2569  valid_acc=79.59%
#
# 💾 New best model saved (epoch 18, val_acc=79.59%)
#
# → Starting epoch 19  (printing every 172 iters)
# [Epoch 19] iter 172/172, avg loss: 0.0527
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# NCM!9145                  | NCM!9145                  | 0.9611
# SWH1319                   | SWH1319                   | 0.9932
# SD2901V                   | SD2901V                   | 0.9926
# QCK8417                   | QCK8417                   | 0.9901
# T/AA823                   | T/AA823                   | 0.9778
# --------------------------------------------------------------------------------
# ==> Epoch 19 done in 10.9s | train_loss=0.0527  valid_loss=0.2887  valid_acc=77.55%
#
# no improvement for 1/100 epochs
#
# → Starting epoch 20  (printing every 172 iters)
# [Epoch 20] iter 172/172, avg loss: 0.0581
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# VKP!3405                  | VKP!3405                  | 0.9555
# JXN7492                   | JXN7492                   | 0.9846
# W8631X                    | W8631X                    | 0.9767
# QS5119P                   | QS5119P                   | 0.9703
# TDB7888                   | TDB7888                   | 0.9960
# --------------------------------------------------------------------------------
# ==> Epoch 20 done in 11.3s | train_loss=0.0581  valid_loss=0.3270  valid_acc=78.43%
#
# no improvement for 2/100 epochs
#
# → Starting epoch 21  (printing every 172 iters)
# [Epoch 21] iter 172/172, avg loss: 0.0386
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# HWE8782                   | HWE8782                   | 0.9585
# BNF8126                   | BNF8126                   | 0.9807
# WUV!7830                  | WUV!7830                  | 0.9403
# QS1595E                   | QS1595E                   | 0.9651
# BLG7607                   | BJG7607                   | 0.9179
# --------------------------------------------------------------------------------
# ==> Epoch 21 done in 11.7s | train_loss=0.0386  valid_loss=0.3538  valid_acc=75.22%
#
# no improvement for 3/100 epochs
#
# → Starting epoch 22  (printing every 172 iters)
# [Epoch 22] iter 172/172, avg loss: 0.0329
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# AHU!7727                  | AHU!7727                  | 0.9911
# TDB7888                   | TDB7888                   | 0.9884
# QCJ!6565                  | QCJ!6965                  | 0.9602
# VFH!2157                  | VFH!2157                  | 0.9635
# TTB1838                   | TTB1838                   | 0.9697
# --------------------------------------------------------------------------------
# ==> Epoch 22 done in 11.5s | train_loss=0.0329  valid_loss=0.3054  valid_acc=79.01%
#
# no improvement for 4/100 epochs
#
# → Starting epoch 23  (printing every 172 iters)
# [Epoch 23] iter 172/172, avg loss: 0.0246
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# AM7017                    | AM7017                    | 0.9592
# QKU7812                   | QKU7812                   | 0.9668
# QSX2233                   | QSX2233                   | 0.9728
# QAR6858                   | QAR6858                   | 0.9547
# PZ171M                    | PZ171M                    | 0.9617
# --------------------------------------------------------------------------------
# ==> Epoch 23 done in 11.5s | train_loss=0.0246  valid_loss=0.3754  valid_acc=70.55%
#
# no improvement for 5/100 epochs
#
# → Starting epoch 24  (printing every 172 iters)
# [Epoch 24] iter 172/172, avg loss: 0.0222
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QTQ1531                   | QTQ1531                   | 0.9799
# JV271                     | JV271                     | 0.9398
# KBJ5226                   | KBJ5226                   | 0.9651
# QAB9731D                  | QAB9731D                  | 0.9943
# KAX1199                   | KAX1199                   | 0.9795
# --------------------------------------------------------------------------------
# ==> Epoch 24 done in 11.0s | train_loss=0.0222  valid_loss=0.3238  valid_acc=80.76%
#
# 💾 New best model saved (epoch 24, val_acc=80.76%)
#
# → Starting epoch 25  (printing every 172 iters)
# [Epoch 25] iter 172/172, avg loss: 0.0604
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# T/WC3                     | T/WC33                    | 0.8906
# QAB!8936                  | QAB!8936                  | 0.9563
# QBF!2288                  | QBF!2288                  | 0.9587
# QAW2391                   | QAW2391                   | 0.9956
# QAA!4174                  | QAA!4174                  | 0.9919
# --------------------------------------------------------------------------------
# ==> Epoch 25 done in 11.1s | train_loss=0.0604  valid_loss=0.3210  valid_acc=75.22%
#
# no improvement for 1/100 epochs
#
# → Starting epoch 26  (printing every 172 iters)
# [Epoch 26] iter 172/172, avg loss: 0.0580
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# T/JA213                   | T/JA213                   | 0.9797
# QMU595                    | QMU595                    | 0.9671
# QAB9766H                  | QAB9766H                  | 0.9804
# TCN!8474                  | TCN!8474                  | 0.9783
# QS1595E                   | QS1595E                   | 0.9609
# --------------------------------------------------------------------------------
# ==> Epoch 26 done in 11.3s | train_loss=0.0580  valid_loss=0.3178  valid_acc=74.93%
#
# no improvement for 2/100 epochs
#
# → Starting epoch 27  (printing every 172 iters)
# [Epoch 27] iter 172/172, avg loss: 0.0309
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# WVB5362                   | WVB5362                   | 0.9375
# QMB!9780                  | QMB!9780                  | 0.9969
# QAA6595Q                  | QAA6595Q                  | 0.9786
# NCH9890                   | NCH9890                   | 0.9565
# QSU9715                   | QSU9715                   | 0.9736
# --------------------------------------------------------------------------------
# ==> Epoch 27 done in 11.5s | train_loss=0.0309  valid_loss=0.2865  valid_acc=79.88%
#
# no improvement for 3/100 epochs
#
# → Starting epoch 28  (printing every 172 iters)
# [Epoch 28] iter 172/172, avg loss: 0.0310
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# TAM!408                   | TKK!4369                  | 0.7960
# TAE2798                   | TAE2798                   | 0.9408
# RT1911                    | RT1911                    | 0.9836
# MDS7934                   | MDS7934                   | 0.9952
# JWC6011                   | JWC6011                   | 0.9902
# --------------------------------------------------------------------------------
# ==> Epoch 28 done in 11.4s | train_loss=0.0310  valid_loss=0.3206  valid_acc=75.51%
#
# no improvement for 4/100 epochs
#
# → Starting epoch 29  (printing every 172 iters)
# [Epoch 29] iter 172/172, avg loss: 0.0205
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# WYJ7760                   | WYJ7760                   | 0.9783
# JTW!5239                  | JTW!5239                  | 0.9309
# QAA8823M                  | QAA8823M                  | 0.9923
# QM2377M                   | QMS677M                   | 0.8515
# BDR!2148                  | BDR!2148                  | 0.9976
# --------------------------------------------------------------------------------
# ==> Epoch 29 done in 11.7s | train_loss=0.0205  valid_loss=0.2738  valid_acc=81.63%
#
# 💾 New best model saved (epoch 29, val_acc=81.63%)
#
# → Starting epoch 30  (printing every 172 iters)
# [Epoch 30] iter 172/172, avg loss: 0.0193
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QCB!1921                  | QCB!1921                  | 0.9771
# QTS6613                   | QTS6613                   | 0.9686
# SML6789                   | SML6789                   | 0.9753
# MDN!8761                  | MDN!8761                  | 0.9928
# QCF847                    | QCF847                    | 0.9649
# --------------------------------------------------------------------------------
# ==> Epoch 30 done in 11.3s | train_loss=0.0193  valid_loss=0.3112  valid_acc=80.17%
#
# no improvement for 1/100 epochs
#
# → Starting epoch 31  (printing every 172 iters)
# [Epoch 31] iter 172/172, avg loss: 0.0168
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QAB2477H                  | QAB2477H                  | 0.9820
# VAJ!4559                  | VAJ!4559                  | 0.9972
# JTU3636                   | JTU3636                   | 0.9928
# VDL7317                   | VDL7317                   | 0.9734
# VE9696                    | VE9696                    | 0.9570
# --------------------------------------------------------------------------------
# ==> Epoch 31 done in 11.4s | train_loss=0.0168  valid_loss=0.3372  valid_acc=80.17%
#
# no improvement for 2/100 epochs
#
# → Starting epoch 32  (printing every 172 iters)
# [Epoch 32] iter 172/172, avg loss: 0.0178
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QCR6004                   | QCR6004                   | 0.9965
# JSD3681                   | JSD3681                   | 0.9738
# VET612                    | VET612                    | 0.9977
# QAR53                     | QAR53                     | 0.9974
# WB6577N                   | WB6577N                   | 0.9789
# --------------------------------------------------------------------------------
# ==> Epoch 32 done in 11.4s | train_loss=0.0178  valid_loss=0.2685  valid_acc=82.80%
#
# 💾 New best model saved (epoch 32, val_acc=82.80%)
#
# → Starting epoch 33  (printing every 172 iters)
# [Epoch 33] iter 172/172, avg loss: 0.0133
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# VFX447                    | VFX447                    | 0.9974
# PGL2189                   | PGL2189                   | 0.9776
# QCP8767                   | QCP8767                   | 0.9856
# PDP6868                   | PDP6868                   | 0.9349
# ANK!8132                  | ANK!8132                  | 0.9746
# --------------------------------------------------------------------------------
# ==> Epoch 33 done in 11.6s | train_loss=0.0133  valid_loss=0.2878  valid_acc=81.05%
#
# no improvement for 1/100 epochs
#
# → Starting epoch 34  (printing every 172 iters)
# [Epoch 34] iter 172/172, avg loss: 0.0200
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# JNA3294                   | JNA3294                   | 0.9281
# SD2901V                   | SD2901V                   | 0.9970
# JVB6226                   | JVB6226                   | 0.9891
# KP3300Q                   | KP3300Q                   | 0.9802
# VJR!1999                  | VJR!1999                  | 0.9901
# --------------------------------------------------------------------------------
# ==> Epoch 34 done in 11.0s | train_loss=0.0200  valid_loss=0.3121  valid_acc=78.13%
#
# no improvement for 2/100 epochs
#
# → Starting epoch 35  (printing every 172 iters)
# [Epoch 35] iter 172/172, avg loss: 0.0200
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# BDP4954                   | BDP4954                   | 0.9672
# QP4444                    | QP4444                    | 0.9827
# QPA3382                   | QPA3382                   | 0.9827
# PMU!3220                  | PMU!3220                  | 0.9942
# AMV2374                   | AMV2374                   | 0.9827
# --------------------------------------------------------------------------------
# ==> Epoch 35 done in 11.4s | train_loss=0.0200  valid_loss=0.3008  valid_acc=81.63%
#
# no improvement for 3/100 epochs
#
# → Starting epoch 36  (printing every 172 iters)
# [Epoch 36] iter 172/172, avg loss: 0.0314
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QAA2454X                  | QAA2454X                  | 0.9780
# QAX!2076                  | QAX!2076                  | 0.9893
# TBH1267                   | TBH1267                   | 0.9550
# W8631X                    | W8631X                    | 0.9519
# VAW4421                   | VAW4421                   | 0.9836
# --------------------------------------------------------------------------------
# ==> Epoch 36 done in 11.2s | train_loss=0.0314  valid_loss=0.3410  valid_acc=67.35%
#
# no improvement for 4/100 epochs
#
# → Starting epoch 37  (printing every 172 iters)
# [Epoch 37] iter 172/172, avg loss: 0.0167
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# VX2808                    | VX2808                    | 0.9743
# SD9913R                   | SD9913R                   | 0.9894
# JSG1987                   | JSG1987                   | 0.9874
# WYL2575                   | WYL2575                   | 0.9838
# VEH!6204                  | VEH!6204                  | 0.9865
# --------------------------------------------------------------------------------
# ==> Epoch 37 done in 11.7s | train_loss=0.0167  valid_loss=0.2824  valid_acc=79.88%
#
# no improvement for 5/100 epochs
#
# → Starting epoch 38  (printing every 172 iters)
# [Epoch 38] iter 172/172, avg loss: 0.0158
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# WUH!8857                  | WUH!8857                  | 0.9880
# QM2377M                   | QM2377M                   | 0.9613
# QKM5112                   | QKM5112                   | 0.9729
# WTW6533                   | WTW6533                   | 0.9769
# SD9913R                   | SD9913R                   | 0.9961
# --------------------------------------------------------------------------------
# ==> Epoch 38 done in 11.8s | train_loss=0.0158  valid_loss=0.3645  valid_acc=76.68%
#
# no improvement for 6/100 epochs
#
# → Starting epoch 39  (printing every 172 iters)
# [Epoch 39] iter 172/172, avg loss: 0.0209
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QS8591M                   | QS8591M                   | 0.9691
# VKD9603                   | VKD9603                   | 0.9675
# QS2025K                   | QS2025K                   | 0.9817
# QAR2857                   | QAR2857                   | 0.9970
# WC4922X                   | WC4922X                   | 0.9353
# --------------------------------------------------------------------------------
# ==> Epoch 39 done in 11.7s | train_loss=0.0209  valid_loss=0.3067  valid_acc=78.43%
#
# no improvement for 7/100 epochs
#
# → Starting epoch 40  (printing every 172 iters)
# [Epoch 40] iter 172/172, avg loss: 0.0166
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QAA377P                   | QAA377P                   | 0.9772
# MCV1838                   | MCV1838                   | 0.9967
# MDV1999                   | MDV1939                   | 0.9213
# QCH9191                   | QCH9191                   | 0.9506
# QAN7517                   | QAN7517                   | 0.9943
# --------------------------------------------------------------------------------
# ==> Epoch 40 done in 11.7s | train_loss=0.0166  valid_loss=0.2694  valid_acc=79.88%
#
# no improvement for 8/100 epochs
#
# → Starting epoch 41  (printing every 172 iters)
# [Epoch 41] iter 172/172, avg loss: 0.0184
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# BKL9211                   | BKL9211                   | 0.9880
# PGL!2189                  | PGL!2189                  | 0.9975
# VJY4021                   | VJY4021                   | 0.9956
# CCW!3760                  | CCW!3760                  | 0.9929
# VCQ7119                   | VCQ7119                   | 0.9807
# --------------------------------------------------------------------------------
# ==> Epoch 41 done in 12.5s | train_loss=0.0184  valid_loss=0.2921  valid_acc=81.92%
#
# no improvement for 9/100 epochs
#
# → Starting epoch 42  (printing every 172 iters)
# [Epoch 42] iter 172/172, avg loss: 0.0126
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# SA1408K                   | SA1408K                   | 0.9940
# QAB373                    | QAB373                    | 0.9930
# QAB3330B                  | QAB3330B                  | 0.9739
# JHC!8095                  | JHC!8095                  | 0.9497
# JSF2692                   | JSF2692                   | 0.9848
# --------------------------------------------------------------------------------
# ==> Epoch 42 done in 11.5s | train_loss=0.0126  valid_loss=0.3386  valid_acc=78.72%
#
# no improvement for 10/100 epochs
#
# → Starting epoch 43  (printing every 172 iters)
# [Epoch 43] iter 172/172, avg loss: 0.0123
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QAA3323X                  | QAA3323X                  | 0.9789
# FE3433                    | FE3433                    | 0.9791
# AHU!7727                  | AHU!7727                  | 0.9833
# QS2582P                   | QS2582P                   | 0.9552
# RW9634                    | RW9634                    | 0.9840
# --------------------------------------------------------------------------------
# ==> Epoch 43 done in 11.5s | train_loss=0.0123  valid_loss=0.2895  valid_acc=79.30%
#
# no improvement for 11/100 epochs
#
# → Starting epoch 44  (printing every 172 iters)
# [Epoch 44] iter 172/172, avg loss: 0.0122
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# WXJ9118                   | WXJ911                    | 0.9669
# WXT!2433                  | WXT!2433                  | 0.9949
# BQX!3898                  | BQX!3898                  | 0.9852
# VKR!5274                  | VKR!5274                  | 0.9903
# JKC7100                   | JKC7100                   | 0.9571
# --------------------------------------------------------------------------------
# ==> Epoch 44 done in 11.5s | train_loss=0.0122  valid_loss=0.3034  valid_acc=81.92%
#
# no improvement for 12/100 epochs
#
# → Starting epoch 45  (printing every 172 iters)
# [Epoch 45] iter 172/172, avg loss: 0.0115
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# VEQ6291                   | VEQ6291                   | 0.9891
# QCT7867                   | QCT7867                   | 0.9848
# NAN6440                   | NAN6440                   | 0.9930
# QAA3986N                  | QAA3986N                  | 0.9810
# WTE!2868                  | WTE!2868                  | 0.9861
# --------------------------------------------------------------------------------
# ==> Epoch 45 done in 11.5s | train_loss=0.0115  valid_loss=0.3364  valid_acc=78.72%
#
# no improvement for 13/100 epochs
#
# → Starting epoch 46  (printing every 172 iters)
# [Epoch 46] iter 172/172, avg loss: 0.0366
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# SYQ9881                   | SYD9881                   | 0.9947
# QTY9455                   | QTY9455                   | 0.9954
# JTE!2309                  | JTE!2309                  | 0.9731
# T/JA213                   | T/JA213                   | 0.9801
# VGN2263                   | VGN2263                   | 0.9793
# --------------------------------------------------------------------------------
# ==> Epoch 46 done in 11.5s | train_loss=0.0366  valid_loss=0.3028  valid_acc=79.59%
#
# no improvement for 14/100 epochs
#
# → Starting epoch 47  (printing every 172 iters)
# [Epoch 47] iter 172/172, avg loss: 0.0258
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# JNB388                    | JNB388                    | 0.9946
# NDL4631                   | NDL4631                   | 0.9986
# NH2225                    | NH2225                    | 0.9593
# WQC4674                   | WQC4674                   | 0.9970
# QAV8900                   | QAV8900                   | 0.9612
# --------------------------------------------------------------------------------
# ==> Epoch 47 done in 11.5s | train_loss=0.0258  valid_loss=0.3378  valid_acc=77.84%
#
# no improvement for 15/100 epochs
#
# → Starting epoch 48  (printing every 172 iters)
# [Epoch 48] iter 172/172, avg loss: 0.0305
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# BLR!9830                  | BLR!9830                  | 0.9832
# AKF!4463                  | AKF!4463                  | 0.9963
# BKV1970                   | BKV1970                   | 0.9980
# VMY!9477                  | VMY!9477                  | 0.9682
# QM4997P                   | QM4997P                   | 0.9838
# --------------------------------------------------------------------------------
# ==> Epoch 48 done in 11.6s | train_loss=0.0305  valid_loss=0.2784  valid_acc=78.43%
#
# no improvement for 16/100 epochs
#
# → Starting epoch 49  (printing every 172 iters)
# [Epoch 49] iter 172/172, avg loss: 0.0304
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# TCN!8474                  | TCN!8474                  | 0.9912
# WTW6533                   | WTW6533                   | 0.9971
# QAA6411                   | QAA6411                   | 0.9890
# T/D1673                   | T/D1673                   | 0.9146
# QS9953S                   | QS9953S                   | 0.9812
# --------------------------------------------------------------------------------
# ==> Epoch 49 done in 11.5s | train_loss=0.0304  valid_loss=0.3522  valid_acc=72.59%
#
# no improvement for 17/100 epochs
#
# → Starting epoch 50  (printing every 172 iters)
# [Epoch 50] iter 172/172, avg loss: 0.0286
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QAA!4174                  | QAA!4174                  | 0.9915
# WXJ9118                   | WXJ9118                   | 0.9605
# PEA!1781                  | PGA!1791                  | 0.9029
# TCA7789                   | TCA7789                   | 0.9980
# WKX!6755                  | WKX!6755                  | 0.9789
# --------------------------------------------------------------------------------
# ==> Epoch 50 done in 11.7s | train_loss=0.0286  valid_loss=0.3453  valid_acc=78.72%
#
# no improvement for 18/100 epochs
#
# → Starting epoch 51  (printing every 172 iters)
# [Epoch 51] iter 172/172, avg loss: 0.0220
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# T/BB2347                  | T/BB2347                  | 0.9789
# TBH1267                   | TBH1267                   | 0.9859
# SMH9778                   | SMH9778                   | 0.9897
# QAB3641H                  | QAB3641H                  | 0.9818
# QCB3330                   | QCB3330                   | 0.9863
# --------------------------------------------------------------------------------
# ==> Epoch 51 done in 11.6s | train_loss=0.0220  valid_loss=0.3375  valid_acc=79.01%
#
# no improvement for 19/100 epochs
#
# → Starting epoch 52  (printing every 172 iters)
# [Epoch 52] iter 172/172, avg loss: 0.0154
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# ANT8883                   | ANT8883                   | 0.9827
# RT9009                    | RT9009                    | 0.9869
# PZ171M                    | PZ171M                    | 0.9482
# QCJ5838                   | QCJ5838                   | 0.9742
# QTW!7053                  | QTW!7053                  | 0.9745
# --------------------------------------------------------------------------------
# ==> Epoch 52 done in 11.8s | train_loss=0.0154  valid_loss=0.2891  valid_acc=79.30%
#
# no improvement for 20/100 epochs
#
# → Starting epoch 53  (printing every 172 iters)
# [Epoch 53] iter 172/172, avg loss: 0.0079
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# PNV!4846                  | PNV!4846                  | 0.9853
# UMK!8883                  | UMK!8883                  | 0.9853
# WCR4455                   | WCR4455                   | 0.9727
# JTU3636                   | JTU3636                   | 0.9889
# MBP5604                   | MBP5604                   | 0.9958
# --------------------------------------------------------------------------------
# ==> Epoch 53 done in 11.2s | train_loss=0.0079  valid_loss=0.2704  valid_acc=81.63%
#
# no improvement for 21/100 epochs
#
# → Starting epoch 54  (printing every 172 iters)
# [Epoch 54] iter 172/172, avg loss: 0.0132
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# VKP!3405                  | VKP!3405                  | 0.9646
# T/BD!1513                 | T/BD!1513                 | 0.9505
# TCN!8474                  | TCN!8474                  | 0.9322
# WA1309F                   | WA1309F                   | 0.9987
# PPR3334                   | PPR3334                   | 0.9978
# --------------------------------------------------------------------------------
# ==> Epoch 54 done in 11.2s | train_loss=0.0132  valid_loss=0.2804  valid_acc=82.22%
#
# no improvement for 22/100 epochs
#
# → Starting epoch 55  (printing every 172 iters)
# [Epoch 55] iter 172/172, avg loss: 0.0118
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QAA8951J                  | QAA8951J                  | 0.9920
# T/N4541                   | T/N4541                   | 0.9920
# VLD745                    | VLD745                    | 0.9963
# QAA6615Q                  | QAA6615Q                  | 0.9973
# VJA520                    | VJA520                    | 0.9972
# --------------------------------------------------------------------------------
# ==> Epoch 55 done in 12.5s | train_loss=0.0118  valid_loss=0.3367  valid_acc=74.05%
#
# no improvement for 23/100 epochs
#
# → Starting epoch 56  (printing every 172 iters)
# [Epoch 56] iter 172/172, avg loss: 0.0137
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# WGC!5600                  | WGC!5600                  | 0.9824
# SD288V                    | SD288V                    | 0.9919
# WQD6028                   | WQD6028                   | 0.9995
# QAQ1011                   | QAQ1011                   | 0.9874
# JLX!6457                  | JLX!6457                  | 0.9837
# --------------------------------------------------------------------------------
# ==> Epoch 56 done in 12.0s | train_loss=0.0137  valid_loss=0.2836  valid_acc=81.34%
#
# no improvement for 24/100 epochs
#
# → Starting epoch 57  (printing every 172 iters)
# [Epoch 57] iter 172/172, avg loss: 0.0164
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# VHG1732                   | VHG1732                   | 0.9555
# QAL8533                   | QAL8533                   | 0.9746
# VHB3371                   | VHB3371                   | 0.9843
# 1M4U3172                  | 1M4U3172                  | 0.9126
# QM6676C                   | QM6676C                   | 0.9660
# --------------------------------------------------------------------------------
# ==> Epoch 57 done in 12.4s | train_loss=0.0164  valid_loss=0.2581  valid_acc=80.17%
#
# no improvement for 25/100 epochs
#
# → Starting epoch 58  (printing every 172 iters)
# [Epoch 58] iter 172/172, avg loss: 0.0114
# ...
# [Epoch 300] iter 172/172, avg loss: 0.0034
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# NCD8456                   | NCD8456                   | 0.9988
# WNL3044                   | WNL3044                   | 0.9645
# QTV6692                   | QTV6692                   | 0.9835
# PHY2884                   | PHY2884                   | 0.9746
# KEN!7203                  | KEN!7203                  | 0.9977
# --------------------------------------------------------------------------------
# ==> Epoch 300 done in 11.1s | train_loss=0.0034  valid_loss=0.4017  valid_acc=79.59%
#
# no improvement for 82/100 epochs
#
# → Starting epoch 301  (printing every 172 iters)
# [Epoch 301] iter 172/172, avg loss: 0.0013
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QAB1571G                  | QAB1571G                  | 0.9881
# SWK426                    | SWK426                    | 0.9875
# KCT6037                   | KCT6037                   | 0.9902
# VEB806                    | VEB806                    | 0.9980
# NBS4847                   | NBS4847                   | 0.9880
# --------------------------------------------------------------------------------
# ==> Epoch 301 done in 11.1s | train_loss=0.0013  valid_loss=0.3382  valid_acc=81.63%
#
# no improvement for 83/100 epochs
#
# → Starting epoch 302  (printing every 172 iters)
# [Epoch 302] iter 172/172, avg loss: 0.0018
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QAA2705N                  | QAA2705N                  | 0.9935
# AKW!716                   | AKW!716                   | 0.9811
# GOLD!886                  | GOLD!886                  | 0.9626
# JRP7041                   | JRP7041                   | 0.9814
# QRR!5692                  | QRR!5692                  | 0.9687
# --------------------------------------------------------------------------------
# ==> Epoch 302 done in 11.3s | train_loss=0.0018  valid_loss=0.3367  valid_acc=81.92%
#
# no improvement for 84/100 epochs
#
# → Starting epoch 303  (printing every 172 iters)
# [Epoch 303] iter 172/172, avg loss: 0.0012
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# SYP9169                   | SYP9169                   | 0.9961
# CDD!8169                  | CDD!8169                  | 0.9762
# RT9009                    | RT9009                    | 0.9885
# WSL8189                   | WSL8189                   | 0.9982
# QAA!9381W                 | QAA!9381W                 | 0.9575
# --------------------------------------------------------------------------------
# ==> Epoch 303 done in 11.3s | train_loss=0.0012  valid_loss=0.3332  valid_acc=82.22%
#
# no improvement for 85/100 epochs
#
# → Starting epoch 304  (printing every 172 iters)
# [Epoch 304] iter 172/172, avg loss: 0.0009
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QAB4033                   | QAB4033                   | 0.9985
# WXW8900                   | WXW8900                   | 0.9781
# QCB3330                   | QCB3330                   | 0.9916
# RT9009                    | RT9009                    | 0.9793
# JLX!1296                  | JLX!1296                  | 0.9936
# --------------------------------------------------------------------------------
# ==> Epoch 304 done in 11.3s | train_loss=0.0009  valid_loss=0.3674  valid_acc=81.05%
#
# no improvement for 86/100 epochs
#
# → Starting epoch 305  (printing every 172 iters)
# [Epoch 305] iter 172/172, avg loss: 0.0013
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# MDS7658                   | MDS7658                   | 0.9942
# PRH5551                   | PRH5551                   | 0.9989
# VGL5629                   | VGL5629                   | 0.9748
# QKT8216                   | QKT8216                   | 0.9779
# QAA3323X                  | QAA3323X                  | 0.9967
# --------------------------------------------------------------------------------
# ==> Epoch 305 done in 11.2s | train_loss=0.0013  valid_loss=0.3580  valid_acc=81.92%
#
# no improvement for 87/100 epochs
#
# → Starting epoch 306  (printing every 172 iters)
# [Epoch 306] iter 172/172, avg loss: 0.0014
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# WFB!6925                  | WFB!6925                  | 0.9911
# JWA!8158                  | JWA!8158                  | 0.9493
# QM8169                    | QM8169                    | 0.9931
# WUX4391                   | WUX4391                   | 0.9986
# QAR!7273                  | QAR!7273                  | 0.9970
# --------------------------------------------------------------------------------
# ==> Epoch 306 done in 11.2s | train_loss=0.0014  valid_loss=0.3761  valid_acc=81.63%
#
# no improvement for 88/100 epochs
#
# → Starting epoch 307  (printing every 172 iters)
# [Epoch 307] iter 172/172, avg loss: 0.0014
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QLB7733                   | QLB7733                   | 0.9759
# SB218F                    | SB218F                    | 0.9991
# RP!5366                   | RP!5366                   | 0.9840
# QTD33                     | QTD33                     | 0.9985
# QS74V                     | QS74V                     | 0.9590
# --------------------------------------------------------------------------------
# ==> Epoch 307 done in 11.2s | train_loss=0.0014  valid_loss=0.4393  valid_acc=79.59%
#
# no improvement for 89/100 epochs
#
# → Starting epoch 308  (printing every 172 iters)
# [Epoch 308] iter 172/172, avg loss: 0.0020
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# WFH6380                   | WFH6380                   | 0.9912
# QTQ1531                   | QTQ1531                   | 0.9968
# WFN4042                   | WFN4042                   | 0.9809
# QKF9126                   | QKF9126                   | 0.9794
# VKD9639                   | VKD9639                   | 0.9802
# --------------------------------------------------------------------------------
# ==> Epoch 308 done in 11.1s | train_loss=0.0020  valid_loss=0.3773  valid_acc=81.05%
#
# no improvement for 90/100 epochs
#
# → Starting epoch 309  (printing every 172 iters)
# [Epoch 309] iter 172/172, avg loss: 0.0082
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QRN!8598                  | QRN!8598                  | 0.9889
# DCS3819                   | DCS3819                   | 0.9987
# MDL1672                   | MDL1672                   | 0.9992
# VGE3354                   | VGE3354                   | 0.9964
# QS3284P                   | QS3284P                   | 0.9956
# --------------------------------------------------------------------------------
# ==> Epoch 309 done in 11.1s | train_loss=0.0082  valid_loss=0.3672  valid_acc=80.76%
#
# no improvement for 91/100 epochs
#
# → Starting epoch 310  (printing every 172 iters)
# [Epoch 310] iter 172/172, avg loss: 0.0013
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# VLX7844                   | VLX7844                   | 0.9766
# WLP6892                   | WLP6892                   | 0.9935
# WFB2641                   | WFB2641                   | 0.9992
# SB218F                    | SB218F                    | 0.9774
# VGE3354                   | VGE3354                   | 0.9840
# --------------------------------------------------------------------------------
# ==> Epoch 310 done in 11.2s | train_loss=0.0013  valid_loss=0.3697  valid_acc=79.59%
#
# no improvement for 92/100 epochs
#
# → Starting epoch 311  (printing every 172 iters)
# [Epoch 311] iter 172/172, avg loss: 0.0010
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QCJ4830                   | QCJ4830                   | 0.9256
# WUV!7830                  | WUV!7830                  | 0.9997
# AGX7136                   | AGX7136                   | 0.9483
# VDL4789                   | VDL4789                   | 0.9960
# NBG8520                   | NBG8520                   | 0.9988
# --------------------------------------------------------------------------------
# ==> Epoch 311 done in 11.1s | train_loss=0.0010  valid_loss=0.3641  valid_acc=81.05%
#
# no improvement for 93/100 epochs
#
# → Starting epoch 312  (printing every 172 iters)
# [Epoch 312] iter 172/172, avg loss: 0.0012
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# T/JA3834                  | T/JA3834                  | 0.9967
# BRW!9                     | BRW!9                     | 0.9939
# SD5508L                   | SD5508L                   | 0.9770
# QDB!448                   | QDB!448                   | 0.9737
# ADU7533                   | ADU7533                   | 0.9997
# --------------------------------------------------------------------------------
# ==> Epoch 312 done in 11.2s | train_loss=0.0012  valid_loss=0.3564  valid_acc=81.05%
#
# no improvement for 94/100 epochs
#
# → Starting epoch 313  (printing every 172 iters)
# [Epoch 313] iter 172/172, avg loss: 0.0075
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# MDV1999                   | MDV1999                   | 0.9487
# RN5082                    | RN5082                    | 0.9840
# VNQ4338                   | VNQ4338                   | 0.9788
# VEN634                    | VCN634                    | 0.9384
# QS1595E                   | QS1595E                   | 0.9838
# --------------------------------------------------------------------------------
# ==> Epoch 313 done in 11.1s | train_loss=0.0075  valid_loss=0.3811  valid_acc=76.09%
#
# no improvement for 95/100 epochs
#
# → Starting epoch 314  (printing every 172 iters)
# [Epoch 314] iter 172/172, avg loss: 0.0028
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# QKU9019                   | QKU9019                   | 0.9958
# QM2377M                   | QM2377M                   | 0.9863
# MDJ50                     | MDJ50                     | 0.9796
# VNL9999                   | VNL9999                   | 0.9805
# RR1776                    | RR1776                    | 0.9821
# --------------------------------------------------------------------------------
# ==> Epoch 314 done in 11.1s | train_loss=0.0028  valid_loss=0.3793  valid_acc=78.43%
#
# no improvement for 96/100 epochs
#
# → Starting epoch 315  (printing every 172 iters)
# [Epoch 315] iter 172/172, avg loss: 0.0017
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# WXJ9118                   | WXJ9118                   | 0.9973
# QAE2205                   | QAE2205                   | 0.9898
# WMX9993                   | WMX9993                   | 0.9959
# PNV!4846                  | PNV!4846                  | 0.9994
# WGC!5600                  | WGC!5600                  | 0.9844
# --------------------------------------------------------------------------------
# ==> Epoch 315 done in 11.0s | train_loss=0.0017  valid_loss=0.3615  valid_acc=78.43%
#
# no improvement for 97/100 epochs
#
# → Starting epoch 316  (printing every 172 iters)
# [Epoch 316] iter 172/172, avg loss: 0.0008
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# BJT8812                   | BJT8812                   | 0.9403
# NCB!7903                  | NCB!7903                  | 0.9789
# AHU!7727                  | AHU!7727                  | 0.9957
# JTE!2309                  | JTE!2309                  | 0.9827
# QAA!4494H                 | QAA!4494H                 | 0.9491
# --------------------------------------------------------------------------------
# ==> Epoch 316 done in 11.2s | train_loss=0.0008  valid_loss=0.3696  valid_acc=80.76%
#
# no improvement for 98/100 epochs
#
# → Starting epoch 317  (printing every 172 iters)
# [Epoch 317] iter 172/172, avg loss: 0.0025
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# JTW!5239                  | JTW!5239                  | 0.9825
# QDB7814                   | QDB7814                   | 0.9998
# QAY9700                   | QAY9700                   | 0.9997
# PRM41                     | PRM41                     | 0.9822
# KFX!7711                  | KFX!7711                  | 0.9740
# --------------------------------------------------------------------------------
# ==> Epoch 317 done in 11.1s | train_loss=0.0025  valid_loss=0.4283  valid_acc=79.30%
#
# no improvement for 99/100 epochs
#
# → Starting epoch 318  (printing every 172 iters)
# [Epoch 318] iter 172/172, avg loss: 0.0012
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | AvgConfidence
# --------------------------------------------------------------------------------
# WQN8002                   | WQN8002                   | 0.9732
# AHU7727                   | AHU7727                   | 0.9946
# CEW!485                   | CEW!485                   | 0.9941
# WMR8630                   | WMR8630                   | 0.9855
# VDV7199                   | VDV7199                   | 0.9881
# --------------------------------------------------------------------------------
# ==> Epoch 318 done in 11.1s | train_loss=0.0012  valid_loss=0.4277  valid_acc=78.43%
#
# no improvement for 100/100 epochs
#
# 🔚 Early stopping: val_acc hasn't improved for 100 epochs.

# %%
clean_history = {
  'epoch':      history['epoch'],
  'train_loss': [x.cpu().item() if hasattr(x, 'cpu') else x for x in history['train_loss']],
  'val_loss':   [x.cpu().item() if hasattr(x, 'cpu') else x for x in history['val_loss']],
  'val_acc':    [x.cpu().item() if hasattr(x, 'cpu') else x for x in history['val_acc']],
}
df = pd.DataFrame(clean_history)
display(df)

plt.figure()
plt.plot(df['epoch'], df['train_loss'], label='Train Loss')
plt.plot(df['epoch'], df['val_loss'],   label='Val Loss')
plt.xlabel('Epoch'); plt.ylabel('Loss'); plt.legend()
plt.title('Loss over Epochs')
plt.show()

plt.figure()
plt.plot(df['epoch'], df['val_acc'],   label='Val Accuracy')
plt.xlabel('Epoch'); plt.ylabel('Accuracy (%)'); plt.legend()
plt.title('Val Accuracy over Epochs')
plt.show()
# Out:
#      epoch  train_loss  val_loss    val_acc
# 0        1    2.614358  1.949283   0.000000
# 1        2    1.597078  1.069742   3.206997
# 2        3    0.858380  0.718701  40.524781
# 3        4    0.529251  0.542846  61.224490
# 4        5    0.408434  0.513308  64.431487
# ..     ...         ...       ...        ...
# 177    178    0.000734  0.425546  80.466472
# 178    179    0.000648  0.412388  79.300292
# 179    180    0.000557  0.411702  79.300292
# 180    181    0.000734  0.409038  79.008746
# 181    182    0.000556  0.444837  76.967930
#
# [182 rows x 4 columns]

# %%
# # ─── Cell 9: ONNX export via isolated inference head ─────────────────────────
# import torch

# class CRNNInference(torch.nn.Module):
#     def __init__(self, crnn, max_len):
#         super().__init__()
#         # use exactly the names printed out by your inspection
#         self.Transformation     = crnn.Transformation
#         self.FeatureExtraction = crnn.FeatureExtraction
#         self.AdaptiveAvgPool    = crnn.AdaptiveAvgPool
#         self.SequenceModeling   = crnn.SequenceModeling
#         self.Prediction         = crnn.Prediction
#         self.max_len           = max_len
#         # adjust this if your converter stores start-token under a different key
#         self.start_id          = crnn.converter.dict['[GO]']

#     def forward(self, image):
#         # 1) Spatial‐transformer + feature CNN
#         x = self.Transformation(image)                     # [B, C, H, W]
#         x = self.FeatureExtraction(x)                      # [B, C, H, W]

#         # 2) Pool down height to 1
#         x = self.AdaptiveAvgPool(x)                        # [B, C, 1, W]
#         x = x.squeeze(2)                                   # [B, C, W]
#         x = x.permute(0, 2, 1)                             # [B, W, C]

#         # 3) 2‐layer BiLSTM
#         contextual = self.SequenceModeling(x)              # [B, W, hidden]

#         # 4) Dummy “[GO]” token vector
#         B = contextual.size(0)
#         dummy_text = torch.full(
#             (B,),
#             self.start_id,
#             dtype=torch.long,
#             device=image.device
#         )  # shape [B]

#         # 5) Attention decoder (inference path)
#         return self.Prediction(
#             batch_H           = contextual,
#             text              = dummy_text,
#             is_train          = False,
#             batch_max_length  = self.max_len
#         )

# # Wrap and export
# inference_model = CRNNInference(model, BATCH_MAX_LENGTH).eval()
# dummy_img       = torch.randn(1, INPUT_CHANNEL, IMG_HEIGHT, IMG_WIDTH, device=device)

# torch.onnx.export(
#     inference_model,
#     dummy_img,
#     "best_attention_crnn.onnx",
#     input_names   = ['image'],
#     output_names  = ['logits'],
#     dynamic_axes  = {
#         'image':  {0: 'batch'},
#         'logits': {0: 'batch', 1: 'time'}
#     },
#     opset_version = 13,
# )

# print("✅ Exported best_attention_crnn.onnx")

# %% [markdown]
# # DUMP

# %%
# # ─── cell 6: attention‐based training loop ──────────────────────────────────────
# for epoch in range(1, NUM_EPOCHS+1):
#     print(f"→ Starting epoch {epoch}  (printing every {PRINT_EVERY} iters)")
#     model.train()
#     epoch_loss = Averager()
#     start      = time.time()

#     for i, (images, texts) in enumerate(train_loader, 1):
#         images = images.to(device)

#         # encode with [GO] & [s]; also get lengths
#         text, length = converter.encode(texts, batch_max_length=BATCH_MAX_LENGTH)
#         text_input  = text[:, :-1].to(device)   # drop final [s]
#         text_target = text[:,  1:].to(device)   # everything after [GO]

#         # forward + loss
#         preds = model(images,
#                       text=text_input,
#                       is_train=True,
#                       batch_max_length=BATCH_MAX_LENGTH)  # [B, S, C]
#         B, S, C = preds.size()
#         loss = criterion(
#             preds.view(B * S, C),
#             text_target.contiguous().view(B * S)
#         )

#         optimizer.zero_grad()
#         loss.backward()
#         torch.nn.utils.clip_grad_norm_(model.parameters(), 5)
#         optimizer.step()
#         epoch_loss.add(loss)

#         if i % PRINT_EVERY == 0 or i == 1:
#             print(f"[Epoch {epoch}] iter {i}/{len(train_loader)}, avg loss: {epoch_loss.val():.4f}", flush=True)

#             # quick greedy‐decode
#             with torch.no_grad():
#                 probs        = preds.softmax(2)           # [B, S, C]
#                 max_vals, max_inds = probs.max(2)         # [B, S]
#                 pred_strs    = converter.decode(max_inds, length)
#                 pred_strs    = [s.split('[s]')[0] for s in pred_strs]

#             # print a mini‐table
#             print("-" * 80)
#             print(f"{'Ground Truth':25s} | {'Prediction':25s} | AvgConfidence")
#             print("-" * 80)
#             for gt, pr, conf_seq in zip(texts[:5], pred_strs[:5], max_vals[:5]):
#                 conf = conf_seq.mean().item()
#                 print(f"{gt:25s} | {pr:25s} | {conf:0.4f}")
#             print("-" * 80)

#     # end‐of‐epoch validation
#     val_loss, val_acc = validate(model, val_loader)
#     elapsed = time.time() - start
#     print(f"==> Epoch {epoch} done in {elapsed:.1f}s | "
#           f"train_loss={epoch_loss.val():.4f}"
#           f"  valid_loss={val_loss:.4f}  valid_acc={val_acc:.2f}%\n")

# %%
# # ─── Cell 6: training w/ history, best‐model saving ───

# # hyper‐params
# best_val_acc    = 0.0
# history         = {'epoch': [], 'train_loss': [], 'val_loss': [], 'val_acc': []}

# for epoch in range(1, NUM_EPOCHS+1):
#     print(f"→ Starting epoch {epoch}  (printing every {PRINT_EVERY} iters)")
#     model.train()
#     epoch_loss = Averager()
#     start = time.time()

#     # ─── training ─────────────────────────────────────────────────────────────
#     for i, (images, texts) in enumerate(train_loader, 1):
#         images = images.to(device)

#         text, length   = converter.encode(texts, batch_max_length=MAX_LABEL_LENGTH)
#         text_input     = text[:, :-1].to(device)
#         text_target    = text[:,  1:].to(device)

#         preds = model(
#             images,
#             text=text_input,
#             is_train=True,
#             batch_max_length=MAX_LABEL_LENGTH
#         )  # [B, S, C]
#         B, S, C = preds.size()
#         loss = criterion(
#             preds.view(B * S, C),
#             text_target.contiguous().view(B * S)
#         )

#         optimizer.zero_grad()
#         loss.backward()
#         torch.nn.utils.clip_grad_norm_(model.parameters(), 5)
#         optimizer.step()
#         epoch_loss.add(loss)

#         # mini‐table prints
#         if i % PRINT_EVERY == 0:
#             print(f"[Epoch {epoch}] iter {i}/{len(train_loader)}, avg loss: {epoch_loss.val():.4f}", flush=True)
#             with torch.no_grad():
#                 probs     = preds.softmax(2)
#                 max_vals, max_inds = probs.max(2)
#                 pred_strs = converter.decode(max_inds, length)
#                 pred_strs = [s.split('[s]')[0] for s in pred_strs]

#             print("-" * 80)
#             print(f"{'Ground Truth':25s} | {'Prediction':25s} | AvgConfidence")
#             print("-" * 80)
#             for gt, pr, conf_seq in zip(texts[:5], pred_strs[:5], max_vals[:5]):
#                 conf = conf_seq.mean().item()
#                 print(f"{gt:25s} | {pr:25s} | {conf_seq.mean().item():.4f}")
#             print("-" * 80)

#     # ─── validation ────────────────────────────────────────────────────────────
#     val_loss, val_acc = validate(model, val_loader)
#     elapsed = time.time() - start
#     train_l = epoch_loss.val()
#     print(f"==> Epoch {epoch} done in {elapsed:.1f}s | "
#           f"train_loss={train_l:.4f}  valid_loss={val_loss:.4f}  valid_acc={val_acc:.2f}%\n")

#     # ─── record history & save best ──────────────────────────────────────────
#     history['epoch'].append(epoch)
#     history['train_loss'].append(train_l)
#     history['val_loss'].append(val_loss)
#     history['val_acc'].append(val_acc)

#     if val_acc > best_val_acc:
#         best_val_acc = val_acc
#         torch.save(model.state_dict(), "best_attention_crnn_!.pth")
#         print(f"💾 New best model saved (epoch {epoch}, val_acc={val_acc:.2f}%)\n")
